# %% [markdown]
# Copyright Jana Schaich Borg/Attribution-NonCommercial 4.0 International (CC BY-NC 4.0)

# %% [markdown]
# # MySQL Exercise 1: Welcome to your first notebook!
#
# Database interfaces vary greatly across platforms and companies.  The interface you will be using here, called Jupyter, is a web application designed for data science teams who need to create and share documents that share live code.  We will be taking advantage of Jupyter's ability to integrate instructional text with areas that allow you to write and run SQL queries.  In this course, you will practice writing queries about the Dognition data set in these Jupyter notebooks as I give you step-by-step instructions through written text.  Then once you are comfortable with the query syntax, you will practice writing queries about the Dillard's data set in Teradata Viewpoint's more traditional SQL interface, called SQL scratchpad. Your assessments each week will be based on the exercises you complete using the Dillard's dataset.
#
# Jupyter runs in a language called Python, so some of the commands you will run in these MySQL exercises will require incorporating small amounts of Python code, along with the MySQL query itself.  Python is a very popular programming language with many statistical and visualization libraries, so you will likely encounter it in other business analysis settings.  Since many data analysis projects do not use Python, however, I will point out to you what parts of the commands are specific to Python interfaces.
#
# ## The first thing you should do every time you start working with a database: load the SQL library
#
# Since Jupyter is run through Python, the first thing you need to do to start practicing SQL queries is load the SQL library.  To do this, type the following line of code into the empty cell below:
#
# ```python
# %load_ext sql
# ```

# %%
# %load_ext sql

# %% [markdown]
# The "%" in this line of code is syntax for Python, not SQL.  The "cell" I am referring to is the empty box area beside the "In [  ]:" you see on the left side of the screen.
#
# Once you've entered the line of code, press the "run" button on the Jupyter toolbar that looks like an arrow.  It's located under “cell” in the drop-down menu bar, and next to the stop button (the solid square).  The run button is outlined in red in this picture:
#
# ![alt text](https://duke.box.com/shared/static/u9chww13kim30t5p6ndh404d9ap6auwf.jpg)
#
# **TIP: Whenever instructions say “run” or "execute" a command in future exercises, type the appropriate code into the empty cell and execute it by pressing this same button with the arrow.**
#
# When the library has loaded, you will see a number between the brackets that preceed the line of code you executed:
#
# For example, it might look like this:
#
# ```
# In [2]:
# ```
#
#
# ## The second thing you must do every time you want to start working with a database: connect to the database you need to use.
#
# Now that the SQL library is loaded, we need to connect to a database.  The following command will log you into the MySQL server at mysqlserver as the user 'studentuser' and will select the database named 'dognitiondb' :
#
# ```python
# mysql://studentuser:studentpw@mysqlserver/dognitiondb
# ```
#
# However, to execute this command using SQL language instead of Python, you will need to begin the line of code with:
#
# ```python
# %sql
# ```
#
# Thus, the complete line of code is:
#
# ```python
# %sql mysql://studentuser:studentpw@mysqlserver/dognitiondb
# ```
#
# Connect to the database by typing this command into the cell below, and running it (note: you can copy and paste the command from above rather than typing it, if you choose):

# %%
# %sql mysql://studentuser:studentpw@mysqlserver/dognitiondb
# Out:
# 'Connected: studentuser@dognitiondb'

# %% [markdown]
# <mark>***Every time you run a line of SQL code in Jupyter, you will need to preface the line with "%sql".  Remember to do this, even though I will not explicitly instruct you to do so for the rest of the exercises in this course.***</mark>
#
# Once you are connected, the output cell (which reads "Out" followed by brackets) will read: "Connected:studentuser@dognitiondb".  To make this the default database for our queries, run this "USE" command:
#
# ```python
# %sql USE dognitiondb
# ```

# %%
# %sql USE dognitiondb
# Out:
# 0 rows affected.
# []

# %% [markdown]
# You are now ready to run queries in the Dognition database!
#
#
# ## The third thing you should do every time you start working with a new database: get to know your data
#
# The data sets you will be working with in business settings will be big.  REALLY big.  If you just start making queries without knowing what you are pulling out, you could hang up your servers or be staring at your computer for hours before you get an output.  Therefore, even if you are given an ER diagram or relational schema like we learned about in the first week of the course, before you start querying I strongly recommend that you (1) confirm how many tables each database has, and (2) identify the fields contained in each table of the database.  To determine how many tables each database has, use the SHOW command:
#
# ```mySQL
# SHOW tables
# ```
#
# **Try it yourself (TIP: if you get an error message, it's probably because you forgot to start the query with "%sql"):**

# %%
# %sql SHOW tables
# Out:
# 6 rows affected.
# [('complete_tests',),
#  ('dogs',),
#  ('exam_answers',),
#  ('reviews',),
#  ('site_activities',),
#  ('users',)]

# %% [markdown]
# The output that appears above should show you there are six tables in the Dognition database.  To determine what columns or fields (we will use those terms interchangeably in this course) are in each table, you can use the SHOW command again, but this time (1) you have to clarify that you want to see columns instead of tables, and (2) you have to specify from which table you want to examine the columns.
#
# The syntax, which sounds very similar to what you would actually say in the spoken English language, looks like this:
#
# ```mySQL
# SHOW columns FROM (enter table name here)
# ```
# or if you have multiple databases loaded:
# ```mySQL
# SHOW columns FROM (enter table name here) FROM (enter database name here)
# ```
# or
# ```mySQL
# SHOW columns FROM databasename.tablename
# ```
# <mark> Whenever you have multiple databases loaded, you will need to specify which database a table comes from using one of the syntax options described above.</mark>
#
# As I said in the earlier "Introduction to Query Syntax" video, it makes it easier to read and troubleshoot your queries if you always write SQL keywords in UPPERCASE format and write your table and field names in their native format.  We will only use the most important SQL keywords in this course, but a full list can be found here:
#
# https://dev.mysql.com/doc/refman/5.5/en/keywords.html
#
#
# **Question 1: How many columns does the "dogs" table have?  Enter the appropriate query below to find out:**

# %%
# %sql SHOW columns from dogs
# Out:
# 21 rows affected.
# [('gender', 'varchar(255)', 'YES', '', None, ''),
#  ('birthday', 'varchar(255)', 'YES', '', None, ''),
#  ('breed', 'varchar(255)', 'YES', '', None, ''),
#  ('weight', 'int(11)', 'YES', '', None, ''),
#  ('dog_fixed', 'tinyint(1)', 'YES', '', None, ''),
#  ('dna_tested', 'tinyint(1)', 'YES', '', None, ''),
#  ('created_at', 'datetime', 'NO', '', None, ''),
#  ('updated_at', 'datetime', 'NO', '', None, ''),
#  ('dimension', 'varchar(255)', 'YES', '', None, ''),
#  ('exclude', 'tinyint(1)', 'YES', '', None, ''),
#  ('breed_type', 'varchar(255)', 'YES', '', None, ''),
#  ('breed_group', 'varchar(255)', 'YES', '', None, ''),
#  ('dog_guid', 'varchar(60)', 'YES', 'MUL', None, ''),
#  ('user_guid', 'varchar(60)', 'YES', 'MUL', None, ''),
#  ('total_tests_completed', 'varchar(255)', 'YES', '', None, ''),
#  ('mean_iti_days', 'varchar(255)', 'YES', '', None, ''),
#  ('mean_iti_minutes', 'varchar(255)', 'YES', '', None, ''),
#  ('median_iti_days', 'varchar(255)', 'YES', '', None, ''),
#  ('median_iti_minutes', 'varchar(255)', 'YES', '', None, ''),
#  ('time_diff_between_first_and_last_game_days', 'varchar(255)', 'YES', '', None, ''),
#  ('time_diff_between_first_and_last_game_minutes', 'varchar(255)', 'YES', '', None, '')]

# %% [markdown]
# You should have determined that the "dogs" table has 21 columns.
#
# An alternate way to learn the same information would be to use the DESCRIBE function.  The syntax is:
#
# ```mySQL
# DESCRIBE tablename
# ```
#
# **Question 2: Try using the DESCRIBE function to learn how many columns are in the "reviews" table:**

# %%
# %sql DESCRIBE reviews
# Out:
# 7 rows affected.
# [('rating', 'int(11)', 'YES', '', None, ''),
#  ('created_at', 'datetime', 'NO', '', None, ''),
#  ('updated_at', 'datetime', 'NO', '', None, ''),
#  ('user_guid', 'varchar(60)', 'YES', 'MUL', None, ''),
#  ('dog_guid', 'varchar(60)', 'YES', 'MUL', None, ''),
#  ('subcategory_name', 'varchar(60)', 'YES', '', None, ''),
#  ('test_name', 'varchar(60)', 'YES', '', None, '')]

# %% [markdown]
# You should have determined that there are 7 columns in the "reviews" table.
#
# The SHOW and DESCRIBE functions give a lot more information about the table than just how many columns, or fields, there are.  Indeed, the first column of the output shows the title of each field in the table.  The column next to that describes what type of data are stored in that column.  There are 3 main types of data in MySQL: text, number, and datetime.  There are many subtypes of data within these three general categories, as described here:
#
# http://support.hostgator.com/articles/specialized-help/technical/phpmyadmin/mysql-variable-types
#
# The next column in the SHOW/DESCRIBE output indicates whether null values can be stored in the field in the table.  The "Key" column of the output provides the following information about each field of data in the table being described (see https://dev.mysql.com/doc/refman/5.6/en/show-columns.html for more information):
#
# + Empty: the column either is not indexed or is indexed only as a secondary column in a multiple-column, nonunique index.
# + PRI: the column is a PRIMARY KEY or is one of the columns in a multiple-column PRIMARY KEY.
# + UNI: the column is the first column of a UNIQUE index.
# + MUL: the column is the first column of a nonunique index in which multiple occurrences of a given value are permitted within the column.
#
# The "Default" field of the output indicates the default value that is assigned to the field. The "Extra" field contains any additional information that is available about a given field in that table.
#
# **Questions 3-6: In the cells below, examine the fields in the other 4 tables of the Dognition database:**

# %%
# %sql DESCRIBE users
# Out:
# 16 rows affected.
# [('sign_in_count', 'int(11)', 'YES', '', '0', ''),
#  ('created_at', 'datetime', 'NO', '', None, ''),
#  ('updated_at', 'datetime', 'NO', '', None, ''),
#  ('max_dogs', 'int(11)', 'YES', '', '0', ''),
#  ('membership_id', 'int(11)', 'YES', '', None, ''),
#  ('subscribed', 'tinyint(1)', 'YES', '', '0', ''),
#  ('exclude', 'tinyint(1)', 'YES', '', None, ''),
#  ('free_start_user', 'tinyint(1)', 'YES', '', None, ''),
#  ('last_active_at', 'datetime', 'YES', '', None, ''),
#  ('membership_type', 'int(11)', 'YES', '', None, ''),
#  ('user_guid', 'text', 'YES', 'MUL', None, ''),
#  ('city', 'varchar(255)', 'YES', '', None, ''),
#  ('state', 'varchar(255)', 'YES', '', None, ''),
#  ('zip', 'varchar(255)', 'YES', '', None, ''),
#  ('country', 'varchar(255)', 'YES', '', None, ''),
#  ('utc_correction', 'varchar(255)', 'YES', '', None, '')]

# %%
sql DESCRIBE exam_answers
# Out:
# 8 rows affected.
# [('script_detail_id', 'int(11)', 'YES', '', None, ''),
#  ('subcategory_name', 'varchar(255)', 'YES', '', None, ''),
#  ('test_name', 'varchar(255)', 'YES', '', None, ''),
#  ('step_type', 'varchar(255)', 'YES', '', None, ''),
#  ('start_time', 'datetime', 'YES', '', None, ''),
#  ('end_time', 'datetime', 'YES', '', None, ''),
#  ('loop_number', 'int(11)', 'YES', '', None, ''),
#  ('dog_guid', 'varchar(60)', 'YES', '', None, '')]

# %%
sql DESCRIBE complete_tests
# Out:
# 6 rows affected.
# [('created_at', 'datetime', 'NO', '', None, ''),
#  ('updated_at', 'datetime', 'NO', '', None, ''),
#  ('user_guid', 'varchar(60)', 'YES', 'MUL', None, ''),
#  ('dog_guid', 'varchar(60)', 'YES', 'MUL', None, ''),
#  ('test_name', 'varchar(60)', 'YES', '', None, ''),
#  ('subcategory_name', 'varchar(60)', 'YES', '', None, '')]

# %%
sql DESCRIBE site_activities
# Out:
# 11 rows affected.
# [('activity_type', 'varchar(150)', 'YES', 'MUL', None, ''),
#  ('description', 'text', 'YES', '', None, ''),
#  ('membership_id', 'int(11)', 'YES', '', None, ''),
#  ('category_id', 'int(11)', 'YES', '', None, ''),
#  ('script_id', 'int(11)', 'YES', '', None, ''),
#  ('created_at', 'datetime', 'NO', '', None, ''),
#  ('updated_at', 'datetime', 'NO', '', None, ''),
#  ('user_guid', 'varchar(255)', 'YES', 'MUL', None, ''),
#  ('script_detail_id', 'int(11)', 'YES', '', None, ''),
#  ('test_name', 'varchar(255)', 'YES', '', None, ''),
#  ('dog_guid', 'varchar(255)', 'YES', 'MUL', None, '')]

# %% [markdown]
# As you examine the fields in each table, you will notice that none of the Dognition tables have primary keys declared.  However, take note of which fields say "MUL" in the "Key" column of the DESCRIBE output, because these columns can still be used to link tables together.  An important thing to keep in mind, though, is that because these linking columns were not configured as primary keys, it is possible the linking fields contain NULL values or duplicate rows.
#
# If you do not have a ER diagram or relational schema of the Dognition database yet, consider making one at this point, because you will need to refer back to table and column names constantly throughout designing your queries  (if you don't remember what primary keys, secondary keys, ER diagrams, or relational schemas are, review the material discussed in the first week of this course).  Some database interfaces do provide notes or visual representations about the information in each table for easy reference, but since the Jupyter interface does not provide this, take your own notes and make your own diagrams, and keep them handy.  As you will see, these diagrams and notes will save you a lot of time when you design your queries to pull data.
#
#
# ## Using SELECT to look at your raw data
#
# Once you have an idea of what is in your tables look like and how they might interact, it's a good idea to look at some of the raw data itself so that you are aware of any anomalies that could pose problems for your analysis or interpretations.  To do that, we will use arguably the most important SQL statement for analysts: the SELECT statement.
#
# SELECT is used anytime you want to retrieve data from a table.  In order to retrieve that data, you always have to provide at least two pieces of information:
#
#     (1) what you want to select, and
#     (2) from where you want to select it.
#
# I recommend that you always format your SQL code to ensure that these two pieces of information are on separate lines, so they are easy to identify quickly by eye.
#
# The skeleton of a SELECT statement looks like this:
#
# ```mySQL
# SELECT
# FROM
# ```
#
# To fill in the statement, you indicate the column names you are interested in after "SELECT" and the table name (and database name, if you have multiple databases loaded) you are drawing the information from after "FROM."  So in order to look at the breeds in the dogs table, you would execute the following command:
#
# ```mySQL
# SELECT breed
# FROM dogs;
# ```
#
# Remember:
# + SQL syntax and keywords are case insensitive.  I recommend that you always enter SQL keywords in upper case and table or column names in either lower case or their native format to make it easy to read and troubleshoot your code, but it is not a requirement to do so.  Table or column names are often case insensitive as well, but defaults may vary across database platforms so it's always a good idea to check.
# + Table or column names with spaces in them need to be surrounded by quotation marks in SQL.  MySQL accepts both double and single quotation marks, but some database systems only accept single quotation marks.  In all database systems, if a table or column name contains an SQL keyword, the name must be enclosed in backticks instead of quotation marks.
# > ` 'the marks that surrounds this phrase are single quotation marks' `
# > ` "the marks that surrounds this phrase are double quotation marks" `
# > `` `the marks that surround this phrase are backticks` ``
# + The semi-colon at the end of a query is only required when you have multiple separate queries saved in the same text file or editor.  That said, I recommend that you make it a habit to always include a semi-colon at the end of your queries.
#
# <mark>An important note for executing queries in Jupyter: in order to tell Python that you want to execute SQL language on multiple lines, you must include two percent signs in front of the SQL prefix instead of one.</mark>  Therefore, to execute the above query, you should enter:
#
# ```mySQL
# %%sql
# SELECT breed
# FROM dogs;
# ```
#
# When Jupyter is busy executing a query, you will see an asterisk in the brackets next to the output field:
#
# ```
# Out [*]
# ```
#
# When the query is completed, you will see a number in the brackets next to the output field.
#
# ```
# Out [5]
# ```
#
# **Try it yourself:**

# %%
# %%sql
# SELECT breed, dimension
# FROM dogs
# Out:
# 35050 rows affected.
# [('Labrador Retriever', 'charmer'),
#  ('Shetland Sheepdog', 'protodog'),
#  ('Golden Retriever', None),
#  ('Golden Retriever', None),
#  ('Shih Tzu', 'einstein'),
#  ('Siberian Husky', 'stargazer'),
#  ('Shih Tzu', 'maverick'),
#  ('Mixed', 'protodog'),
#  ('Labrador Retriever', 'einstein'),
#  ('Shih Tzu-Poodle Mix', 'socialite'),
#  ('German Shepherd Dog-Pembroke Welsh Corgi Mix', None),
#  ('Vizsla', 'socialite'),
#  ('Pug', 'stargazer'),
#  ('Boxer', 'ace'),
#  ('German Shepherd Dog-Nova Scotia Duck Tolling Retriever Mix', None),
#  ('Beagle', 'protodog'),
#  ('Beagle', 'expert'),
#  ('Beagle', None),
#  ('Mixed', None),
#  ('Chesapeake Bay Retriever', 'charmer'),
#  ('Border Collie', None),
#  ('Belgian Malinois', 'stargazer'),
#  ('Australian Shepherd-German Shepherd Dog Mix', 'renaissance-dog'),
#  ('Poodle', None),
#  ('Poodle', None),
#  ('Golden Doodle', None),
#  ('Labrador Retriever', None),
#  ('German Shepherd Dog', None),
#  ('German Shepherd Dog', None),
#  ('Weimaraner', 'stargazer'),
#  ('Mixed', 'maverick'),
#  ('Bouvier des Flandres', 'socialite'),
#  ('Mixed', 'einstein'),
#  ('German Shepherd Dog', None),
#  ('Beagle', None),
#  ('Mudi', None),
#  ('Parson Russell Terrier-Beagle Mix', None),
#  ('Dalmatian', None),
#  ("I Don't Know", None),
#  ('Border Collie-Labrador Retriever Mix', 'charmer'),
#  ('Belgian Tervuren', 'socialite'),
#  ('Mixed', 'maverick'),
#  ('Labrador Retriever', 'stargazer'),
#  ('Shih Tzu', 'protodog'),
#  ('Australian Terrier', None),
#  ('Shih Tzu', 'maverick'),
#  ('Golden Retriever', 'einstein'),
#  ('Bernese Mountain Dog', None),
#  ('Chihuahua- Mix', None),
#  ('Shetland Sheepdog', None),
#  ('Shetland Sheepdog', None),
#  ('Mixed', None),
#  ('Chihuahua-Dachshund Mix', None),
#  ('Finnish Spitz', None),
#  ('Siberian Husky', None),
#  ('Rottweiler', None),
#  ('Pembroke Welsh Corgi', None),
#  ('Brussels Griffon', None),
#  ('Mixed', None),
#  ('French Bulldog', None),
#  ('French Bulldog', None),
#  ('Shih Tzu', 'einstein'),
#  ('Doberman Pinscher', None),
#  ('German Shepherd Dog', 'charmer'),
#  ('Pembroke Welsh Corgi', None),
#  ('English Cocker Spaniel-Cocker Spaniel Mix', 'renaissance-dog'),
#  ('Rottweiler', None),
#  ('German Shepherd Dog', None),
#  ('Cavalier King Charles Spaniel-Bichon Frise Mix', None),
#  ('Shih Tzu', None),
#  ('Bedlington Terrier', 'protodog'),
#  ('Labrador Retriever', None),
#  ('Russell Terrier', None),
#  ('Poodle', 'charmer'),
#  ('Irish Setter', 'socialite'),
#  ('German Shepherd Dog', 'expert'),
#  ('Irish Setter', 'socialite'),
#  ('Poodle', 'protodog'),
#  ('Irish Red and White Setter', 'charmer'),
#  ('Poodle-Cocker Spaniel Mix', None),
#  ('American Pit Bull Terrier', None),
#  ('Golden Retriever', None),
#  ('Beagle-Schipperke Mix', None),
#  ('Greyhound', None),
#  ('Labrador Retriever-Golden Retriever Mix', None),
#  ('Labrador Retriever-Golden Retriever Mix', None),
#  ('Labrador Retriever', 'einstein'),
#  ('Boston Terrier-Chihuahua Mix', None),
#  ('American Pit Bull Terrier', 'socialite'),
#  ('Mixed', 'socialite'),
#  ('Beagle-Cavalier King Charles Spaniel Mix', 'ace'),
#  ('Boxer', None),
#  ('Pug', None),
#  ('French Bulldog', None),
#  ('Mixed', 'expert'),
#  ('Mixed', None),
#  ('Labradoodle', 'expert'),
#  ('Mixed', 'socialite'),
#  ('Pembroke Welsh Corgi', 'charmer'),
#  ('Golden Retriever', 'ace'),
#  ('Cocker Spaniel', 'protodog'),
#  ('Mixed', 'ace'),
#  ('Rottweiler', None),
#  ('Labrador Retriever-Border Collie Mix', None),
#  ('Lhasa Apso-Poodle Mix', None),
#  ('Labradoodle', None),
#  ('English Springer Spaniel', None),
#  ('English Springer Spaniel', None),
#  ('Mixed', None),
#  ('Shih Tzu', 'einstein'),
#  ('Neapolitan Mastiff', None),
#  ('Rat Terrier', None),
#  ('Border Terrier', 'socialite'),
#  ('Collie-Shetland Sheepdog Mix', 'charmer'),
#  ('German Shepherd Dog', 'socialite'),
#  ('Dachshund', 'protodog'),
#  ('Dachshund', 'protodog'),
#  ('Golden Retriever-Collie Mix', 'renaissance-dog'),
#  ('Beagle', 'charmer'),
#  ('Labrador Retriever', 'renaissance-dog'),
#  ('American Eskimo Dog-Papillon Mix', 'socialite'),
#  ('Papillon', 'stargazer'),
#  ('Pomeranian', None),
#  ('German Shepherd Dog-Belgian Tervuren Mix', None),
#  ('German Shepherd Dog', None),
#  ('Maltese-Yorkshire Terrier Mix', None),
#  ('Australian Shepherd', None),
#  ('Shiba Inu', None),
#  ('Rat Terrier', None),
#  ('Poodle', 'charmer'),
#  ('Border Collie-Greyhound Mix', None),
#  ('Poodle', 'socialite'),
#  ('Labradoodle', 'protodog'),
#  ('Mixed', 'ace'),
#  ('Maltese-Poodle Mix', None),
#  ('Siberian Husky-German Shepherd Dog Mix', None),
#  ('Chihuahua', None),
#  ('Golden Retriever-German Shepherd Dog Mix', 'ace'),
#  ('Parson Russell Terrier', 'charmer'),
#  ('Rhodesian Ridgeback', 'expert'),
#  ('Mixed', 'ace'),
#  ('Mixed', None),
#  ('Chihuahua', None),
#  ('West Highland White Terrier', 'protodog'),
#  ('Poodle-Miniature Schnauzer Mix', None),
#  ('Maltese-Poodle Mix', None),
#  ('Yorkshire Terrier-Poodle Mix', None),
#  ('Vizsla', 'socialite'),
#  ('Golden Retriever', None),
#  ('Labradoodle', None),
#  ('Silky Terrier-Poodle Mix', None),
#  ('Mixed', None),
#  ('Russell Terrier-Miniature Pinscher Mix', None),
#  ('Mixed', 'socialite'),
#  ('Bernese Mountain Dog', 'socialite'),
#  ('Bernese Mountain Dog', 'socialite'),
#  ('Bernese Mountain Dog', 'socialite'),
#  ('Yorkshire Terrier', 'protodog'),
#  ('Australian Cattle Dog- Mix', 'maverick'),
#  ('Mixed', None),
#  ('Flat-Coated Retriever', None),
#  ('Staffordshire Bull Terrier-Bulldog Mix', None),
#  ('Mixed', None),
#  ('Mixed', 'charmer'),
#  ('Kooikerhondje', 'maverick'),
#  ('German Shepherd Dog', 'socialite'),
#  ('Labrador Retriever-Golden Retriever Mix', 'charmer'),
#  ('German Shepherd Dog-Border Collie Mix', 'stargazer'),
#  ('Mixed', None),
#  ('Golden Retriever', 'socialite'),
#  ('Mixed', 'expert'),
#  ('German Shepherd Dog', 'maverick'),
#  ('Mixed', 'maverick'),
#  ('Labradoodle', 'expert'),
#  ('Shih Tzu', 'stargazer'),
#  ('American Staffordshire Terrier', None),
#  ('Bulldog', None),
#  ('Mixed', None),
#  ('Labrador Retriever', 'expert'),
#  ('Beagle', 'expert'),
#  ('Beagle', 'renaissance-dog'),
#  ('Cardigan Welsh Corgi-German Shepherd Dog Mix', None),
#  ('German Shepherd Dog', 'renaissance-dog'),
#  ('Doberman Pinscher', None),
#  ('Doberman Pinscher-German Shepherd Dog Mix', None),
#  ('Mixed', None),
#  ('Shetland Sheepdog', None),
#  ('Canaan Dog- Mix', 'charmer'),
#  ('Beagle', None),
#  ('Rhodesian Ridgeback', None),
#  ('Miniature Schnauzer', 'socialite'),
#  ('Russell Terrier-Pug Mix', None),
#  ('Mixed', None),
#  ('Australian Cattle Dog-Border Collie Mix', 'protodog'),
#  ('Mixed', None),
#  ('Shih Tzu', None),
#  ('Shih Tzu', 'stargazer'),
#  ('English Cocker Spaniel', None),
#  ('Australian Shepherd', None),
#  ('Parson Russell Terrier', None),
#  ('Boxer', None),
#  ('German Shepherd Dog', 'protodog'),
#  ('Chihuahua-Dachshund Mix', 'protodog'),
#  ('Australian Cattle Dog', None),
#  ('Border Collie-Australian Shepherd Mix', 'socialite'),
#  ('Shih Tzu', None),
#  ('Miniature Schnauzer', None),
#  ('Australian Shepherd-Border Collie Mix', 'protodog'),
#  ('Mixed', None),
#  ('Poodle', None),
#  ('Labrador Retriever', 'charmer'),
#  ('Mixed', None),
#  ('French Spaniel', 'charmer'),
#  ('Mixed', 'maverick'),
#  ('Italian Greyhound', 'socialite'),
#  ('Weimaraner', 'protodog'),
#  ('Leonberger', None),
#  ('Poodle', 'socialite'),
#  ('German Shepherd Dog', 'protodog'),
#  ('Mixed', 'charmer'),
#  ('Portuguese Water Dog', None),
#  ('Boykin Spaniel', None),
#  ('Mixed', 'einstein'),
#  ('Labrador Retriever', 'ace'),
#  ('Soft Coated Wheaten Terrier', None),
#  ('Poodle', None),
#  ('Mixed', 'charmer'),
#  ('Mixed', 'ace'),
#  ('German Shepherd Dog', 'socialite'),
#  ('Bulldog', None),
#  ('Golden Retriever', None),
#  ('Boston Terrier', 'ace'),
#  ('Shih Tzu', 'einstein'),
#  ('Brittany', 'protodog'),
#  ('Bernese Mountain Dog', None),
#  ('Golden Retriever-Labrador Retriever Mix', None),
#  ('Mixed', 'protodog'),
#  ('Golden Retriever-Labrador Retriever Mix', None),
#  ('Mixed', None),
#  ('Australian Cattle Dog', None),
#  ('Labrador Retriever-Chinese Shar-Pei Mix', 'charmer'),
#  ('Labrador Retriever', 'stargazer'),
#  ('Nova Scotia Duck Tolling Retriever', 'socialite'),
#  ('Nova Scotia Duck Tolling Retriever', 'renaissance-dog'),
#  ('Mixed', 'protodog'),
#  ('Labrador Retriever', 'expert'),
#  ('Labrador Retriever', 'expert'),
#  ('Australian Shepherd', 'socialite'),
#  ('Mixed', 'stargazer'),
#  ('Siberian Husky', None),
#  ('Mixed', None),
#  ('Mixed', None),
#  ('Lhasa Apso', 'ace'),
#  ('Australian Shepherd', None),
#  ('Mixed', 'ace'),
#  ('Mixed', 'ace'),
#  ('Mixed', None),
#  ('Labrador Retriever', 'protodog'),
#  ('Mixed', None),
#  ('American Eskimo Dog', 'renaissance-dog'),
#  ('Boxer', 'protodog'),
#  ('Keeshond', None),
#  ('Bull Terrier', None),
#  ('Soft Coated Wheaten Terrier', None),
#  ('Boston Terrier', None),
#  ('German Shepherd Dog', None),
#  ('Poodle', None),
#  ('German Shepherd Dog', None),
#  ('Shih Tzu-Maltese Mix', None),
#  ('Labrador Retriever', 'protodog'),
#  ('Chesapeake Bay Retriever', None),
#  ('Mixed', 'socialite'),
#  ('Shih Tzu', 'protodog'),
#  ('Cocker Spaniel', 'protodog'),
#  ('Labrador Retriever', 'stargazer'),
#  ('Maltese', None),
#  ('Mixed', 'maverick'),
#  ('Cockapoo', 'stargazer'),
#  ('Chihuahua-Miniature Pinscher Mix', None),
#  ('German Shepherd Dog', None),
#  ('Mixed', None),
#  ('Shih Tzu', None),
#  ('Shih Tzu', 'maverick'),
#  ('Australian Cattle Dog', 'expert'),
#  ('Maltese-Poodle Mix', None),
#  ('Maltese-Shih Tzu Mix', None),
#  ('Mixed', None),
#  ('Boxer', 'ace'),
#  ('Dachshund-Miniature Pinscher Mix', None),
#  ('Mixed', 'maverick'),
#  ('Miniature American Shepherd', None),
#  ('Mixed', 'expert'),
#  ('Mixed', None),
#  ('Golden Retriever', 'protodog'),
#  ('Parson Russell Terrier', 'protodog'),
#  ('Border Collie', None),
#  ('German Shepherd Dog', 'maverick'),
#  ('Labrador Retriever-Australian Cattle Dog Mix', 'expert'),
#  ('Poodle', None),
#  ('Shih Tzu', 'protodog'),
#  ('Shih Tzu', None),
#  ('Mixed', None),
#  ('Mixed', 'socialite'),
#  ("I Don't Know", 'einstein'),
#  ('Border Collie', None),
#  ('Golden Retriever', 'socialite'),
#  ('Mixed', 'protodog'),
#  ('Mixed', 'protodog'),
#  ('Chihuahua', 'renaissance-dog'),
#  ('Australian Shepherd', 'charmer'),
#  ('Poodle', None),
#  ('Affenpinscher', None),
#  ('Keeshond', None),
#  ('Chihuahua', 'charmer'),
#  ('English Setter', None),
#  ('Miniature Schnauzer-Poodle Mix', 'socialite'),
#  ('Mixed', None),
#  ('Havanese', 'protodog'),
#  ('German Shepherd Dog', None),
#  ('Australian Shepherd', 'renaissance-dog'),
#  ('Mixed', None),
#  ('Border Collie', None),
#  ('Boxer', 'stargazer'),
#  ('Labrador Retriever-Cane Corso Mix', 'protodog'),
#  ('Labrador Retriever', None),
#  ('Miniature Schnauzer', None),
#  ('Mixed', 'socialite'),
#  ('Mixed', 'einstein'),
#  ('Bichon Frise-Shih Tzu Mix', 'maverick'),
#  ('Pug', 'socialite'),
#  ('Pointer-Labrador Retriever Mix', 'charmer'),
#  ('Labrador Retriever-Basenji Mix', 'socialite'),
#  ('Poodle', None),
#  ('Golden Retriever', 'renaissance-dog'),
#  ('Australian Cattle Dog', None),
#  ('German Shepherd Dog', 'ace'),
#  ('Mixed', None),
#  ('Golden Doodle', None),
#  ('Pembroke Welsh Corgi-Russell Terrier Mix', 'einstein'),
#  ('Mixed', None),
#  ('Mixed', 'socialite'),
#  ('Labrador Retriever', 'charmer'),
#  ('Border Collie-Labrador Retriever Mix', 'expert'),
#  ('Mixed', None),
#  ('Bulldog-Beagle Mix', None),
#  ('Border Collie', None),
#  ('Bulldog', 'ace'),
#  ('Mixed', 'maverick'),
#  ('Nova Scotia Duck Tolling Retriever', 'socialite'),
#  ('Mixed', None),
#  ('Australian Shepherd', None),
#  ('English Cocker Spaniel', None),
#  ('Golden Retriever', 'ace'),
#  ('Poodle-Maltese Mix', 'renaissance-dog'),
#  ('Great Dane-Labrador Retriever Mix', 'maverick'),
#  ('Mixed', 'protodog'),
#  ('Golden Retriever', 'ace'),
#  ('Boxer', None),
#  ('Bernese Mountain Dog', 'stargazer'),
#  ('Havanese', None),
#  ('Mixed', None),
#  ('Boxer', None),
#  ('Mixed', None),
#  ('Brittany-Poodle Mix', 'socialite'),
#  ('Shih Tzu', 'stargazer'),
#  ('Mixed', 'protodog'),
#  ('Scottish Terrier', 'ace'),
#  ('Mixed', 'expert'),
#  ('Mixed', 'socialite'),
#  ('Weimaraner', None),
#  ('Shih Tzu', None),
#  ('Weimaraner', 'expert'),
#  ('Mixed', None),
#  ('West Highland White Terrier', None),
#  ('Labradoodle', 'socialite'),
#  ('Labrador Retriever', None),
#  ('Mixed', None),
#  ('Beagle', 'renaissance-dog'),
#  ('Labrador Retriever-Cardigan Welsh Corgi Mix', 'ace'),
#  ('Mixed', None),
#  ('Mixed', 'charmer'),
#  ('Mixed', None),
#  ('Bearded Collie-Tibetan Terrier Mix', None),
#  ('Shih Tzu', None),
#  ('Australian Shepherd', None),
#  ('Beagle', 'charmer'),
#  ('Beagle', 'stargazer'),
#  ('German Shepherd Dog', None),
#  ("I Don't Know", None),
#  ('Mixed', None),
#  ('Miniature American Shepherd', 'socialite'),
#  ('Great Dane', 'charmer'),
#  ('Golden Retriever', None),
#  ('Golden Retriever-Labrador Retriever Mix', None),
#  ('Labrador Retriever', None),
#  ('Mixed', 'renaissance-dog'),
#  ('Icelandic Sheepdog', None),
#  ('Golden Retriever', 'renaissance-dog'),
#  ('Dachshund', 'renaissance-dog'),
#  ('German Shorthaired Pointer-Labrador Retriever Mix', 'renaissance-dog'),
#  ('Miniature Schnauzer', None),
#  ('Miniature Schnauzer', 'expert'),
#  ('Pug-Chihuahua Mix', None),
#  ('Cockapoo', 'renaissance-dog'),
#  ('Mixed', None),
#  ('Weimaraner', None),
#  ('Yorkshire Terrier-Bichon Frise Mix', None),
#  ('Cockapoo', None),
#  ('Border Collie', None),
#  ('Golden Retriever', 'protodog'),
#  ('Cairn Terrier', None),
#  ('Yorkshire Terrier- Mix', None),
#  ('German Shepherd Dog', None),
#  ('Belgian Sheepdog- Mix', None),
#  ('Australian Cattle Dog-Border Collie Mix', 'stargazer'),
#  ('Old English Sheepdog', None),
#  ('West Highland White Terrier', 'protodog'),
#  ('Golden Retriever', None),
#  ('Mixed', 'charmer'),
#  ('Mixed', 'charmer'),
#  ('Miniature Schnauzer', None),
#  ('Mixed', 'expert'),
#  ('Boston Terrier', None),
#  ('Portuguese Water Dog', None),
#  ('American Pit Bull Terrier-American Staffordshire Terrier Mix', None),
#  ('American Pit Bull Terrier-American Staffordshire Terrier Mix', None),
#  ('Labrador Retriever', None),
#  ('Golden Retriever', None),
#  ('Golden Retriever', None),
#  ('Danish-Swedish Farmdog', None),
#  ('Golden Retriever', 'charmer'),
#  ('Labrador Retriever', None),
#  ('Mixed', None),
#  ('Cardigan Welsh Corgi', None),
#  ('Bernese Mountain Dog', None),
#  ('Boxer', None),
#  ('Boxer', None),
#  ('Poodle', None),
#  ('Mixed', None),
#  ('Labradoodle', 'renaissance-dog'),
#  ('Mixed', 'stargazer'),
#  ('Labradoodle', 'protodog'),
#  ('Mixed', None),
#  ('Shetland Sheepdog', 'charmer'),
#  ('Shetland Sheepdog', 'protodog'),
#  ('Cavalier King Charles Spaniel', 'renaissance-dog'),
#  ('Beagle', 'expert'),
#  ('Bichon Frise-Cavalier King Charles Spaniel Mix', 'ace'),
#  ('Golden Doodle', None),
#  ('Labrador Retriever', None),
#  ('French Bulldog', 'socialite'),
#  ('Cockapoo', None),
#  ('Rhodesian Ridgeback-Boxer Mix', 'maverick'),
#  ('Mixed', 'stargazer'),
#  ('Poodle-Cavalier King Charles Spaniel Mix', 'socialite'),
#  ('Poodle-Cavalier King Charles Spaniel Mix', 'maverick'),
#  ('Mixed', 'protodog'),
#  ('Beagle-Australian Cattle Dog Mix', None),
#  ('Mixed', 'protodog'),
#  ('Mixed', None),
#  ('Shetland Sheepdog', None),
#  ('Labrador Retriever-Rottweiler Mix', None),
#  ('Pomeranian', 'socialite'),
#  ('Poodle', None),
#  ('Mixed', None),
#  ('Yorkshire Terrier', None),
#  ('Shih Tzu', None),
#  ('Mixed', None),
#  ('Border Collie', 'renaissance-dog'),
#  ('Mixed', None),
#  ('Dalmatian', 'protodog'),
#  ('Chow Chow-Golden Retriever Mix', None),
#  ('German Shepherd Dog-Beagle Mix', 'protodog'),
#  ('Siberian Husky', 'protodog'),
#  ('Other', None),
#  ('American Staffordshire Terrier-Labrador Retriever Mix', None),
#  ('Yorkshire Terrier', None),
#  ('Cockapoo', None),
#  ('Affenpinscher', 'stargazer'),
#  ('Maltese', 'ace'),
#  ('Mixed', None),
#  ('Border Terrier- Mix', None),
#  ('Scottish Terrier', 'protodog'),
#  ('English Setter', None),
#  ('Labrador Retriever', 'renaissance-dog'),
#  ('Mixed', 'expert'),
#  ('Mixed', None),
#  ('Other', 'ace'),
#  ('Havanese', None),
#  ('Havanese', None),
#  ('Havanese', None),
#  ('Border Terrier', 'socialite'),
#  ('Border Terrier', 'protodog'),
#  ('Border Terrier', 'socialite'),
#  ('Australian Shepherd', 'protodog'),
#  ('Bulldog', None),
#  ('Coton de Tulear', None),
#  ('Cardigan Welsh Corgi', 'ace'),
#  ('Mixed', None),
#  ('Mixed', None),
#  ('Russell Terrier', None),
#  ('Greyhound', 'maverick'),
#  ('American Water Spaniel', 'ace'),
#  ('Mixed', 'protodog'),
#  ('German Shepherd Dog', 'expert'),
#  ('Russell Terrier-Chihuahua Mix', None),
#  ('Labrador Retriever', None),
#  ('Poodle', 'protodog'),
#  ('Cavalier King Charles Spaniel', 'renaissance-dog'),
#  ('Mastiff', 'maverick'),
#  ('Cavalier King Charles Spaniel', 'stargazer'),
#  ('Mixed', 'ace'),
#  ("I Don't Know", None),
#  ('Shiba Inu', 'ace'),
#  ('Golden Retriever', None),
#  ('Mixed', None),
#  ('Mixed', None),
#  ('Border Collie', 'renaissance-dog'),
#  ('Beagle', 'charmer'),
#  ('Mixed', None),
#  ('German Shepherd Dog', 'ace'),
#  ('Miniature Schnauzer', None),
#  ('Labradoodle', None),
#  ('Australian Shepherd-Golden Retriever Mix', None),
#  ('German Shorthaired Pointer', None),
#  ('German Shorthaired Pointer', None),
#  ('German Shorthaired Pointer', None),
#  ('German Shorthaired Pointer', None),
#  ('Border Collie-Belgian Tervuren Mix', None),
#  ('American Staffordshire Terrier-Australian Shepherd Mix', 'renaissance-dog'),
#  ('Pekingese-Dachshund Mix', None),
#  ('German Shepherd Dog-Siberian Husky Mix', 'maverick'),
#  ('Golden Doodle', 'stargazer'),
#  ('Rat Terrier', None),
#  ('Chihuahua', None),
#  ('Portuguese Water Dog', 'protodog'),
#  ('Rottweiler- Mix', None),
#  ('Mixed', 'expert'),
#  ('Labrador Retriever', 'stargazer'),
#  ('Labrador Retriever', 'stargazer'),
#  ('Labrador Retriever', 'protodog'),
#  ('Pug-Maltese Mix', 'protodog'),
#  ('Boston Terrier', 'socialite'),
#  ('Boston Terrier', 'protodog'),
#  ('Labradoodle', 'socialite'),
#  ('Border Collie', 'maverick'),
#  ('Cairn Terrier', None),
#  ('Mixed', 'expert'),
#  ('Shih Tzu', None),
#  ('English Springer Spaniel', 'socialite'),
#  ('Mixed', None),
#  ('Maltese', 'socialite'),
#  ('Golden Retriever', 'stargazer'),
#  ('Mixed', None),
#  ('Golden Retriever', 'socialite'),
#  ('Siberian Husky-Australian Shepherd Mix', 'stargazer'),
#  ('Australian Cattle Dog', None),
#  ('Chihuahua', None),
#  ('Whippet', 'stargazer'),
#  ('West Highland White Terrier', None),
#  ('Boston Terrier-Bulldog Mix', 'stargazer'),
#  ('Mixed', None),
#  ('Mixed', None),
#  ('Mixed', 'maverick'),
#  ('Mixed', None),
#  ('Portuguese Water Dog', 'renaissance-dog'),
#  ('Border Collie-Dalmatian Mix', None),
#  ('Other', 'stargazer'),
#  ('Cocker Spaniel', 'charmer'),
#  ('Welsh Springer Spaniel', 'protodog'),
#  ('Poodle-Old English Sheepdog Mix', None),
#  ('Mixed', 'protodog'),
#  ('Golden Retriever', None),
#  ('Mixed', None),
#  ('Mixed', 'einstein'),
#  ('German Shepherd Dog', 'expert'),
#  ('Mixed', None),
#  ('Labrador Retriever', 'ace'),
#  ('Labrador Retriever', None),
#  ('German Shepherd Dog', 'renaissance-dog'),
#  ('Labradoodle', 'protodog'),
#  ('Labrador Retriever', 'socialite'),
#  ('Mixed', 'protodog'),
#  ('Border Terrier', None),
#  ('Golden Retriever', None),
#  ('Golden Retriever', 'charmer'),
#  ('Staffordshire Bull Terrier', 'protodog'),
#  ('Australian Shepherd', None),
#  ('Havanese', None),
#  ('Labrador Retriever', None),
#  ('Soft Coated Wheaten Terrier', None),
#  ('Mixed', None),
#  ('Golden Retriever', 'socialite'),
#  ('Mixed', 'ace'),
#  ('Mixed', None),
#  ('Poodle', 'charmer'),
#  ('Poodle', 'charmer'),
#  ('Shih Tzu', None),
#  ('Border Collie', 'socialite'),
#  ('Border Collie-Staffordshire Bull Terrier Mix', 'protodog'),
#  ('Siberian Husky', 'protodog'),
#  ('German Shepherd Dog', 'charmer'),
#  ('Shih Tzu', 'maverick'),
#  ('Mixed', None),
#  ('English Springer Spaniel', None),
#  ('Australian Cattle Dog- Mix', None),
#  ('Boxer', None),
#  ('Other', 'protodog'),
#  ("I Don't Know", None),
#  ('Golden Doodle', 'charmer'),
#  ('Bichon Frise-Poodle Mix', 'expert'),
#  ('Mixed', None),
#  ('Shetland Sheepdog', 'charmer'),
#  ('Shetland Sheepdog', None),
#  ('Golden Retriever', None),
#  ('Mixed', None),
#  ('Labrador Retriever', 'charmer'),
#  ('German Shorthaired Pointer-Catahoula Leopard Dog Mix', None),
#  ('Mixed', None),
#  ('Alaskan Malamute-Collie Mix', 'ace'),
#  ('Mixed', None),
#  ('Doberman Pinscher', None),
#  ('Collie', None),
#  ('Boxer', 'renaissance-dog'),
#  ('Weimaraner', 'ace'),
#  ('Boxer', None),
#  ('Labrador Retriever', 'socialite'),
#  ('Poodle', 'renaissance-dog'),
#  ('Mixed', 'protodog'),
#  ('Coton de Tulear', 'stargazer'),
#  ('Shih Tzu', 'stargazer'),
#  ('Shih Tzu', 'ace'),
#  ('Golden Retriever-Newfoundland Mix', None),
#  ('Shih Tzu', 'socialite'),
#  ('Shetland Sheepdog', None),
#  ('Mixed', None),
#  ('Border Collie', 'protodog'),
#  ('Mixed', None),
#  ('Border Collie', None),
#  ('Shih Tzu', None),
#  ('American Staffordshire Terrier', None),
#  ('Shih Tzu', 'renaissance-dog'),
#  ('Mixed', 'maverick'),
#  ('Other', 'protodog'),
#  ('Greyhound', None),
#  ('Cavalier King Charles Spaniel', 'stargazer'),
#  ('Border Collie', None),
#  ('Mixed', 'socialite'),
#  ('Mixed', 'maverick'),
#  ('Boxer-American Staffordshire Terrier Mix', None),
#  ('Miniature Schnauzer', 'renaissance-dog'),
#  ('Cavalier King Charles Spaniel-Poodle Mix', 'socialite'),
#  ('Other', 'maverick'),
#  ('Shih Tzu', 'maverick'),
#  ('Boston Terrier', None),
#  ('Poodle', None),
#  ('German Shepherd Dog', None),
#  ('Norfolk Terrier', None),
#  ('Norfolk Terrier', None),
#  ('Labrador Retriever', 'socialite'),
#  ('Labrador Retriever-Rottweiler Mix', 'socialite'),
#  ('Mixed', None),
#  ('Nova Scotia Duck Tolling Retriever', 'socialite'),
#  ('German Shepherd Dog', None),
#  ('Australian Shepherd', None),
#  ('Greyhound', 'maverick'),
#  ('Staffordshire Bull Terrier-Great Dane Mix', None),
#  ('Mixed', 'protodog'),
#  ('Wire Fox Terrier', None),
#  ('Golden Retriever', None),
#  ('French Spaniel', None),
#  ('Samoyed', None),
#  ('Coton de Tulear', 'renaissance-dog'),
#  ('Mixed', None),
#  ('Labrador Retriever', None),
#  ('Poodle-Maltese Mix', None),
#  ('German Shepherd Dog', 'ace'),
#  ('Golden Retriever', 'expert'),
#  ('Border Collie', 'ace'),
#  ('Maltese-Yorkshire Terrier Mix', None),
#  ('Cockapoo', 'renaissance-dog'),
#  ('Collie', None),
#  ('Labrador Retriever-German Shepherd Dog Mix', 'protodog'),
#  ("I Don't Know", 'charmer'),
#  ('Border Collie', None),
#  ('Mixed', None),
#  ('Pekingese-Shih Tzu Mix', None),
#  ('Mixed', None),
#  ('Siberian Husky', 'renaissance-dog'),
#  ('Shih Tzu', 'stargazer'),
#  ('Rhodesian Ridgeback', None),
#  ('Mixed', None),
#  ('Dalmatian', None),
#  ('Dalmatian', None),
#  ('Labrador Retriever', None),
#  ('Staffordshire Bull Terrier-Miniature Schnauzer Mix', None),
#  ('Cocker Spaniel', 'socialite'),
#  ('Mixed', None),
#  ('Greyhound', None),
#  ('Shetland Sheepdog', None),
#  ('Poodle', None),
#  ('Puggle', 'charmer'),
#  ('Mixed', None),
#  ('Cockapoo', None),
#  ('Beagle- Mix', 'maverick'),
#  ('Rhodesian Ridgeback', None),
#  ('Havanese', 'socialite'),
#  ('Golden Retriever', 'renaissance-dog'),
#  ('Mixed', None),
#  ('Shih Tzu', None),
#  ('Shih Tzu', 'socialite'),
#  ('Mixed', None),
#  ('Shih Tzu', None),
#  ('Havanese', 'expert'),
#  ('Yorkshire Terrier', 'protodog'),
#  ('Dalmatian', 'charmer'),
#  ('Dalmatian', 'renaissance-dog'),
#  ('Belgian Malinois', 'maverick'),
#  ('Mixed', 'stargazer'),
#  ('Rhodesian Ridgeback', None),
#  ('Labradoodle', 'socialite'),
#  ('Australian Shepherd', 'protodog'),
#  ('Australian Shepherd', None),
#  ('Dalmatian', 'socialite'),
#  ('Portuguese Water Dog', 'renaissance-dog'),
#  ('Australian Shepherd-Australian Cattle Dog Mix', None),
#  ("I Don't Know", None),
#  ('French Bulldog', None),
#  ('Boston Terrier', None),
#  ('Labrador Retriever', 'ace'),
#  ('Mixed', None),
#  ('Mixed', None),
#  ('Pomeranian', 'protodog'),
#  ('Whippet', None),
#  ('Golden Doodle', 'protodog'),
#  ('Border Collie', None),
#  ('Border Collie', None),
#  ('Border Collie', None),
#  ('Poodle-Labrador Retriever Mix', 'charmer'),
#  ('Pug-Wire Fox Terrier Mix', None),
#  ('Greyhound', None),
#  ('Pug-Wire Fox Terrier Mix', None),
#  ('Pug-Smooth Fox Terrier Mix', None),
#  ('Pembroke Welsh Corgi', 'maverick'),
#  ('Australian Shepherd', 'einstein'),
#  ('German Shepherd Dog', None),
#  ('Mixed', None),
#  ('Shih Tzu', 'stargazer'),
#  ('Wire Fox Terrier', None),
#  ('Mixed', 'socialite'),
#  ('Labrador Retriever', 'einstein'),
#  ('Bearded Collie-Beagle Mix', 'protodog'),
#  ('Golden Retriever', 'socialite'),
#  ('Border Collie-Australian Cattle Dog Mix', 'maverick'),
#  ('Mixed', 'stargazer'),
#  ('Great Dane', 'charmer'),
#  ('Brussels Griffon', None),
#  ('Poodle', None),
#  ('Irish Setter', 'stargazer'),
#  ('Poodle', 'maverick'),
#  ('Labrador Retriever', None),
#  ('Mixed', None),
#  ('Puggle', 'charmer'),
#  ('Shih Tzu', 'expert'),
#  ('Nova Scotia Duck Tolling Retriever', None),
#  ('Poodle-Dachshund Mix', None),
#  ('German Shepherd Dog', None),
#  ('Golden Retriever', 'renaissance-dog'),
#  ('Mixed', 'stargazer'),
#  ('Golden Retriever', 'protodog'),
#  ('Cocker Spaniel', None),
#  ('Miniature Schnauzer', 'renaissance-dog'),
#  ('Shetland Sheepdog', 'protodog'),
#  ('Shetland Sheepdog', 'charmer'),
#  ('Mixed', 'charmer'),
#  ('Pug-Chihuahua Mix', 'ace'),
#  ('Mixed', None),
#  ('Coton de Tulear', None),
#  ('Golden Retriever', None),
#  ('Golden Retriever', None),
#  ('Papillon', None),
#  ('Mastiff', 'protodog'),
#  ('Shih Tzu', 'einstein'),
#  ('Polish Lowland Sheepdog', 'protodog'),
#  ('Miniature Pinscher', None),
#  ('English Springer Spaniel', 'ace'),
#  ("I Don't Know", 'socialite'),
#  ('American Eskimo Dog', None),
#  ('German Shepherd Dog', 'socialite'),
#  ('Soft Coated Wheaten Terrier', None),
#  ('Mixed', 'renaissance-dog'),
#  ('Chinese Crested-Poodle Mix', 'renaissance-dog'),
#  ('Labrador Retriever', 'ace'),
#  ('Golden Retriever', 'stargazer'),
#  ('American Pit Bull Terrier-Australian Cattle Dog Mix', 'socialite'),
#  ('Shih Tzu', 'ace'),
#  ('Catahoula Leopard Dog-Rottweiler Mix', 'maverick'),
#  ('Shih Tzu', 'renaissance-dog'),
#  ('Belgian Tervuren', 'charmer'),
#  ('Belgian Tervuren', 'protodog'),
#  ('Greyhound', None),
#  ('Nova Scotia Duck Tolling Retriever', None),
#  ('Mixed', 'expert'),
#  ('Australian Shepherd-Border Collie Mix', None),
#  ('Bernese Mountain Dog', None),
#  ('West Highland White Terrier', 'stargazer'),
#  ('Poodle-Shih Tzu Mix', None),
#  ('Boxer-Border Collie Mix', None),
#  ('Shih Tzu', 'stargazer'),
#  ('Other', None),
#  ('Cavalier King Charles Spaniel', None),
#  ('Mixed', None),
#  ('Border Collie', 'ace'),
#  ("I Don't Know", None),
#  ('Golden Retriever', None),
#  ('Great Dane-Irish Wolfhound Mix', None),
#  ('Pyrenean Shepherd', None),
#  ('Pyrenean Shepherd', None),
#  ('Labrador Retriever', 'charmer'),
#  ('Golden Retriever', 'ace'),
#  ('German Shepherd Dog', 'charmer'),
#  ('Other', 'renaissance-dog'),
#  ('Chinese Shar-Pei', 'protodog'),
#  ('Mastiff', 'charmer'),
#  ('French Bulldog', None),
#  ('Australian Shepherd', 'protodog'),
#  ('Australian Shepherd', 'stargazer'),
#  ('Australian Shepherd', 'einstein'),
#  ('Dachshund', None),
#  ("I Don't Know", 'maverick'),
#  ('Golden Retriever', 'socialite'),
#  ('Maltese', 'protodog'),
#  ('Mixed', 'renaissance-dog'),
#  ('Mixed', 'renaissance-dog'),
#  ('Cavalier King Charles Spaniel', None),
#  ('Labradoodle', 'renaissance-dog'),
#  ('Labradoodle', 'einstein'),
#  ('Border Collie', None),
#  ('Lhasa Apso', 'protodog'),
#  ('Greyhound', None),
#  ('Mixed', 'stargazer'),
#  ('Shih Tzu', 'stargazer'),
#  ('Dogue de Bordeaux-Boxer Mix', 'socialite'),
#  ('Golden Doodle', 'socialite'),
#  ('Belgian Malinois', None),
#  ('Greyhound', 'stargazer'),
#  ('Belgian Malinois', 'protodog'),
#  ('Akita', None),
#  ('Golden Retriever', 'socialite'),
#  ('Mixed', None),
#  ('Labrador Retriever', 'socialite'),
#  ('Golden Retriever', 'maverick'),
#  ('Golden Retriever', None),
#  ('Australian Shepherd', None),
#  ('Bulldog', 'renaissance-dog'),
#  ('Golden Doodle', 'renaissance-dog'),
#  ('American Staffordshire Terrier-Catahoula Leopard Dog Mix', None),
#  ('Mixed', None),
#  ('Golden Retriever', None),
#  ('German Shepherd Dog', None),
#  ('Scottish Terrier', None),
#  ('Bulldog', None),
#  ('Shih Tzu-Pekingese Mix', None),
#  ('Labrador Retriever', 'maverick'),
#  ('Rat Terrier', None),
#  ('Border Terrier', None),
#  ('Poodle', None),
#  ('Labrador Retriever', None),
#  ('Boxer', None),
#  ('Beagle-Labrador Retriever Mix', None),
#  ('Australian Shepherd', None),
#  ('Golden Retriever', None),
#  ('Dachshund-Beagle Mix', None),
#  ('Silky Terrier', None),
#  ('Shetland Sheepdog', None),
#  ('Mixed', 'stargazer'),
#  ('Golden Doodle', None),
#  ('Scottish Terrier', None),
#  ('-German Shepherd Dog Mix', 'ace'),
#  ('Boxer', None),
#  ('Labrador Retriever', None),
#  ('Keeshond', None),
#  ('Mixed', None),
#  ('Mixed', None),
#  ('German Shorthaired Pointer', None),
#  ('Coton de Tulear', 'renaissance-dog'),
#  ('Golden Retriever', None),
#  ('Mixed', None),
#  ('Belgian Malinois', None),
#  ('Chihuahua', 'renaissance-dog'),
#  ('Poodle', None),
#  ('American Pit Bull Terrier', 'charmer'),
#  ('Bernese Mountain Dog', None),
#  ('Golden Retriever', 'protodog'),
#  ('Mixed', None),
#  ('Mixed', None),
#  ('German Shepherd Dog-Chow Chow Mix', None),
#  ('Labrador Retriever-Golden Retriever Mix', 'einstein'),
#  ('Weimaraner', None),
#  ('Mixed', None),
#  ('German Shepherd Dog', None),
#  ('Border Collie-Australian Shepherd Mix', None),
#  ('Labrador Retriever- Mix', None),
#  ('Border Collie', None),
#  ('Labrador Retriever', 'socialite'),
#  ('Mixed', None),
#  ('Beagle-Australian Cattle Dog Mix', None),
#  ('Mixed', None),
#  ('Pembroke Welsh Corgi-Great Pyrenees Mix', None),
#  ('Mixed', None),
#  ('Golden Retriever', None),
#  ('Golden Retriever', None),
#  ('Mixed', None),
#  ('German Shepherd Dog', 'socialite'),
#  ('Australian Shepherd-Pembroke Welsh Corgi Mix', 'charmer'),
#  ('Mixed', 'stargazer'),
#  ('German Shepherd Dog', 'stargazer'),
#  ('Labrador Retriever', 'socialite'),
#  ('Cavalier King Charles Spaniel', None),
#  ('Australian Shepherd', None),
#  ('French Bulldog', None),
#  ('Labrador Retriever', None),
#  ('Golden Doodle', 'renaissance-dog'),
#  ('Chesapeake Bay Retriever', 'expert'),
#  ('Poodle', None),
#  ('Golden Doodle', None),
#  ('Labrador Retriever', 'socialite'),
#  ('Maltese-Poodle Mix', None),
#  ('Labrador Retriever', None),
#  ('Labradoodle', 'protodog'),
#  ('Cavalier King Charles Spaniel', None),
#  ('Mixed', None),
#  ('Mixed', None),
#  ('Dachshund', None),
#  ('Havanese', None),
#  ('Mixed', None),
#  ('Labrador Retriever', None),
#  ('Boxer', None),
#  ('Mixed', None),
#  ('Boxer', None),
#  ('German Shepherd Dog', 'charmer'),
#  ('Border Collie', None),
#  ('Mixed', None),
#  ('Australian Shepherd', None),
#  ('Afghan Hound-Golden Retriever Mix', 'socialite'),
#  ('Mixed', None),
#  ('Dachshund', None),
#  ('Shorkie', None),
#  ('Field Spaniel', 'socialite'),
#  ('Mixed', None),
#  ('Cavalier King Charles Spaniel', None),
#  ('Poodle', None),
#  ('Chihuahua-American Staffordshire Terrier Mix', 'ace'),
#  ('Newfoundland', None),
#  ('Mixed', 'renaissance-dog'),
#  ('Yorkshire Terrier', None),
#  ('Australian Cattle Dog', None),
#  ('Other', None),
#  ('English Cocker Spaniel', 'renaissance-dog'),
#  ('Boxer', 'charmer'),
#  ('Portuguese Water Dog', 'charmer'),
#  ('Labradoodle', None),
#  ('Mixed', None),
#  ('Pug', 'protodog'),
#  ('Bluetick Coonhound', 'renaissance-dog'),
#  ('Pug-Miniature Pinscher Mix', 'socialite'),
#  ('Shetland Sheepdog', None),
#  ('Whippet-Chinese Shar-Pei Mix', None),
#  ('German Shepherd Dog', 'socialite'),
#  ('German Shepherd Dog', 'stargazer'),
#  ('Boxer-Bulldog Mix', None),
#  ('Portuguese Water Dog', 'socialite'),
#  ('Other', 'ace'),
#  ('Portuguese Water Dog', None),
#  ('Portuguese Water Dog', None),
#  ('Portuguese Water Dog', None),
#  ('Golden Retriever', 'protodog'),
#  ('Labrador Retriever', None),
#  ('Labradoodle', None),
#  ('Papillon', None),
#  ('Poodle', None),
#  ('Mixed', None),
#  ('Poodle', None),
#  ('Portuguese Water Dog', 'socialite'),
#  ('Vizsla- Mix', 'ace'),
#  ('Boxer', None),
#  ('Chow Chow-Labrador Retriever Mix', None),
#  ('Rat Terrier', None),
#  ('Rhodesian Ridgeback-Boxer Mix', None),
#  ('Labrador Retriever', None),
#  ('Mixed', None),
#  ('Border Collie-Whippet Mix', None),
#  ('Mixed', None),
#  ('Russell Terrier', None),
#  ('Other', None),
#  ('Belgian Malinois', None),
#  ('German Shepherd Dog', None),
#  ('Border Collie-Pembroke Welsh Corgi Mix', None),
#  ('Mixed', None),
#  ('Pug', None),
#  ...]

# %% [markdown]
# When you do so, you will see a line at the top of the output panel that says "35050 rows affected".  This means that there are 35050 rows of data in the dogs table.  Each row of the output lists the name of the breed of the dog represented by that entry.  Notice that some breed names are listed multiple times, because several dogs of that breed have participated in the Dognition tests.
#
# If you scroll all the way down to the bottom of the output, you will see a notification that says "35050 rows, truncated to displaylimit of 1000."  We have set up a display limit of 1000 rows in these notebooks to ensure that our database servers are not overloaded, and to reduce the amount of time you have to wait for the query output. However, in a actual scenario these limits would not necessarily be in place for you.  Therefore, before we go any further, I want to show you how you could restrict the number of rows outputted by a query.
#
# ![Alt text](https://duke.box.com/shared/static/dm85qcbpdsza8tc7be8x7tc6x6tr2xjq.jpg)
#
#
#
# ## Using LIMIT to restrict the number of rows in your output (and prevent system crashes)
#
# The MySQL clause you should use is called LIMIT, and it is always placed at the very end of your query.  The simplest version of a limit statement looks like this:
#
# ```mySQL
# SELECT breed
# FROM dogs LIMIT 5;
# ```
#
# The "5" in this case indicates that you will only see the first 5 rows of data you select.
#
# **Question 7: In the next cell, try entering a query that will let you see the first 10 rows of the breed column in the dogs table.**

# %%
# %%sql
# SELECT breed, dimension
# FROM dogs
# LIMIT 10
# Out:
# 10 rows affected.
# [('Labrador Retriever', 'charmer'),
#  ('Shetland Sheepdog', 'protodog'),
#  ('Golden Retriever', None),
#  ('Golden Retriever', None),
#  ('Shih Tzu', 'einstein'),
#  ('Siberian Husky', 'stargazer'),
#  ('Shih Tzu', 'maverick'),
#  ('Mixed', 'protodog'),
#  ('Labrador Retriever', 'einstein'),
#  ('Shih Tzu-Poodle Mix', 'socialite')]

# %% [markdown]
# You can also select rows of data from different parts of the output table, rather than always just starting at the beginning.  To do this, use the OFFSET clause after LIMIT. The number after the OFFSET clause indicates from which row the output will begin querying.  Note that the offset of Row 1 of a table is actually 0.  Therefore, in the following query:
#
# ```mySQL
# SELECT breed
# FROM dogs LIMIT 10 OFFSET 5;
# ```
#
# 10 rows of data will be returned, starting at Row 6.
#
# An alternative way to write the OFFSET clause in the query is:
#
# ```mySQL
# SELECT breed
# FROM dogs LIMIT 5, 10;
# ```
#
# In this notation, the offset is the number before the comma, and the number of rows returned is the number after the comma.
#
# **Try it yourself:**

# %%
# %%sql
# SELECT breed, dimension
# FROM dogs
# LIMIT 10
# OFFSET 10
# Out:
# 10 rows affected.
# [('German Shepherd Dog-Pembroke Welsh Corgi Mix', None),
#  ('Vizsla', 'socialite'),
#  ('Pug', 'stargazer'),
#  ('Boxer', 'ace'),
#  ('German Shepherd Dog-Nova Scotia Duck Tolling Retriever Mix', None),
#  ('Beagle', 'protodog'),
#  ('Beagle', 'expert'),
#  ('Beagle', None),
#  ('Mixed', None),
#  ('Chesapeake Bay Retriever', 'charmer')]

# %% [markdown]
# The LIMIT command is one of the pieces of syntax that can vary across database platforms.  MySQL uses LIMIT to restrict the output, but other databases including Teradata use a statement called "TOP" instead.  Oracle has yet another syntax:
#
# http://www.tutorialspoint.com/sql/sql-top-clause.htm
#
# Make sure to look up the correct syntax for the database type you are using.
#
#
# ## Using SELECT to query multiple columns
#
# Now that we know how to limit our output, we are ready to make our SELECT statement work a little harder.  The SELECT statement can be used to select multiple columns as well as a single column.  The output of the query will depend on the order of the columns you enter after the SELECT statement in your query.  <mark> When you enter column names, separate each name with a comma, but do NOT include a comma after the last column name. </mark>
#
# **Try the following query with different orders of the column names to observe the differences in output (I will include a LIMIT statement in many of the examples I use in the rest of the course, but feel free to change or remove them to explore different aspects of the data):**
#
# ```mySQL
# SELECT breed, breed_type, breed_group
# FROM dogs LIMIT 5, 10;
# ```

# %% [markdown]
# Another trick to know about when using SELECT is that <mark> you can use an asterisk as a "wild card" to return all the data in a table.</mark>  (A wild card is defined as a character that will represent or match any character or sequence of characters in a query.) <mark> Take note, this is very risky to do if you do not limit your output or if you don't know how many data are in your database, so use the wild card with caution.</mark>  However, it is a handy tool to use when you don't have all the column names easily available or when you know you want to query an entire table.
#
# The syntax is as follows:
#
# ```mySQL
# SELECT *
# FROM dogs LIMIT 5, 10;
# ```
#
# **Question 8: Try using the wild card to query the reviews table:**

# %%
# %%sql
# SELECT *
# FROM reviews
# LIMIT 10,10
# Out:
# 10 rows affected.
# [(6, datetime.datetime(2014, 5, 2, 3, 5, 29), datetime.datetime(2014, 5, 2, 3, 5, 29), 'ce261aa4-7144-11e5-ba71-058fbc01cf0b', 'ce2609c4-7144-11e5-ba71-058fbc01cf0b', 'Communication', 'Arm Pointing'),
#  (2, datetime.datetime(2014, 5, 2, 3, 12, 47), datetime.datetime(2014, 5, 2, 3, 12, 47), 'ce261aa4-7144-11e5-ba71-058fbc01cf0b', 'ce2609c4-7144-11e5-ba71-058fbc01cf0b', 'Communication', 'Foot Pointing'),
#  (7, datetime.datetime(2014, 5, 2, 11, 50, 27), datetime.datetime(2014, 5, 2, 11, 50, 27), 'ce261bd0-7144-11e5-ba71-058fbc01cf0b', 'ce260c1c-7144-11e5-ba71-058fbc01cf0b', 'Shaker Game', 'Shaker Warm-Up'),
#  (0, datetime.datetime(2014, 5, 2, 18, 48, 36), datetime.datetime(2014, 5, 2, 18, 48, 36), 'ce2ab050-7144-11e5-ba71-058fbc01cf0b', 'ce3fd48a-7144-11e5-ba71-058fbc01cf0b', 'Empathy', 'Yawn Game'),
#  (0, datetime.datetime(2014, 5, 2, 18, 52, 7), datetime.datetime(2014, 5, 2, 18, 52, 7), 'ce2ab050-7144-11e5-ba71-058fbc01cf0b', 'ce3fd48a-7144-11e5-ba71-058fbc01cf0b', 'Empathy', 'Eye Contact Warm-up'),
#  (0, datetime.datetime(2014, 5, 2, 18, 59, 16), datetime.datetime(2014, 5, 2, 18, 59, 16), 'ce2ab050-7144-11e5-ba71-058fbc01cf0b', 'ce3fd48a-7144-11e5-ba71-058fbc01cf0b', 'Empathy', 'Eye Contact Game'),
#  (0, datetime.datetime(2014, 5, 2, 21, 57, 27), datetime.datetime(2014, 5, 2, 21, 57, 27), 'ce3f01e0-7144-11e5-ba71-058fbc01cf0b', 'ce405f90-7144-11e5-ba71-058fbc01cf0b', 'Empathy', 'Yawn Warm-up'),
#  (0, datetime.datetime(2014, 5, 2, 22, 4, 31), datetime.datetime(2014, 5, 2, 22, 4, 31), 'ce3f01e0-7144-11e5-ba71-058fbc01cf0b', 'ce405f90-7144-11e5-ba71-058fbc01cf0b', 'Empathy', 'Yawn Game'),
#  (1, datetime.datetime(2014, 5, 2, 22, 16, 26), datetime.datetime(2014, 5, 2, 22, 16, 26), 'ce3f01e0-7144-11e5-ba71-058fbc01cf0b', 'ce405f90-7144-11e5-ba71-058fbc01cf0b', 'Empathy', 'Eye Contact Game'),
#  (4, datetime.datetime(2014, 5, 3, 0, 30, 56), datetime.datetime(2014, 5, 3, 0, 30, 56), 'ce471eca-7144-11e5-ba71-058fbc01cf0b', 'ce405e28-7144-11e5-ba71-058fbc01cf0b', 'Memory', 'Delayed Cup Game')]

# %% [markdown]
# NOTE: if you do this for the dogs table, your output will be too wide to see at one time in the dialog box.  Use the scroll bars at bottom and to the right of the dialog box to see the entire output table.
#
#
# SELECT statements can also be used to make new derivations of individual columns using "+" for addition, "-" for subtraction, "\*" for multiplication, or "/" for division.  For example, if you wanted the median inter-test intervals in hours instead of minutes or days, you could query:
#
# ```mySQL
# SELECT median_iti_minutes / 60
# FROM dogs LIMIT 5, 10;
# ```
#
# **Question 9: Go ahead and try it, adding in a column to your output that shows you the original median_iti in minutes.**

# %%
# %%sql
# SELECT median_iti_minutes / 60
# FROM dogs
# LIMIT 5, 10
# Out:
# 10 rows affected.
# [(0.085555555285,),
#  (0.0080555537245,),
#  (0.11138889105833334,),
#  (0.081111109755,),
#  (0.09333333570666666,),
#  (0.14027777682833334,),
#  (0.10750000088166667,),
#  (0.09583333319833334,),
#  (0.094444443495,),
#  (0.09055555474166667,)]

# %% [markdown]
# ## Now it's time to practice writing your own SELECT statements.
#
# **Question 10: How would you retrieve the first 15 rows of data from the dog_guid, subcategory_name, and test_name fields of the Reviews table, in that order?**

# %%
# %%sql
# SELECT dog_guid, subcategory_name, test_name
# FROM reviews
# LIMIT 15
# Out:
# 15 rows affected.
# [('ce3ac77e-7144-11e5-ba71-058fbc01cf0b', 'Empathy', 'Yawn Warm-up'),
#  ('ce2aedcc-7144-11e5-ba71-058fbc01cf0b', 'Empathy', 'Eye Contact Warm-up'),
#  ('ce2aedcc-7144-11e5-ba71-058fbc01cf0b', 'Empathy', 'Eye Contact Game'),
#  ('ce2aedcc-7144-11e5-ba71-058fbc01cf0b', 'Communication', 'Treat Warm-up'),
#  ('ce405c52-7144-11e5-ba71-058fbc01cf0b', 'Empathy', 'Yawn Warm-up'),
#  ('ce405c52-7144-11e5-ba71-058fbc01cf0b', 'Empathy', 'Yawn Game'),
#  ('ce405c52-7144-11e5-ba71-058fbc01cf0b', 'Empathy', 'Eye Contact Game'),
#  ('ce405e28-7144-11e5-ba71-058fbc01cf0b', 'Communication', 'Treat Warm-up'),
#  ('ce405e28-7144-11e5-ba71-058fbc01cf0b', 'Cunning', 'Turn Your Back'),
#  ('ce2609c4-7144-11e5-ba71-058fbc01cf0b', 'Communication', 'Treat Warm-up'),
#  ('ce2609c4-7144-11e5-ba71-058fbc01cf0b', 'Communication', 'Arm Pointing'),
#  ('ce2609c4-7144-11e5-ba71-058fbc01cf0b', 'Communication', 'Foot Pointing'),
#  ('ce260c1c-7144-11e5-ba71-058fbc01cf0b', 'Shaker Game', 'Shaker Warm-Up'),
#  ('ce3fd48a-7144-11e5-ba71-058fbc01cf0b', 'Empathy', 'Yawn Game'),
#  ('ce3fd48a-7144-11e5-ba71-058fbc01cf0b', 'Empathy', 'Eye Contact Warm-up')]

# %% [markdown]
# **Question 11: How would you retrieve 10 rows of data from the activity_type, created_at, and updated_at fields of the site_activities table, starting at row 50?  What do you notice about the created_at and updated_at fields?**

# %%
# %%sql
# SELECT activity_type, created_at, updated_at
# FROM site_activities
# LIMIT 10,49
# Out:
# 49 rows affected.
# [('point_in_cat', datetime.datetime(2013, 7, 25, 20, 15, 52), datetime.datetime(2013, 7, 25, 20, 15, 52)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 42, 58), datetime.datetime(2013, 7, 25, 20, 42, 58)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 43, 54), datetime.datetime(2013, 7, 25, 20, 43, 54)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 43, 51), datetime.datetime(2013, 7, 25, 20, 43, 51)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 44, 2), datetime.datetime(2013, 7, 25, 20, 44, 2)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 44, 30), datetime.datetime(2013, 7, 25, 20, 44, 30)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 44, 26), datetime.datetime(2013, 7, 25, 20, 44, 26)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 44, 35), datetime.datetime(2013, 7, 25, 20, 44, 35)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 45, 5), datetime.datetime(2013, 7, 25, 20, 45, 5)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 45, 1), datetime.datetime(2013, 7, 25, 20, 45, 1)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 45, 10), datetime.datetime(2013, 7, 25, 20, 45, 10)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 45, 36), datetime.datetime(2013, 7, 25, 20, 45, 36)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 45, 43), datetime.datetime(2013, 7, 25, 20, 45, 43)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 45, 42), datetime.datetime(2013, 7, 25, 20, 45, 42)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 46, 17), datetime.datetime(2013, 7, 25, 20, 46, 17)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 46, 13), datetime.datetime(2013, 7, 25, 20, 46, 13)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 46, 21), datetime.datetime(2013, 7, 25, 20, 46, 21)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 46, 51), datetime.datetime(2013, 7, 25, 20, 46, 51)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 46, 57), datetime.datetime(2013, 7, 25, 20, 46, 57)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 46, 55), datetime.datetime(2013, 7, 25, 20, 46, 55)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 47, 9), datetime.datetime(2013, 7, 25, 20, 47, 9)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 48, 8), datetime.datetime(2013, 7, 25, 20, 48, 8)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 50, 57), datetime.datetime(2013, 7, 25, 20, 50, 57)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 51, 42), datetime.datetime(2013, 7, 25, 20, 51, 42)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 51, 44), datetime.datetime(2013, 7, 25, 20, 51, 44)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 51, 49), datetime.datetime(2013, 7, 25, 20, 51, 49)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 52, 21), datetime.datetime(2013, 7, 25, 20, 52, 21)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 52, 24), datetime.datetime(2013, 7, 25, 20, 52, 24)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 52, 34), datetime.datetime(2013, 7, 25, 20, 52, 34)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 53, 11), datetime.datetime(2013, 7, 25, 20, 53, 11)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 53, 13), datetime.datetime(2013, 7, 25, 20, 53, 13)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 53, 13), datetime.datetime(2013, 7, 25, 20, 53, 13)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 53, 52), datetime.datetime(2013, 7, 25, 20, 53, 52)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 53, 48), datetime.datetime(2013, 7, 25, 20, 53, 48)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 53, 53), datetime.datetime(2013, 7, 25, 20, 53, 53)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 54, 29), datetime.datetime(2013, 7, 25, 20, 54, 29)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 54, 26), datetime.datetime(2013, 7, 25, 20, 54, 26)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 54, 35), datetime.datetime(2013, 7, 25, 20, 54, 35)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 55, 1), datetime.datetime(2013, 7, 25, 20, 55, 1)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 55, 8), datetime.datetime(2013, 7, 25, 20, 55, 8)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 55, 7), datetime.datetime(2013, 7, 25, 20, 55, 7)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 55, 50), datetime.datetime(2013, 7, 25, 20, 55, 50)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 56, 9), datetime.datetime(2013, 7, 25, 20, 56, 9)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 56, 21), datetime.datetime(2013, 7, 25, 20, 56, 21)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 21, 0, 31), datetime.datetime(2013, 7, 25, 21, 0, 31)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 21, 2, 29), datetime.datetime(2013, 7, 25, 21, 2, 29)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 21, 2, 31), datetime.datetime(2013, 7, 25, 21, 2, 31)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 21, 2, 45), datetime.datetime(2013, 7, 25, 21, 2, 45)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 21, 5, 41), datetime.datetime(2013, 7, 25, 21, 5, 41))]

# %% [markdown]
# **Question 12: How would you retrieve 20 rows of data from all the columns in the users table, starting from row 2000?  What do you notice about the free_start_user field?**

# %%
# %%sql
# SELECT *
# FROM users
# LIMIT 20,1999
# Out:
# 1999 rows affected.
# [(3, datetime.datetime(2013, 2, 6, 2, 34, 46), datetime.datetime(2015, 1, 28, 20, 51, 50), 1, 1, 1, None, None, None, 1, 'ce1375b6-7144-11e5-ba71-058fbc01cf0b', 'Grayslake', 'IL', '60030', 'US', '-6'),
#  (9, datetime.datetime(2013, 2, 6, 3, 37, 7), datetime.datetime(2015, 1, 28, 20, 51, 50), 1, 2, 1, None, None, None, 2, 'ce1377b4-7144-11e5-ba71-058fbc01cf0b', 'Falls Church', 'VA', '22044', 'US', '-5'),
#  (22, datetime.datetime(2013, 2, 6, 3, 32, 8), datetime.datetime(2015, 1, 28, 20, 51, 50), 2, 2, 1, None, None, datetime.datetime(2014, 7, 30, 21, 54, 31), 2, 'ce137700-7144-11e5-ba71-058fbc01cf0b', 'Everett', 'WA', '98203', 'US', '-8'),
#  (5, datetime.datetime(2013, 2, 6, 4, 54, 49), datetime.datetime(2015, 1, 28, 20, 51, 50), 2, 2, 1, None, None, datetime.datetime(2014, 9, 20, 17, 8, 44), 2, 'ce137868-7144-11e5-ba71-058fbc01cf0b', 'Dixon', 'CA', '95620', 'US', '-8'),
#  (5, datetime.datetime(2013, 2,
datetime.datetime(2015, 1, 28, 20, 51, 51), 1, 1, 0, None, None, None, 1, 'ce2227be-7144-11e5-ba71-058fbc01cf0b', 'Princeton', 'NJ', '8540', 'US', '-5'),
#  (9, datetime.datetime(2013, 2, 9, 21, 29, 39), datetime.datetime(2015, 2, 8, 16, 46, 47), 1, 2, 1, None, None, datetime.datetime(2015, 2, 8, 16, 46, 47), 2, 'ce2228fe-7144-11e5-ba71-058fbc01cf0b', 'Oakland', 'CA', '94607', 'US', '-8'),
#  (41, datetime.datetime(2013, 2, 9, 23, 59, 48), datetime.datetime(2015, 1, 28, 20, 51, 51), 1, 2, 1, None, None, None, 2, 'ce222a02-7144-11e5-ba71-058fbc01cf0b', 'London', 'LND', 'W4 2SA', 'GB', '#N/A'),
#  (31, datetime.datetime(2013, 2, 6, 16, 41, 38), datetime.datetime(2015, 7, 23, 21, 38, 40), 1, 5, 1, None, None, datetime.datetime(2015, 7, 23, 21, 32, 13), 3, 'ce137f20-7144-11e5-ba71-058fbc01cf0b', 'Nathrop', 'CO', '81236', 'US', '-7'),
#  (4, datetime.datetime(2013, 2, 9, 5, 54, 44), datetime.datetime(2015, 1, 28, 20, 51, 51), 1, 1, 1, None, None, None, 1, 'ce221c88-7144-11e5-ba71-058fbc01cf0b', 'New York', 'NY', '10028', 'US', '-5'),
#  (4, datetime.datetime(2013, 2, 10, 3, 6, 20), datetime.datetime(2015, 1, 28, 20, 51, 51), 1, 1, 0, None, None, None, 1, 'ce222a70-7144-11e5-ba71-058fbc01cf0b', 'Orlando', 'FL', '32801', 'US', '-5'),
#  (4, datetime.datetime(2013, 2, 10, 7, 3, 17), datetime.datetime(2015, 1, 28, 20, 51, 51), 1, 1, 1, None, None, datetime.datetime(2014, 3, 4, 19, 35, 51), 1, 'ce222ade-7144-11e5-ba71-058fbc01cf0b', 'St. Privé St. Mesmin', 'F', '45750', 'FR', '-'),
#  (10, datetime.datetime(2013, 2, 9, 6, 44, 12), datetime.datetime(2015, 1, 28, 20, 51, 51), 1, 1, 0, None, None, None, 1, 'ce221d1e-7144-11e5-ba71-058fbc01cf0b', 'Moorooka', 'QLD', '4105', 'AU', '-'),
#  (13, datetime.datetime(2013, 2, 10, 15, 36, 35), datetime.datetime(2015, 1, 28, 20, 51, 51), 1, 2, 1, None, None, datetime.datetime(2015, 1, 21, 0, 42, 11), 2, 'ce222fa2-7144-11e5-ba71-058fbc01cf0b', 'Atlanta', 'GA', '30328', 'US', '-5'),
#  (74, datetime.datetime(2013, 2, 10, 18, 56, 48), datetime.datetime(2015, 5, 16, 9, 25), 2, 2, 1, None, None, datetime.datetime(2015, 5, 16, 9, 25), 2, 'ce2232cc-7144-11e5-ba71-058fbc01cf0b', 'Delémont', 'JU', '2800', 'CH', '#N/A'),
#  (15, datetime.datetime(2013, 2, 10, 19, 18, 2), datetime.datetime(2015, 7, 12, 23, 43, 41), 1, 2, 1, None, None, datetime.datetime(2015, 7, 12, 23, 43, 41), 2, 'ce223452-7144-11e5-ba71-058fbc01cf0b', 'New York', 'NY', '10003', 'US', '-5'),
#  (5, datetime.datetime(2013, 2, 10, 20, 7, 24), datetime.datetime(2015, 1, 28, 20, 51, 51), 2, 2, 1, None, None, None, 2, 'ce2234f2-7144-11e5-ba71-058fbc01cf0b', 'Mcminnville', 'OR', '97128', 'US', '-8'),
#  (5, datetime.datetime(2013, 2, 10, 20, 7, 24), datetime.datetime(2015, 1, 28, 20, 51, 51), 2, 2, 1, None, None, None, 2, 'ce2234f2-7144-11e5-ba71-058fbc01cf0b', 'Mcminnville', 'OR', '97128', 'US', '-8'),
#  (6, datetime.datetime(2013, 2, 10, 20, 37, 9), datetime.datetime(2015, 1, 28, 20, 51, 51), 1, 1, 1, None, None, datetime.datetime(2014, 4, 27, 17, 25, 2), 1, 'ce223628-7144-11e5-ba71-058fbc01cf0b', 'Altoona', 'IA', '50009', 'US', '-6'),
#  (8, datetime.datetime(2013, 2, 10, 20, 51, 19), datetime.datetime(2015, 1, 28, 20, 51, 51), 3, 2, 1, None, None, datetime.datetime(2014, 3, 19, 0, 53, 29), 2, 'ce2236c8-7144-11e5-ba71-058fbc01cf0b', 'Hillsborough', 'NC', '27278', 'US', '-5'),
#  (8, datetime.datetime(2013, 2,
datetime.datetime(2015, 1, 28, 20, 51, 51), 1, 2, 1, None, None, datetime.datetime(2014, 10, 1, 20, 1, 39), 2, 'ce223f06-7144-11e5-ba71-058fbc01cf0b', 'North Adams', 'MA', '1247', 'US', '-5'),
#  (20, datetime.datetime(2013, 2, 11, 18, 6, 55), datetime.datetime(2015, 6, 3, 0, 37, 59), 1, 2, 1, None, None, datetime.datetime(2015, 6, 3, 0, 37, 59), 2, 'ce22408c-7144-11e5-ba71-058fbc01cf0b', 'Sellersville', 'PA', '18960', 'US', '-5'),
#  (17, datetime.datetime(2013, 2, 10, 22, 42, 44), datetime.datetime(2015, 1, 28, 20, 51, 51), 1, 2, 0, 1, 0, None, 2, 'ce22392a-7144-11e5-ba71-058fbc01cf0b', 'Durham', 'NC', '27701', 'US', '-5'),
#  (10, datetime.datetime(2013, 2, 11, 18, 52, 3), datetime.datetime(2015, 1, 28, 20, 51, 51), 1, 2, 1, None, None, datetime.datetime(2014, 4, 2, 16, 32, 39), 2, 'ce2240f0-7144-11e5-ba71-058fbc01cf0b', 'New Carlisle', 'IN', '46552', 'US', '-5'),
#  (6, datetime.datetime(2013, 2, 11, 17, 32, 26), datetime.datetime(2015, 1, 28, 20, 51, 51), 1, 1, 0, None, None, None, 1, 'ce224028-7144-11e5-ba71-058fbc01cf0b', 'Durham', 'NC', '27701', 'US', '-5'),
#  (9, datetime.datetime(2013, 2, 11, 22, 24, 37), datetime.datetime(2015, 1, 28, 20, 51, 51), 1, 1, 1, None, None, None, 1, 'ce22414a-7144-11e5-ba71-058fbc01cf0b', 'Alma', 'WI', '54610', 'US', '-6'),
#  (24, datetime.datetime(2013, 2, 11, 22, 36, 38), datetime.datetime(2015, 1, 28, 20, 51, 51), 1, 1, 0, None, None, None, 1, 'ce2241ae-7144-11e5-ba71-058fbc01cf0b', 'Rotorua', 'N', '3015', 'NZ', '#N/A'),
#  (13, datetime.datetime(2013, 2, 11, 22, 57, 15), datetime.datetime(2015, 5, 28, 19, 20, 33), 2, 2, 1, None, None, datetime.datetime(2015, 5, 28, 19, 20, 33), 2, 'ce224208-7144-11e5-ba71-058fbc01cf0b', 'Pennington', 'NJ', '8534', 'US', '-5'),
#  (13, datetime.datetime(2013, 2, 11, 22, 57, 15), datetime.datetime(2015, 5, 28, 19, 20, 33), 2, 2, 1, None, None, datetime.datetime(2015, 5, 28, 19, 20, 33), 2, 'ce224208-7144-11e5-ba71-058fbc01cf0b', 'Pennington', 'NJ', '8534', 'US', '-5'),
#  (5, datetime.datetime(2013, 2, 11, 23, 48, 15), datetime.datetime(2015, 1, 28, 20, 51, 51), 1, 1, 1, None, None, None, 1, 'ce22426c-7144-11e5-ba71-058fbc01cf0b', 'Santa Fe', 'NM', '87506', 'US', '-7'),
#  (1, datetime.datetime(2013, 2, 12, 0, 19, 16), datetime.datetime(2015, 1, 28, 20, 51, 51), 1, 1, 0, None, None, None, 1, 'ce22432a-7144-11e5-ba71-058fbc01cf0b', 'Washington', 'DC', '20024', 'US', '-5'),
#  (1, datetime.datetime(2013, 2, 12, 0, 31, 55), datetime.datetime(2015, 1, 28, 20, 51, 51), 1, 1, 0, None, None, None, 1, 'ce22438e-7144-11e5-ba71-058fbc01cf0b', 'Towson', 'MD', '21286', 'US', '-5'),
#  (14, datetime.datetime(2013, 2, 12, 0, 44, 56), datetime.datetime(2015, 1, 29, 19, 17, 8), 1, 2, 1, None, None, datetime.datetime(2015, 1, 29, 19, 17, 8), 2, 'ce2243e8-7144-11e5-ba71-058fbc01cf0b', 'Carmel Valley', 'CA', '93924', 'US', '-8'),
#  (2, datetime.datetime(2013, 2, 12, 0, 51, 26), datetime.datetime(2015, 1, 28, 20, 51, 51), 1, 1, 0, None, None, None, 1, 'ce22444c-7144-11e5-ba71-058fbc01cf0b', 'Alpharetta', 'GA', '30005', 'US', '-5'),
#  (45, datetime.datetime(2013, 2, 12, 2, 34, 1), datetime.datetime(2015, 1, 28, 20, 51, 51), 2, 2, 1, None, None, datetime.datetime(2014, 5, 30, 21, 57, 45), 2, 'ce22456e-7144-11e5-ba71-058fbc01cf0b', 'Chemainus', 'BC', 'V0R', 'CA', '#N/A'),
#  (45, datetime.datetime(2013, 2, 12, 2, 34, 1), datetime.datetime(2015, 1, 28, 20, 51, 51), 2, 2, 1, None, None, datetime.datetime(2014, 5, 30, 21, 57, 45), 2, 'ce22456e-7144-11e5-ba71-058fbc01cf0b', 'Chemainus', 'BC', 'V0R', 'CA', '#N/A'),
#  (22, datetime.datetime(2013, 2, 12, 20, 0, 50), datetime.datetime(2015, 1, 28, 20, 51, 51), 1, 2, 1, None, None, None, 2, 'ce22492e-7144-11e5-ba71-058fbc01cf0b', 'Macon', 'GA', '31204', 'US', '-5'),
#  (181, datetime.datetime(2013, 2, 5, 17, 54, 42), datetime.datetime(2015, 1, 28, 20, 51, 49), 13, 2, 1, 1, 0, None, 2, 'ce135e14-7144-11e5-ba71-058fbc01cf0b', 'Raleigh', 'NC', '27606', 'US', '-5'),
#  (4, datetime.datetime(2013, 2, 10, 10, 21, 31), datetime.datetime(2015, 1, 28, 20, 51, 51), 2, 2, 0, None, None, datetime.datetime(2014, 6, 3, 1, 35, 27), 2, 'ce222e58-7144-11e5-ba71-058fbc01cf0b', 'Vancouver', 'BC', 'V6B', 'CA', '#N/A'),
#  (4, datetime.datetime(2013, 2, 10, 10, 21, 31), datetime.datetime(2015, 1, 28, 20, 51, 51), 2, 2, 0, None, None, datetime.datetime(2014, 6, 3, 1, 35, 27), 2, 'ce222e58-7144-11e5-ba71-058fbc01cf0b', 'Vancouver', 'BC', 'V6B', 'CA', '#N/A'),
#  (2, datetime.datetime(2013, 2, 13, 3, 7, 15), datetime.datetime(2015, 1, 28, 20, 51, 52), 1, 2, 1, None, None, None, 2, 'ce224b0e-7144-11e5-ba71-058fbc01cf0b', 'Bala Cynwyd', 'PA', '19004', 'US', '-5'),
#  (8, datetime.datetime(2013, 2, 6, 21, 46, 4), datetime.datetime(2015, 2, 24, 20, 57, 4), 1, 2, 1, None, None, datetime.datetime(2015, 2, 24, 20, 57, 4), 2, 'ce138920-7144-11e5-ba71-058fbc01cf0b', 'Woodinville', 'NC', '27702', 'US', '-5'),
#  (9, datetime.datetime(2013, 2, 13, 3, 38, 36), datetime.datetime(2015, 1, 28, 20, 51, 52), 2, 2, 0, None, None, None, 2, 'ce224b68-7144-11e5-ba71-058fbc01cf0b', 'Auckland', 'N', '626', 'NZ', '#N/A'),
#  (9, datetime.datetime(2013, 2, 13, 3, 38, 36), datetime.datetime(2015, 1, 28, 20, 51, 52), 2, 2, 0, None, None, None, 2, 'ce224b68-7144-11e5-ba71-058fbc01cf0b', 'Auckland', 'N', '626', 'NZ', '#N/A'),
#  (3, datetime.datetime(2013, 2, 13, 6, 7, 13), datetime.datetime(2015, 1, 28, 20, 51, 52), 1, 1, 0, None, None, datetime.datetime(2014, 9, 13, 2, 0, 40), 1, 'ce224bcc-7144-11e5-ba71-058fbc01cf0b', 'Dallas', 'TX', '75214', 'US', '-6'),
#  (21, datetime.datetime(2013, 2, 12, 22, 30, 53), datetime.datetime(2015, 1, 28, 20, 51, 52), 1, 2, 1, None, None, datetime.datetime(2014, 12, 19, 2, 14, 40), 2, 'ce224a46-7144-11e5-ba71-058fbc01cf0b', 'Prairie Village', 'KS', '66208', 'US', '-6'),
#  (3, datetime.datetime(2013, 2, 13, 19, 38, 35), datetime.datetime(2015, 1, 28, 20, 51, 52), 2, 2, 1, None, None, None, 2, 'ce224d52-7144-11e5-ba71-058fbc01cf0b', 'Phoenix', 'AZ', '85028', 'US', '-7'),
#  (3, datetime.datetime(2013, 2, 13, 19, 38, 35), datetime.datetime(2015, 1, 28, 20, 51, 52), 2, 2, 1, None, None, None, 2, 'ce224d52-7144-11e5-ba71-058fbc01cf0b', 'Phoenix', 'AZ', '85028', 'US', '-7'),
#  (7, datetime.datetime(2013, 2, 13, 21, 37, 2), datetime.datetime(2015, 1, 28, 20, 51, 52), 1, 2, 1, None, None, None, 2, 'ce224e10-7144-11e5-ba71-058fbc01cf0b', 'Philadelphia', 'PA', '19104', 'US', '-5'),
#  (8, datetime.datetime(2013, 2, 5, 15, 29, 50), datetime.datetime(2015, 1, 28, 20, 51, 49), 2, 1, 1, None, None, None, 1, 'ce1353d8-7144-11e5-ba71-058fbc01cf0b', 'Barre', 'MA', '1005', 'US', '-5'),
#  (9, datetime.datetime(2013, 2, 13, 19, 59, 42), datetime.datetime(2015, 1, 28, 20, 51, 52), 1, 1, 0, None, None, None, 1, 'ce224dac-7144-11e5-ba71-058fbc01cf0b', 'San Marcos', 'TX', '78666', 'US', '-6'),
#  (2, datetime.datetime(2013, 2, 14, 4, 3, 33), datetime.datetime(2015, 1, 28, 20, 51, 52), 1, 1, 0, None, None, None, 1, '
datetime.datetime(2015, 1, 28, 20, 51, 52), 2, 2, 1, None, None, None, 2, 'ce240fac-7144-11e5-ba71-058fbc01cf0b', 'Freeland', 'MD', '21053', 'US', '-5'),
#  (16, datetime.datetime(2013, 2, 18, 23, 13, 11), datetime.datetime(2015, 1, 28, 20, 51, 52), 2, 2, 0, None, None, None, 2, 'ce241042-7144-11e5-ba71-058fbc01cf0b', 'Cary', 'NC', '27511', 'US', '-5'),
#  (8, datetime.datetime(2013, 2, 18, 23, 14, 18), datetime.datetime(2015, 1, 30, 0, 14, 1), 1, 2, 1, None, None, datetime.datetime(2015, 1, 30, 0, 14, 1), 2, 'ce2410d8-7144-11e5-ba71-058fbc01cf0b', 'New York', 'NY', '10022', 'US', '-5'),
#  (16, datetime.datetime(2013, 2, 18, 23, 13, 11), datetime.datetime(2015, 1, 28, 20, 51, 52), 2, 2, 0, None, None, None, 2, 'ce241042-7144-11e5-ba71-058fbc01cf0b', 'Cary', 'NC', '27511', 'US', '-5'),
#  (5, datetime.datetime(2013, 2, 18, 23, 33, 43), datetime.datetime(2015, 1, 28, 20, 51, 52), 1, 2, 1, None, None, None, 2, 'ce241178-7144-11e5-ba71-058fbc01cf0b', 'Las Vegas', 'NV', '89119', 'US', '-8'),
#  (6, datetime.datetime(2013, 2, 19, 0, 13, 43), datetime.datetime(2015, 1, 28, 20, 51, 52), 1, 2, 1, None, None, None, 2, 'ce241218-7144-11e5-ba71-058fbc01cf0b', 'Phoenix', 'MD', '21131', 'US', '-5'),
# ...
#  (11, datetime.datetime(2013, 4, 24, 5, 0, 21), datetime.datetime(2015, 1, 28, 20, 52, 3), 1, 2, 1, None, None, datetime.datetime(2014, 8, 27, 18, 41, 13), 2, 'ce26ac08-7144-11e5-ba71-058fbc01cf0b', 'Santa Monica', 'CA', '90403', 'US', '-8'),
#  (4, datetime.datetime(2013, 4, 24, 5, 48, 24), datetime.datetime(2015, 1, 28, 20, 52, 3), 1, 1, 1, None, None, datetime.datetime(2014, 2, 16, 20, 35, 31), 1, 'ce26acc6-7144-11e5-ba71-058fbc01cf0b', 'Melbourne', 'VIC', '3072', 'AU', '#N/A'),
#  (46, datetime.datetime(2013, 4, 24, 10, 14, 57), datetime.datetime(2015, 3, 3, 22, 48, 57), 1, 2, 1, None, None, datetime.datetime(2015, 3, 3, 22, 48, 57), 2, 'ce26ad84-7144-11e5-ba71-058fbc01cf0b', 'Erie', 'PA', '16509', 'US', '-5'),
#  (15, datetime.datetime(2013, 4, 24, 10, 43, 39), datetime.datetime(2015, 1, 28, 20, 52, 3), 1, 2, 1, None, None, datetime.datetime(2014, 2, 21, 20, 29), 2, 'ce26adde-7144-11e5-ba71-058fbc01cf0b', 'Smyrna', 'GA', '30082', 'US', '-5'),
#  (16, datetime.datetime(2013, 4, 24, 12, 39, 51), datetime.datetime(2015, 1, 28, 20, 52, 3), 1, 1, 1, None, None, None, 1, 'ce26ae38-7144-11e5-ba71-058fbc01cf0b', 'Westerly', 'RI', '2891', 'US', '#N/A'),
#  (2, datetime.datetime(2013, 4, 24, 13, 23, 49), datetime.datetime(2015, 1, 28, 20, 52, 3), 1, 2, 1, None, None, datetime.datetime(2014, 12, 17, 22, 5, 15), 2, 'ce26aeec-7144-11e5-ba71-058fbc01cf0b', 'Pasadena', 'CA', '91106', 'US', '-8'),
#  (5, datetime.datetime(2013, 4, 24, 13, 51, 26), datetime.datetime(2015, 1, 28, 20, 52, 3), 2, 1, 1, None, None, None, 1, 'ce26b202-7144-11e5-ba71-058fbc01cf0b', 'Jamaica', 'NY', '11432', 'US', '-5'),
#  (104, datetime.datetime(2013, 4, 24, 14, 0, 29), datetime.datetime(2015, 1, 28, 20, 52, 3), 5, 2, 1, None, None, datetime.datetime(2014, 7, 6, 1, 17, 13), 2, 'ce26b266-7144-11e5-ba71-058fbc01cf0b', 'Nashville', 'TN', '37204', 'US', '-6'),
#  (104, datetime.datetime(2013, 4, 24, 14, 0, 29), datetime.datetime(2015, 1, 28, 20, 52, 3), 5, 2, 1, None, None, datetime.datetime(2014, 7, 6, 1, 17, 13), 2, 'ce26b266-7144-11e5-ba71-058fbc01cf0b', 'Nashville', 'TN', '37204', 'US', '-6'),
#  (104, datetime.datetime(2013, 4, 24, 14, 0, 29), datetime.datetime(2015, 1, 28, 20, 52, 3), 5, 2, 1, None, None, datetime.datetime(2014, 7, 6, 1, 17, 13), 2, 'ce26b266-7144-11e5-ba71-058fbc01cf0b', 'Nashville', 'TN', '37204', 'US', '-6'),
#  (3, datetime.datetime(2013, 4, 24, 14, 30, 17), datetime.datetime(2015, 1, 28, 20, 52, 3), 1, 2, 0, None, None, None, 2, 'ce26b2c0-7144-11e5-ba71-058fbc01cf0b', 'New York', 'NY', '10031', 'US', '-5'),
#  (2, datetime.datetime(2013, 4, 24, 14, 59, 38), datetime.datetime(2015, 1, 28, 20, 52, 3), 1, 2, 1, None, None, None, 2, 'ce26b3ce-7144-11e5-ba71-058fbc01cf0b', 'Midlothian', 'VA', '23113', 'US', '-5'),
#  (20, datetime.datetime(2013, 4, 24, 15, 27, 36), datetime.datetime(2015, 2, 25, 13, 26, 49), 2, 2, 1, None, None, datetime.datetime(2015, 2, 25, 13, 26, 49), 2, 'ce26b4fa-7144-11e5-ba71-058fbc01cf0b', 'Dandridge', 'TN', '37725', 'US', '-5'),
#  (11, datetime.datetime(2013, 4, 24, 15, 58, 37), datetime.datetime(2015, 1, 28, 20, 52, 3), 1, 2, 1, None, None, datetime.datetime(2014, 2, 22, 0, 22, 24), 2, 'ce26ba4a-7144-11e5-ba71-058fbc01cf0b', 'Oakland', 'CA', '94602', 'US', '-8'),
#  (10, datetime.datetime(2013, 4, 24, 15, 53, 42), datetime.datetime(2015, 1, 28, 20, 52, 3), 1, 1, 1, None, None, None, 1, 'ce26b9c8-7144-11e5-ba71-058fbc01cf0b', 'Topeka', 'KS', '66614', 'US', '-6'),
#  (99, datetime.datetime(2013, 4, 24, 16, 6, 19), datetime.datetime(2015, 6, 30, 19, 19, 47), 1, 2, 1, None, None, datetime.datetime(2015, 6, 30, 19, 19, 47), 2, 'ce26bedc-7144-11e5-ba71-058fbc01cf0b', 'Alexandria', 'VA', '22307', 'US', '-5'),
#  (20, datetime.datetime(2013, 4, 24, 16, 21, 10), datetime.datetime(2015, 1, 28, 20, 52, 3), 1, 2, 1, None, None, datetime.datetime(2014, 4, 27, 0, 59, 43), 2, 'ce26c31e-7144-11e5-ba71-058fbc01cf0b', 'Tucson', 'AZ', '85737', 'US', '-7'),
#  (9, datetime.datetime(2013, 4, 24, 17, 9, 24), datetime.datetime(2015, 9, 15, 1, 53, 57), 3, 2, 1, None, None, datetime.datetime(2015, 9, 15, 1, 53, 57), 2, 'ce26c6c0-7144-11e5-ba71-058fbc01cf0b', 'Woodland', 'CA', '95695', 'US', '-8'),
#  (9, datetime.datetime(2013, 4, 24, 17, 9, 24), datetime.datetime(2015, 9, 15, 1, 53, 57), 3, 2, 1, None, None, datetime.datetime(2015, 9, 15, 1, 53, 57), 2, 'ce26c6c0-7144-11e5-ba71-058fbc01cf0b', 'Woodland', 'CA', '95695', 'US', '-8'),
#  (9, datetime.datetime(2013, 4, 24, 17, 9, 24), datetime.datetime(2015, 9, 15, 1, 53, 57), 3, 2, 1, None, None, datetime.datetime(2015, 9, 15, 1, 53, 57), 2, 'ce26c6c0-7144-11e5-ba71-058fbc01cf0b', 'Woodland', 'CA', '95695', 'US', '-8'),
#  (15, datetime.datetime(2013, 4, 24, 17, 13, 45), datetime.datetime(2015, 1, 30, 1, 52, 5), 1, 2, 1, None, None, datetime.datetime(2015, 1, 30, 1, 52, 5), 2, 'ce26c9d6-7144-11e5-ba71-058fbc01cf0b', 'Morristown', 'NJ', '7960', 'US', '-5'),
#  (9, datetime.datetime(2013, 4, 24, 17, 14, 16), datetime.datetime(2015, 1, 28, 20, 52, 3), 1, 2, 1, None, None, datetime.datetime(2014, 8, 28, 12, 52, 18), 2, 'ce26cdbe-7144-11e5-ba71-058fbc01cf0b', 'Concord', 'NH', '3303', 'US', '-5'),
#  (4, datetime.datetime(2013, 4, 24, 17, 21, 58), datetime.datetime(2015, 1, 28, 20, 52, 3), 1, 2, 1, None, None, datetime.datetime(2014, 5, 27, 3, 2, 32), 2, 'ce26d610-7144-11e5-ba71-058fbc01cf0b', 'San Francisco', 'CA', '94102', 'US', '-8'),
#  (2, datetime.datetime(2013, 4, 24, 18, 19, 56), datetime.datetime(2015, 1, 28, 20, 52, 3), 1, 2, 1, None, None, None, 2, 'ce26d82c-7144-11e5-ba71-058fbc01cf0b', 'Chelsea', 'MI', '48118', 'US', '-5'),
#  (7, datetime.datetime(2013, 4, 24, 18, 18, 26), datetime.datetime(2015, 1, 28, 20, 52, 3), 1, 1, 1, None, None, None, 1, 'ce26d73c-7144-11e5-ba71-058fbc01cf0b', 'Irvine', 'CA', '92603', 'US', '-8'),
#  (7, datetime.datetime(2013, 4, 24, 12, 58, 28), datetime.datetime(2015, 4, 5, 14, 7, 52), 1, 2, 1, None, None, datetime.datetime(2015, 4, 5, 14, 7, 52), 2, 'ce26ae92-7144-11e5-ba71-058fbc01cf0b', 'Munich', 'BY', '80339', 'DE', '#N/A'),
#  (5, datetime.datetime(2013, 4, 24, 20, 22, 29), datetime.datetime(2015, 1, 28, 20, 52, 3), 1, 1, 1, None, None, datetime.datetime(2014, 5, 25, 16, 51, 51), 1, 'ce26d958-7144-11e5-ba71-058fbc01cf0b', 'Rock Hill', 'SC', '29732', 'US', '-5'),
#  (2, datetime.datetime(2013, 4, 24, 20, 22, 56), datetime.datetime(2015, 1, 28, 20, 52, 3), 2, 2, 1, None, None, None, 2, 'ce26da16-7144-11e5-ba71-058fbc01cf0b', 'Toledo', 'OH', '43614', 'US', '-5'),
#  (13, datetime.datetime(2013, 4, 24, 20, 34, 15), datetime.datetime(2015, 9, 26, 17, 5, 46), 2, 2, 0, None, None, datetime.datetime(2015, 9, 26, 17, 5, 46), 2, 'ce26da7a-7144-11e5-ba71-058fbc01cf0b', 'San Francisco', 'CA', '94110', 'US', '-8'),
#  (6, datetime.datetime(2013, 4, 24, 21, 34, 28), datetime.datetime(2015, 1, 28, 20, 52, 3), 2, 1, 0, None, None, None, 1, 'ce26db9c-7144-11e5-ba71-058fbc01cf0b', 'Spencer', 'NY', '14883', 'US', '-5'),
#  (15, datetime.datetime(2013, 4, 24, 21, 56, 19), datetime.datetime(2015, 1, 28, 20, 52, 3), 4, 2, 1, None, None, datetime.datetime(2014, 7, 30, 18, 33, 49), 2, 'ce26dbf6-7144-11e5-ba71-058fbc01cf0b', 'San Francisco', 'CA', '94114', 'US', '-8'),
#  (4, datetime.datetime(2013, 4, 24, 22, 0, 5), datetime.datetime(2015, 1, 28, 20, 52, 3), 2, 2, 1, None, None, None, 2, 'ce26dc5a-7144-11e5-ba71-058fbc01cf0b', 'Montclair', 'NJ', '7043', 'US', '-5'),
#  (7, datetime.datetime(2013, 4, 24, 22, 0, 8), datetime.datetime(2015, 1, 28, 20, 52, 3), 1, 2, 1, None, None, datetime.datetime(2014, 12, 24, 13, 53, 55), 2, 'ce26dcb4-7144-11e5-ba71-058fbc01cf0b', 'Bethesda', 'MD', '20817', 'US', '-5'),
#  (2, datetime.datetime(2013, 4, 24, 22, 4, 28), datetime.datetime(2015, 1, 28, 20, 52, 3), 1, 1, 0, None, None, None, 1, 'ce26dd18-7144-11e5-ba71-058fbc01cf0b', 'Potomac', 'MD', '20854', 'US', '-5'),
#  (14, datetime.datetime(2013, 4, 24, 22, 7, 4), datetime.datetime(2015, 1, 28, 20, 52, 3), 1, 2, 1, None, None, None, 2, 'ce26dd7c-7144-11e5-ba71-058fbc01cf0b', 'Tucson', 'AZ', '85718', 'US', '-7'),
#  (11, datetime.datetime(2013, 4, 24, 22, 58, 19), datetime.datetime(2015, 1, 31, 18, 11, 1), 1, 1, 1, None, None, datetime.datetime(2015, 1, 31, 18, 11, 1), 1, 'ce26de3a-7144-11e5-ba71-058fbc01cf0b', 'Brooklyn', 'NY', '11231', 'US', '-5'),
#  (9, datetime.datetime(2013, 4, 25, 0, 10, 42), datetime.datetime(2015, 1, 28, 20, 52, 3), 1, 2, 0, None, None, None, 2, 'ce26def8-7144-11e5-ba71-058fbc01cf0b', 'Seattle', 'WA', '98101', 'US', '-8'),
#  (19, datetime.datetime(2013, 4, 25, 1, 3, 3), datetime.datetime(2015, 1, 28, 20, 52, 3), 1, 1, 1, None, None, None, 1, 'ce26e01a-7144-11e5-ba71-058fbc01cf0b', 'Fairbanks', 'AK', '99712', 'US', '-9'),
#  (3, datetime.datetime(2013, 4, 25, 0, 54, 44), datetime.datetime(2015, 1, 28, 20, 52, 3), 2, 1, 0, None, None, None, 1, 'ce26dfb6-7144-11e5-ba71-058fbc01cf0b', 'Seattle', 'WA', '98109', 'US', '-8'),
#  (6, datetime.datetime(2013, 4, 25, 1, 40, 19), datetime.datetime(2015, 1, 28, 20, 52, 3), 1, 1, 1, None, None, datetime.datetime(2014, 6, 27, 22, 17, 49), 1, 'ce26e074-7144-11e5-ba71-058fbc01cf0b', 'Little Rock', 'AR', '72207', 'US', '-6'),
#  (5, datetime.datetime(2013, 4, 24, 2, 53, 22), datetime.datetime(2015, 1, 28, 20, 52, 3), 1, 2, 0, None, None, datetime.datetime(2014, 5, 27, 1, 25, 48), 2, 'ce26a8a2-7144-11e5-ba71-058fbc01cf0b', 'Boston', 'MA', '2118', 'US', '#N/A'),
#  (32, datetime.datetime(2013, 4, 25, 4, 8, 39), datetime.datetime(2015, 10, 9, 3, 7, 55), 2, 1, 1, 0, 0, datetime.datetime(2015, 10, 9, 3, 7, 55), 1, 'ce26e1fa-7144-11e5-ba71-058fbc01cf0b', 'Belmont', 'CA', '94002', 'US', '-8'),
#  (12, datetime.datetime(2013, 4, 25, 5, 18, 41), datetime.datetime(2015, 1, 28, 20, 52, 3), 1, 1, 0, None, None, None, 1, 'ce26e2b8-7144-11e5-ba71-058fbc01cf0b', 'Sausalito', 'CA', '94965', 'US', '-8'),
#  (5, datetime.datetime(2013, 4, 25, 2, 11, 17), datetime.datetime(2015, 1, 28, 20, 52, 3), 1, 1, 0, None, None, None, 1, 'ce26e13c-7144-11e5-ba71-058fbc01cf0b', 'Durham', 'NC', '27705', 'US', '-5'),
#  (35, datetime.datetime(2013, 4, 25, 13, 3, 39), datetime.datetime(2015, 1, 28, 20, 52, 3), 1, 2, 1, None, None, datetime.datetime(2014, 12, 31, 20, 24, 22), 2, 'ce26e376-7144-11e5-ba71-058fbc01cf0b', 'New York', 'NY', '10028', 'US', '-5'),
#  (3, datetime.datetime(2013, 4, 25, 13, 56, 49), datetime.datetime(2015, 1, 28, 20, 52, 4), 1, 1, 0, None, None, None, 1, 'ce26e434-7144-11e5-ba71-058fbc01cf0b', 'Athens', 'GA', '30606', 'US', '-5'),
#  (2, datetime.datetime(2013, 4, 25, 14, 15, 2), datetime.datetime(2015, 1, 28, 20, 52, 4), 1, 2, 1, None, None, None, 2, 'ce26e498-7144-11e5-ba71-058fbc01cf0b', 'Tunkhannock', 'PA', '18657', 'US', '-5'),
#  (17, datetime.datetime(2013, 4, 25, 14, 17, 34), datetime.datetime(2015, 1, 28, 20, 52, 4), 1, 2, 1, None, None, datetime.datetime(2014, 11, 28, 2, 41, 9), 2, 'ce26e4f2-7144-11e5-ba71-058fbc01cf0b', 'Las Vegas', 'NM', '87701', 'US', '-7'),
#  (17, datetime.datetime(2013, 4, 25, 14, 40, 33), datetime.datetime(2015, 1, 28, 20, 52, 4), 1, 2, 1, None, None, datetime.datetime(2015, 1, 11, 19, 15, 43), 2, 'ce26e5b0-7144-11e5-ba71-058fbc01cf0b', 'Houston', 'TX', '77019', 'US', '-6'),
#  (12, datetime.datetime(2013, 4, 25, 15, 19, 24), datetime.datetime(2015, 1, 28, 20, 52, 4), 1, 1, 1, None, None, datetime.datetime(2014, 7, 31, 7, 35, 34), 1, 'ce26e614-7144-11e5-ba71-058fbc01cf0b', 'Cagliari', '88', '9127', 'IT', '#N/A'),
#  (6, datetime.datetime(2013, 4, 25, 16, 50, 41), datetime.datetime(2015, 1, 28, 20, 52, 4), 1, 2, 1, None, None, datetime.datetime(2014, 4, 28, 12, 56, 42), 2, 'ce26e6d2-7144-11e5-ba71-058fbc01cf0b', 'Santiago', 'RM', '7660153', 'CL', '#N/A'),
#  (3, datetime.datetime(2013, 4, 25, 5, 53, 41), datetime.datetime(2015, 1, 28, 20, 52, 3), 1, 1, 1, None, None, None, 1, 'ce26e31c-7144-11e5-ba71-058fbc01cf0b', 'Boulder', 'CO', '80304', 'US', '-7'),
#  (6, datetime.datetime(2013, 4, 25, 18, 28, 2), datetime.datetime(2015, 1, 28, 20, 52, 4), 2, 2, 0, None, None, None, 2, 'ce26e7f4-7144-11e5-ba71-058fbc01cf0b', 'San Jose', 'CA', '95112', 'US', '-8'),
#  (8, datetime.datetime(2013, 4, 25, 17, 46, 10), datetime.datetime(2015, 1, 28, 20, 52, 4), 5, 2, 1, None, None, datetime.datetime(2014, 4, 14, 22, 53, 25), 2, 'ce26e790-7144-11e5-ba71-058fbc01cf0b', 'Brighton', 'CO', '80602', 'US', '-7'),
#  (1, datetime.datetime(2013, 4, 25, 19, 10, 10), datetime.datetime(2015, 1, 28, 20, 52, 4), 1, 1, 1, None, None, None, 1, 'ce26e90c-7144-11e5-ba71-058fbc01cf0b', 'Purcellville', 'VA', '20132', 'US', '-5'),
#  (4, datetime.datetime(2013, 4, 25, 19, 43, 33), datetime.datetime(2015, 1, 28, 20, 52, 4), 1, 1, 1, None, None, None, 1, 'ce26e970-7144-11e5-ba71-058fbc01cf0b', 'Cassano Delle Murge', '75', '70020', 'IT', '#N/A'),
#  (7, datetime.datetime(2013, 4, 25, 22, 1, 14), datetime.datetime(2015, 1, 28, 20, 52, 4), 1, 1, 1, None, None, datetime.datetime(2014, 3, 28, 20, 50, 42), 1, 'ce26ea38-7144-11e5-ba71-058fbc01cf0b', 'Tampa', 'FL', '33629', 'US', '-5'),
#  (2, datetime.datetime(2013, 4, 25, 22, 25, 3), datetime.datetime(2015, 1, 28, 20, 52, 4), 2, 1, 0, None, None, None, 1, 'ce26ea92-7144-11e5-ba71-058fbc01cf0b', 'New York', 'NY', '10075', 'US', '-5'),
#  (2, datetime.datetime(2013, 4, 25, 23, 25, 56), datetime.datetime(2015, 1, 28, 20, 52, 4), 1, 1, 0, None, None, None, 1, 'ce26ec18-7144-11e5-ba71-058fbc01cf0b', 'Orlando', 'FL', '32832', 'US', '-5'),
#  (2, datetime.datetime(2013, 4, 25, 23, 31, 54), datetime.datetime(2015, 1, 28, 20, 52, 4), 2, 2, 0, None, None, None, 2, 'ce26ec7c-7144-11e5-ba71-058fbc01cf0b', 'West Palm Beach', 'FL', '33407', 'US', '-5'),
#  (3, datetime.datetime(2013, 4, 25, 23, 52, 19), datetime.datetime(2015, 1, 28, 20, 52, 4), 1, 2, 0, None, None, None, 2, 'ce26ecd6-7144-11e5-ba71-058fbc01cf0b', 'Portland', 'OR', '97221', 'US', '-8'),
#  (13, datetime.datetime(2013, 4, 26, 1, 2, 43), datetime.datetime(2015, 2, 25, 16, 42, 39), 1, 2, 1, None, None, datetime.datetime(2015, 2, 25, 16, 42, 39), 2, 'ce26edbc-7144-11e5-ba71-058fbc01cf0b', 'New York', 'NY', '10008', 'US', '-5'),
#  (3, datetime.datetime(2013, 4, 26, 1, 31, 51), datetime.datetime(2015, 1, 28, 20, 52, 4), 1, 1, 0, None, None, datetime.datetime(2014, 6, 3, 1, 57, 56), 1, 'ce26ee84-7144-11e5-ba71-058fbc01cf0b', 'Baltimore', 'MD', '21218', 'US', '-5'),
#  (10, datetime.datetime(2013, 4, 26, 2, 26, 30), datetime.datetime(2015, 5, 20, 2, 29, 22), 1, 1, 0, None, None, datetime.datetime(2015, 5, 20, 2, 29, 22), 1, 'ce26ef42-7144-11e5-ba71-058fbc01cf0b', 'San Francisco', 'CA', '94114', 'US', '-8'),
#  (3, datetime.datetime(2013, 4, 26, 2, 27, 1), datetime.datetime(2015, 1, 28, 20, 52, 4), 1, 1, 0, None, None, None, 1, 'ce26efa6-7144-11e5-ba71-058fbc01cf0b', 'San Francisco', 'CA', '94131', 'US', '-8'),
#  (2, datetime.datetime(2013, 4, 26, 2, 55, 57), datetime.datetime(2015, 1, 28, 20, 52, 4), 1, 1, 0, None, None, None, 1, 'ce26f212-7144-11e5-ba71-058fbc01cf0b', 'Bend', 'OR', '97701', 'US', '-8'),
#  (22, datetime.datetime(2013, 4, 26, 3, 15, 55), datetime.datetime(2015, 2, 24, 19, 48, 53), 1, 2, 1, None, None, datetime.datetime(2015, 2, 24, 19, 48, 53), 2, 'ce26f276-7144-11e5-ba71-058fbc01cf0b', 'Bozeman', 'MT', '59715', 'US', '-7'),
#  (9, datetime.datetime(2013, 4, 26, 3, 44, 44), datetime.datetime(2015, 1, 28, 20, 52, 4), 1, 2, 1, None, None, datetime.datetime(2014, 4, 4, 2, 11, 5), 2, 'ce26f3a2-7144-11e5-ba71-058fbc01cf0b', 'Menlo Park', 'CA', '94025', 'US', '-8'),
#  (6, datetime.datetime(2013, 4, 26, 3, 41, 17), datetime.datetime(2015, 1, 28, 20, 52, 4), 1, 1, 1, None, None, datetime.datetime(2014, 2, 21, 19, 17, 48), 1, 'ce26f33e-7144-11e5-ba71-058fbc01cf0b', 'Kailua', 'HI', '96734', 'US', '-10'),
#  (10, datetime.datetime(2013, 4, 26, 6, 52, 2), datetime.datetime(2015, 1, 28, 20, 52, 4), 3, 2, 1, None, None, datetime.datetime(2014, 8, 27, 20, 27, 48), 2, 'ce26f438-7144-11e5-ba71-058fbc01cf0b', 'Vandoeuvres ', 'GE', '1253', 'CH', '#N/A'),
#  (10, datetime.datetime(2013, 4, 26, 6, 52, 2), datetime.datetime(2015, 1, 28, 20, 52, 4), 3, 2, 1, None, None, datetime.datetime(2014, 8, 27, 20, 27, 48), 2, 'ce26f438-7144-11e5-ba71-058fbc01cf0b', 'Vandoeuvres ', 'GE', '1253', 'CH', '#N/A'),
#  ...]

# %% [markdown]
# ## You have already learned how to see all the data in your database!  Congratulations!
#
# Feel free to practice any other queries you are interested in below:
