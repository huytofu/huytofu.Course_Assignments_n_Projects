# %% [markdown]
# Copyright Jana Schaich Borg/Attribution-NonCommercial 4.0 International (CC BY-NC 4.0)

# %% [markdown]
# # MySQL Exercise 5: Summaries of Groups of Data
#
# So far you've learned how to select, reformat, manipulate, order, and summarize data from a single table in database.  In this lesson, you are going to learn how to summarize multiple subsets of your data in the same query.  The method for doing this is to include a "GROUP BY" clause in your SQL query.
#
#
#
# ## The GROUP BY clause
#
# The GROUP BY clause comes after the WHERE clause, but before ORDER BY or LIMIT:
#
# <img src="https://duke.box.com/shared/static/lc0yjfz1339q3mc04ne13m2q5tkzy3x7.jpg" width=400 alt="SELECT FROM WHERE ORDER BY" />
#
# The GROUP BY clause is easy to incorporate into your queries.  In fact, it might be a little too easy to incorporate into MySQL queries, because it can be used incorrectly in MySQL queries even when no error message is displayed.  As a consequence, I suggest you adopt a healthy dose of caution every time you use the GROUP BY clause.  By the end of this lesson, you will understand why.  When used correctly, though, GROUP BY is one of the most useful and efficient parts of an SQL query, and once you are comfortable using it, you will use it very frequently.
#
# **To get started, load the SQL library and the Dognition database, and set the dognition database as the default:**

# %%
# %load_ext sql
# %sql mysql://studentuser:studentpw@mysqlserver/dognitiondb
# %sql USE dognitiondb
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# 0 rows affected.
# []

# %% [markdown]
# Let's return to a question from MySQL Exercise 4.  How would you query the average rating for each of the 40 tests in the Reviews table? As we discussed, one very inefficient method to do that would be to write 40 separate queries with each one having a different test name in the WHERE conditional clause.  Then you could copy or transcribe the results from all 40 queries into one place.  But that wouldn't be very pleasant.  Here's how you could do the same thing using one query that has a GROUP BY clause:
#
# ```mySQL
# SELECT test_name, AVG(rating) AS AVG_Rating
# FROM reviews
# GROUP BY test_name
# ```
#
# This query will output the average rating for each test.  More technically, this query will instruct MySQL to average all the rows that have the same value in the test_name column.
#
# Notice that I included test_name in the SELECT statement.  As a strong rule of thumb, if you are grouping by a column, you should also include that column in the SELECT statement.  If you don't do this, you won't know to which group each row of your output corresponds.
#
# **To see what I mean, try the query above without test_name included in the SELECT statement:**

# %% [markdown]
# You can form groups using derived values as well as original columns.  To illustrate this, let's address another question: how many tests were completed during each month of the year?
#
# To answer this question, we need to take advantage of another datetime function described in the website below:
#
# http://www.w3resource.com/mysql/date-and-time-functions/date-and-time-functions.php
#
# MONTH() will return a number representing the month of a date entry. To get the total number of tests completed each month, you could put the MONTH function into the GROUP BY clause, in this case through an alias:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY Month;
# ```
#
# You can also group by multiple columns or derived fields.  If we wanted to determine the total number of each type of test completed each month, you could include both "test_name" and the derived "Month" field in the GROUP BY clause, separated by a comma.
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY test_name, Month;
# ```
#
# MySQL allows you to use aliases in a GROUP BY clause, but some database systems do not.  If you are using a database system that does NOT accept aliases in GROUP BY clauses, you can still group by derived fields, but you have to duplicate the calculation for the derived field in the GROUP BY clause in addition to including the derived field in the SELECT clause:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY test_name, MONTH(created_at);
# ```
#
# Try the query once with test_name first in the GROUP BY list, and once with Month first in the GROUP BY list below.  Inspect the outputs:

# %%
# %sql describe dogs
# Out:
# 21 rows affected.
# [('gender', 'varchar(255)', 'YES', '', None, ''),
#  ('birthday', 'varchar(255)', 'YES', '', None, ''),
#  ('breed', 'varchar(255)', 'YES', '', None, ''),
#  ('weight', 'int(11)', 'YES', '', None, ''),
#  ('dog_fixed', 'tinyint(1)', 'YES', '', None, ''),
#  ('dna_tested', 'tinyint(1)', 'YES', '', None, ''),
#  ('created_at', 'datetime', 'NO', '', None, ''),
#  ('updated_at', 'datetime', 'NO', '', None, ''),
#  ('dimension', 'varchar(255)', 'YES', '', None, ''),
#  ('exclude', 'tinyint(1)', 'YES', '', None, ''),
#  ('breed_type', 'varchar(255)', 'YES', '', None, ''),
#  ('breed_group', 'varchar(255)', 'YES', '', None, ''),
#  ('dog_guid', 'varchar(60)', 'YES', 'MUL', None, ''),
#  ('user_guid', 'varchar(60)', 'YES', 'MUL', None, ''),
#  ('total_tests_completed', 'varchar(255)', 'YES', '', None, ''),
#  ('mean_iti_days', 'varchar(255)', 'YES', '', None, ''),
#  ('mean_iti_minutes', 'varchar(255)', 'YES', '', None, ''),
#  ('median_iti_days', 'varchar(255)', 'YES', '', None, ''),
#  ('median_iti_minutes', 'varchar(255)', 'YES', '', None, ''),
#  ('time_diff_between_first_and_last_game_days', 'varchar(255)', 'YES', '', None, ''),
#  ('time_diff_between_first_and_last_game_minutes', 'varchar(255)', 'YES', '', None, '')]

# %% [markdown]
# Notice that in the first case, the first block of rows share the same test_name, but are broken up into separate months (for those of you who took the "Data Visualization and Communication with Tableau" course of this specialization, this is similar to what would happen if you put test_name first and created_at second on the rows or columns shelf in Tableau).
#
# In the second case, the first block of rows share the same month, but are broken up into separate tests  (this is similar to what would happen if you put created_at first and test_name second on the rows or columns shelf in Tableau).  If you were to visualize these outputs, they would look like the charts below.
#
# <img src="https://duke.box.com/shared/static/y6l3ldxg289brid5mmn886qweglt65qv.jpg" width=800 alt="ORDER" />
#
# Different database servers might default to ordering the outputs in a certain way, but you shouldn't rely on that being the case.  To ensure the output is ordered in a way you intend, add an ORDER BY clause to your grouped query using the syntax you already know and have practiced:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY test_name, Month
# ORDER BY test_name ASC, Month ASC;
# ```
#
# **Question 1: Output a table that calculates the number of distinct female and male dogs in each breed group of the Dogs table, sorted by the total number of dogs in descending order (the sex/breed_group pair with the greatest number of dogs should have 8466 unique Dog_Guids):**

# %%
# %%sql
# SELECT TRIM(LEADING '-' FROM breed_group) as trim_breedgroup, gender, count(DISTINCT dog_guid) as number_of_dogs
# FROM dogs
# GROUP BY gender, trim_breedgroup
# ORDER BY number_of_dogs DESC
# Out:
# 18 rows affected.
# [(None, 'male', 8466),
#  (None, 'female', 8367),
#  ('Sporting', 'male', 2584),
#  ('Sporting', 'female', 2262),
#  ('Herding', 'male', 1736),
#  ('Herding', 'female', 1704),
#  ('Toy', 'male', 1473),
#  ('Toy', 'female', 1145),
#  ('Non-Sporting', 'male', 1098),
#  ('Working', 'male', 1075),
#  ('Non-Sporting', 'female', 919),
#  ('Terrier', 'male', 919),
#  ('Working', 'female', 895),
#  ('Terrier', 'female', 794),
#  ('Hound', 'male', 725),
#  ('Hound', 'female', 614),
#  ('', 'male', 147),
#  ('', 'female', 127)]

# %% [markdown]
# Some database servers, including MySQL, allow you to use numbers in place of field names in the GROUP BY or ORDER BY fields to reduce the overall length of the queries.  I tend to avoid this abbreviated method of writing queries because I find it challenging to troubleshoot when you are writing complicated queries with many fields, but it does allow you to write queries faster.  To use this method, assign each field in your SELECT statement a number acording to the order the field appears in the SELECT statement.  In the following statement:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# ```
#
# test_name would be #1, Month would be #2, and Num_Completed_Tests would be #3.  You could then rewrite the query above to read:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY 1, 2
# ORDER BY 1 ASC, 2 ASC;
# ```
#
# **Question 2: Revise the query your wrote in Question 1 so that it uses only numbers in the GROUP BY and ORDER BY fields.**

# %%
# %%sql
# SELECT TRIM(LEADING '-' FROM breed_group) as trim_breedgroup, gender, count(DISTINCT dog_guid) as number_of_dogs
# FROM dogs
# GROUP BY 1, 2
# ORDER BY 3 DESC
# Out:
# 18 rows affected.
# [(None, 'male', 8466),
#  (None, 'female', 8367),
#  ('Sporting', 'male', 2584),
#  ('Sporting', 'female', 2262),
#  ('Herding', 'male', 1736),
#  ('Herding', 'female', 1704),
#  ('Toy', 'male', 1473),
#  ('Toy', 'female', 1145),
#  ('Non-Sporting', 'male', 1098),
#  ('Working', 'male', 1075),
#  ('Non-Sporting', 'female', 919),
#  ('Terrier', 'male', 919),
#  ('Working', 'female', 895),
#  ('Terrier', 'female', 794),
#  ('Hound', 'male', 725),
#  ('Hound', 'female', 614),
#  ('', 'male', 147),
#  ('', 'female', 127)]

# %% [markdown]
# ## The HAVING clause
#
# Just like you can query subsets of rows using the WHERE clause, you can query subsets of aggregated groups using the HAVING clause.  However, wheras the expression that follows a WHERE clause has to be applicable to each row of data in a column, the expression that follows a HAVING clause has to be applicable or computable using a group of data.
#
# If you wanted to examine the number of tests completed only during the winter holiday months of November and December, you would need to use a WHERE clause, because the month a test was completed in is recorded in each row.  Your query might look like this:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# WHERE MONTH(created_at)=11 OR MONTH(created_at)=12
# GROUP BY 1, 2
# ORDER BY 3 DESC;
# ```
# If you then wanted to output only the test-month pairs that had at least 20 records in them, you would add a HAVING clause, because the stipulation of at least 20 records only makes sense and is only computable at the aggregated group level:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# WHERE MONTH(created_at)=11 OR MONTH(created_at)=12
# GROUP BY 1, 2
# HAVING COUNT(created_at)>=20
# ORDER BY 3 DESC;
# ```
#
# **Question 3: Revise the query your wrote in Question 2 so that it (1) excludes the NULL and empty string entries in the breed_group field, and (2) excludes any groups that don't have at least 1,000 distinct Dog_Guids in them.  Your result should contain 8 rows.  (HINT: sometimes empty strings are registered as non-NULL values.  You might want to include the following line somewhere in your query to exclude these values as well):**
#
# ```mySQL
# breed_group!=""
# ```

# %%
# %%sql
# SELECT TRIM(LEADING '-' FROM breed_group) as trim_breedgroup, gender, count(DISTINCT dog_guid) as number_of_dogs
# FROM dogs
# GROUP BY 1, 2
# HAVING trim_breedgroup != "" and trim_breedgroup is not NULL and number_of_dogs >= 1000
# ORDER BY 3 DESC
# Out:
# 8 rows affected.
# [('Sporting', 'male', 2584),
#  ('Sporting', 'female', 2262),
#  ('Herding', 'male', 1736),
#  ('Herding', 'female', 1704),
#  ('Toy', 'male', 1473),
#  ('Toy', 'female', 1145),
#  ('Non-Sporting', 'male', 1098),
#  ('Working', 'male', 1075)]

# %% [markdown]
# We will review several issues that can be tricky about using GROUP BY in your queries in the next lesson, but those issues will make more sense once you are sure you are comfortable with the basic functionality of the GROUP BY and HAVING clauses.
#
#
#
# ## Practice incorporating GROUP BY and HAVING into your own queries.
#
# **Question 4: Write a query that outputs the average number of tests completed and average mean inter-test-interval for every breed type, sorted by the average number of completed tests in descending order (popular hybrid should be the first row in your output).**

# %%
# %sql describe exam_answers
# Out:
# 8 rows affected.
# [('script_detail_id', 'int(11)', 'YES', '', None, ''),
#  ('subcategory_name', 'varchar(255)', 'YES', '', None, ''),
#  ('test_name', 'varchar(255)', 'YES', '', None, ''),
#  ('step_type', 'varchar(255)', 'YES', '', None, ''),
#  ('start_time', 'datetime', 'YES', '', None, ''),
#  ('end_time', 'datetime', 'YES', '', None, ''),
#  ('loop_number', 'int(11)', 'YES', '', None, ''),
#  ('dog_guid', 'varchar(60)', 'YES', '', None, '')]

# %%
# %%sql
# SELECT TRIM(LEADING '-' FROM breed) as breed_fixed, AVG(total_tests_completed) as average_no_test_completed
# FROM dogs
# GROUP BY breed_fixed
# ORDER BY average_no_test_completed DESC
# Out:
# 2006 rows affected.
# [('Golden Retriever-Brittany Mix', 43.0),
#  ('Golden Retriever-Airedale Terrier Mix', 42.0),
#  ('Rhodesian Ridgeback-American Staffordshire Terrier Mix', 40.5),
#  ('Siberian Husky-German Shorthaired Pointer Mix', 35.0),
#  ('Portuguese Pointer', 34.0),
#  ('German Shepherd Dog-Gordon Setter Mix', 32.0),
#  ('Danish-Swedish Farmdog-Czechoslovakian Vlcak Mix', 31.0),
#  ('Australian Shepherd-Bloodhound Mix', 31.0),
#  ('Collie Mix', 30.0),
#  ('German Shepherd Dog-American Eskimo Dog Mix', 30.0),
#  ('Schapendoes', 30.0),
#  ('American Staffordshire Terrier-Australian Shepherd Mix', 28.0),
#  ('Tosa', 28.0),
#  ('Russell Terrier-Japanese Chin Mix', 28.0),
#  ('Chihuahua-American Staffordshire Terrier Mix', 27.0),
#  ('Border Collie-Great Dane Mix', 26.5),
#  ('Australian Cattle Dog-Curly-Coated Retriever Mix', 26.0),
#  ('American Eskimo Dog-Papillon Mix', 25.0),
#  ('Boston Terrier-Pug Mix', 25.0),
#  ('American Pit Bull Terrier-Bull Terrier Mix', 25.0),
#  ('Cardigan Welsh Corgi-Beagle Mix', 25.0),
#  ('Polish Lowland Sheepdog', 23.5),
#  ('Ibizan Hound', 23.5),
#  ('American Pit Bull Terrier- Mix', 23.5),
#  ('Basenji-Manchester Terrier Mix', 23.0),
#  ('American Pit Bull Terrier-Australian Shepherd Mix', 23.0),
#  ('Golden Retriever-St. Bernard Mix', 23.0),
#  ('Belgian Malinois-Chinese Shar-Pei Mix', 23.0),
#  ('American Eskimo Dog-Staffordshire Bull Terrier Mix', 23.0),
#  ('Border Collie-Whippet Mix', 22.5),
#  ('Labrador Retriever-Basenji Mix', 22.0),
#  ('Brittany-Poodle Mix', 22.0),
#  ('Boston Terrier-Bulldog Mix', 22.0),
#  ('Catahoula Leopard Dog-Rottweiler Mix', 22.0),
#  ('Greyhound-Pointer Mix', 22.0),
#  ('Bluetick Coonhound', 21.0),
#  ('English Cocker Spaniel-Cocker Spaniel Mix', 20.0),
#  ('Beagle-Cavalier King Charles Spaniel Mix', 20.0),
#  ('Canaan Dog- Mix', 20.0),
#  ('Labrador Retriever-Cane Corso Mix', 20.0),
#  ('Pembroke Welsh Corgi-Russell Terrier Mix', 20.0),
#  ('Labrador Retriever-Cardigan Welsh Corgi Mix', 20.0),
#  ('Pug-Maltese Mix', 20.0),
#  ('Alaskan Malamute-Collie Mix', 20.0),
#  ('Beagle- Mix', 20.0),
#  ('Bearded Collie-Beagle Mix', 20.0),
#  ('Dogue de Bordeaux-Boxer Mix', 20.0),
#  ('German Shepherd Dog Mix', 20.0),
#  ('Afghan Hound-Golden Retriever Mix', 20.0),
#  ('Brittany-German Shorthaired Pointer Mix', 20.0),
#  ('American Eskimo Dog-Russell Terrier Mix', 20.0),
#  ('Pekingese-Parson Russell Terrier Mix', 20.0),
#  ('Dachshund-Boston Terrier Mix', 20.0),
#  ('Redbone Coonhound-Bloodhound Mix', 20.0),
#  ('Chinese Shar-Pei-Labrador Retriever Mix', 20.0),
#  ('Pomeranian-Basenji Mix', 20.0),
#  ('Portuguese Podengo Pequeno', 20.0),
#  ('Australian Shepherd-Shih Tzu Mix', 20.0),
#  ('American Pit Bull Terrier-Boston Terrier Mix', 20.0),
#  ('Doberman Pinscher-Greyhound Mix', 20.0),
#  ('Redbone Coonhound-Rhodesian Ridgeback Mix', 20.0),
#  ('Catahoula Leopard Dog-Plott Mix', 20.0),
#  ('Poodle-Japanese Chin Mix', 20.0),
#  ('Great Pyrenees-Siberian Husky Mix', 20.0),
#  ('Dachshund-Pomeranian Mix', 20.0),
#  ('Poodle-Pomeranian Mix', 20.0),
#  ('Portuguese Podengo', 20.0),
#  ('Labrador Retriever-Flat-Coated Retriever Mix', 20.0),
#  ('Belgian Tervuren-Whippet Mix', 20.0),
#  ('Dogue de Bordeaux-Labrador Retriever Mix', 20.0),
#  ('Weimaraner-Bluetick Coonhound Mix', 20.0),
#  ('Jindo-German Shepherd Dog Mix', 20.0),
#  ('Dalmatian-American Pit Bull Terrier Mix', 20.0),
#  ('Pug-French Bulldog Mix', 20.0),
#  ('Bull Terrier-Staffordshire Bull Terrier Mix', 20.0),
#  ('Basset Hound-Beagle Mix', 20.0),
#  ('Perro de Presa Canario', 20.0),
#  ('Boxer-Siberian Husky Mix', 20.0),
#  ('Irish Wolfhound-Great Dane Mix', 20.0),
#  ('Border Collie-Boxer Mix', 20.0),
#  ('Irish Setter-Poodle Mix', 20.0),
#  ('Bullmastiff-Chinese Shar-Pei Mix', 20.0),
#  ('Greyhound-Saluki Mix', 20.0),
#  ('Greyhound-Scottish Deerhound Mix', 20.0),
#  ('Bernese Mountain Dog-Border Collie Mix', 20.0),
#  ('Border Collie-Belgian Sheepdog Mix', 20.0),
#  ('American Eskimo Dog-Australian Shepherd Mix', 20.0),
#  ('German Shepherd Dog-Shiba Inu Mix', 20.0),
#  ('Beagle-Chow Chow Mix', 20.0),
#  ('Beagle-Smooth Fox Terrier Mix', 20.0),
#  ('Airedale Terrier-German Shorthaired Pointer Mix', 20.0),
#  ('Miniature Schnauzer-Shih Tzu Mix', 20.0),
#  ('Rottweiler-Border Collie Mix', 20.0),
#  ('English Setter-Border Collie Mix', 20.0),
#  ('Yorkshire Terrier-Rat Terrier Mix', 20.0),
#  ('Lhasa Apso-Bichon Frise Mix', 20.0),
#  ('Belgian Malinois-Chow Chow Mix', 20.0),
#  ('German Shepherd Dog-Pug Mix', 20.0),
#  ('Pug-Pekingese Mix', 20.0),
#  ('Australian Terrier-Lowchen Mix', 20.0),
#  ('Cairn Terrier-Pomeranian Mix', 20.0),
#  ('Australian Cattle Dog-Catahoula Leopard Dog Mix', 20.0),
#  ('Belgian Malinois-German Shepherd Dog Mix', 20.0),
#  ('Affenpinscher-Brussels Griffon Mix', 20.0),
#  ('Australian Shepherd-Flat-Coated Retriever Mix', 20.0),
#  ('Giant Schnauzer-American Eskimo Dog Mix', 20.0),
#  ('Akita-Labrador Retriever Mix', 20.0),
#  ('American Staffordshire Terrier-Dogo Argentino Mix', 20.0),
#  ('Cairn Terrier-Airedale Terrier Mix', 20.0),
#  ('German Shepherd Dog-Keeshond Mix', 20.0),
#  ('Border Terrier-Cairn Terrier Mix', 20.0),
#  ('Beagle-Shetland Sheepdog Mix', 20.0),
#  ('Whippet-Beagle Mix', 20.0),
#  ('Chinook-German Shepherd Dog Mix', 20.0),
#  ('Nova Scotia Duck Tolling Retriever-Chihuahua Mix', 20.0),
#  ('Miniature Pinscher-Basenji Mix', 20.0),
#  ('Labrador Retriever-Bichon Frise Mix', 20.0),
#  ('Bullmastiff-Labrador Retriever Mix', 20.0),
#  ('Border Terrier-West Highland White Terrier Mix', 20.0),
#  ('Cavalier King Charles Spaniel-Pekingese Mix', 20.0),
#  ('Treeing Walker Coonhound-Parson Russell Terrier Mix', 20.0),
#  ('Parson Russell Terrier-Maltese Mix', 20.0),
#  ('Welsh Terrier-Miniature Schnauzer Mix', 20.0),
#  ('Papillon-Chihuahua Mix', 20.0),
#  ('Papillon-German Spitz Mix', 20.0),
#  ('Miniature Schnauzer-Labrador Retriever Mix', 20.0),
#  ('Labrador Retriever-Belgian Malinois Mix', 20.0),
#  ('Doberman Pinscher-Dalmatian Mix', 20.0),
#  ('Poodle-Bernese Mountain Dog Mix', 20.0),
#  ('German Shepherd Dog-Bloodhound Mix', 20.0),
#  ('Beagle-Chinese Shar-Pei Mix', 20.0),
#  ('Flat-Coated Retriever-Irish Water Spaniel Mix', 20.0),
#  ('Australian Cattle Dog-Bearded Collie Mix', 20.0),
#  ('Border Collie-Borzoi Mix', 20.0),
#  ('Chihuahua-Boston Terrier Mix', 20.0),
#  ('German Shorthaired Pointer-German Longhaired Pointer Mix', 20.0),
#  ('Miniature Schnauzer-Russell Terrier Mix', 20.0),
#  ('American Staffordshire Terrier-Treeing Walker Coonhound Mix', 20.0),
#  ('Redbone Coonhound-Australian Shepherd Mix', 20.0),
#  ('American Pit Bull Terrier-Dogue de Bordeaux Mix', 20.0),
#  ('Pembroke Welsh Corgi-Border Collie Mix', 20.0),
#  ('Brittany-Basset Hound Mix', 20.0),
#  ('Border Collie-Bull Terrier Mix', 20.0),
#  ('Siberian Husky-Mastiff Mix', 20.0),
#  ('Rottweiler-Greater Swiss Mountain Dog Mix', 20.0),
#  ('Pug-Poodle Mix', 20.0),
#  ('Havanese-Coton de Tulear Mix', 20.0),
#  ('Whippet-Rhodesian Ridgeback Mix', 20.0),
#  ('Pomeranian-Boston Terrier Mix', 20.0),
#  ('Pomeranian-Anatolian Shepherd Dog Mix', 20.0),
#  ('Jack Russell Terrier-Labrador Retriever Mix', 20.0),
#  ('Australian Cattle Dog-Redbone Coonhound Mix', 20.0),
#  ('Beagle-Greyhound Mix', 20.0),
#  ('Basenji-English Springer Spaniel Mix', 20.0),
#  ('American English Coonhound', 20.0),
#  ('Standard Poodle-Irish Setter Mix', 20.0),
#  ('American Hairless Terrier-Shetland Sheepdog Mix', 20.0),
#  ('Beagle-Boston Terrier Mix', 20.0),
#  ('American Pit Bull Terrier-Border Collie Mix', 20.0),
#  ('Pug-Cocker Spaniel Mix', 20.0),
#  ('Cardigan Welsh Corgi-Catahoula Leopard Dog Mix', 20.0),
#  ('Chinese Shar-Pei-Cocker Spaniel Mix', 20.0),
#  ('Jack Russell Terrier-Cavalier King Charles Spaniel Mix', 20.0),
#  ('Wire Fox Terrier-Italian Greyhound Mix', 20.0),
#  ('Border Collie-Great Pyrenees Mix', 20.0),
#  ('Rat Terrier-Yorkshire Terrier Mix', 20.0),
#  ('Silky Terrier-Schipperke Mix', 20.0),
#  ('Saluki-Greyhound Mix', 20.0),
#  ('Keeshond-German Shepherd Dog Mix', 20.0),
#  ('Dachshund-Staffordshire Bull Terrier Mix', 20.0),
#  ('Australian Cattle Dog-Treeing Walker Coonhound Mix', 20.0),
#  ('Basset Hound-American Staffordshire Terrier Mix', 20.0),
#  ('Siberian Husky-American English Coonhound Mix', 20.0),
#  ('American Staffordshire Terrier-Staffordshire Bull Terrier Mix', 20.0),
#  ('French Spaniel-German Shorthaired Pointer Mix', 20.0),
#  ('Siberian Husky-Keeshond Mix', 20.0),
#  ('Chihuahua-Miniature Australian Shepherd Mix', 20.0),
#  ('Shetland Sheepdog-Cairn Terrier Mix', 20.0),
#  ('Newfoundland-Poodle Mix', 20.0),
#  ('Vizsla-Dachshund Mix', 20.0),
#  ('Border Collie-Bernese Mountain Dog Mix', 20.0),
#  ('Cocker Spaniel-Labrador Retriever Mix', 20.0),
#  ('Pointer-Bracco Italiano Mix', 20.0),
#  ('Chihuahua-Manchester Terrier Mix', 20.0),
#  ('American Pit Bull Terrier-Whippet Mix', 20.0),
#  ('Basset Hound-Pointer Mix', 20.0),
#  ('Labrador Retriever-English Cocker Spaniel Mix', 20.0),
#  ('Bernese Mountain Dog-Standard Poodle Mix', 20.0),
#  ('Newfoundland-Standard Poodle Mix', 20.0),
#  ('Border Terrier-Standard Schnauzer Mix', 20.0),
#  ('Jack Russell Terrier-Shih Tzu Mix', 20.0),
#  ('Border Collie-Cavalier King Charles Spaniel Mix', 20.0),
#  ('Chow Chow-American Pit Bull Terrier Mix', 20.0),
#  ('Miniature Australian Shepherd-Shetland Sheepdog Mix', 20.0),
#  ('Jack Russell Terrier-German Shepherd Dog Mix', 20.0),
#  ('Jack Russell Terrier-Whippet Mix', 20.0),
#  ('Poodle-German Wirehaired Pointer Mix', 20.0),
#  ('Entlebucher Mountain Dog', 19.5),
#  ('Australian Cattle Dog-Rottweiler Mix', 19.0),
#  ('Australian Shepherd-Pembroke Welsh Corgi Mix', 18.5),
#  ('Labrador Retriever Mix', 18.5),
#  ('Rhodesian Ridgeback-Boxer Mix', 18.0),
#  ('Chow Chow-Cocker Spaniel Mix', 18.0),
#  ('Siberian Husky-American Pit Bull Terrier Mix', 18.0),
#  ('Brittany-Golden Retriever Mix', 18.0),
#  ('Jack Russell Terrier-Manchester Terrier Mix', 18.0),
#  ('Border Terrier- Mix', 17.0),
#  ('Border Collie-Staffordshire Bull Terrier Mix', 17.0),
#  ('Beagle-Pekingese Mix', 17.0),
#  ('Dachshund-Golden Retriever Mix', 17.0),
#  ('Beagle-Treeing Walker Coonhound Mix', 17.0),
#  ('Tibetan Terrier-Jack Russell Terrier Mix', 17.0),
#  ('Shih Tzu-Bull Terrier Mix', 17.0),
#  ('German Shepherd Dog-Treeing Walker Coonhound Mix', 17.0),
#  ('Bearded Collie-Tibetan Terrier Mix', 16.0),
#  ('Pug-Chihuahua Mix', 16.0),
#  ('American Pit Bull Terrier-Pointer Mix', 16.0),
#  ('Puli', 16.0),
#  ('Old English Sheepdog-Poodle Mix', 16.0),
#  ('Bernese Mountain Dog-Poodle Mix', 16.0),
#  ('Parson Russell Terrier-Russell Terrier Mix', 16.0),
#  ('Parson Russell Terrier-Poodle Mix', 16.0),
#  ('Cirneco dell"Etna', 16.0),
#  ('Poodle-Border Collie Mix', 16.0),
#  ('Italian Greyhound-Rat Terrier Mix', 16.0),
#  ('Brussels Griffon-Pug Mix', 16.0),
#  ('Yorkshire Terrier-Pomeranian Mix', 16.0),
#  ('Rhodesian Ridgeback-Vizsla Mix', 16.0),
#  ('Bulldog-Mastiff Mix', 16.0),
#  ('Boxer-Poodle Mix', 16.0),
#  ('Miniature Schnauzer-West Highland White Terrier Mix', 16.0),
#  ('Boston Terrier-Russell Terrier Mix', 16.0),
#  ('Maltese-Havanese Mix', 16.0),
#  ('Great Pyrenees-Bernese Mountain Dog Mix', 16.0),
#  ('Treeing Walker Coonhound-Pointer Mix', 16.0),
#  ('Wire Fox Terrier-Dachshund Mix', 16.0),
#  ('Border Collie-German Shorthaired Pointer Mix', 16.0),
#  ('Toy Fox Terrier-Australian Shepherd Mix', 16.0),
#  ('Wire Fox Terrier-Bulldog Mix', 16.0),
#  ('Belgian Sheepdog-Chow Chow Mix', 16.0),
#  ('Whippet-Rat Terrier Mix', 16.0),
#  ('Hovawart-German Shepherd Dog Mix', 16.0),
#  ('Labrador Retriever-Airedale Terrier Mix', 16.0),
#  ('Airedale Terrier-Catahoula Leopard Dog Mix', 16.0),
#  ('American Eskimo Dog-Pomeranian Mix', 15.75),
#  ('Pug-Beagle Mix', 15.666666666666666),
#  ('Chesapeake Bay Retriever-Labrador Retriever Mix', 15.666666666666666),
#  ('Pug-Miniature Pinscher Mix', 15.5),
#  ('St. Bernard-Labrador Retriever Mix', 15.5),
#  ('Norwegian Buhund', 15.5),
#  ('American Staffordshire Terrier-Bullmastiff Mix', 15.5),
#  ('German Shepherd Dog-Australian Cattle Dog Mix', 15.5),
#  ('Cavalier King Charles Spaniel-Cocker Spaniel Mix', 15.5),
#  ('German Shepherd Dog-American Staffordshire Terrier Mix', 15.5),
#  ('Standard Schnauzer-Poodle Mix', 15.5),
#  ('Beagle-Poodle Mix', 15.5),
#  ('Black and Tan Coonhound-Labrador Retriever Mix', 15.5),
#  ('Australian Cattle Dog-Border Collie Mix', 15.285714285714286),
#  ('Labrador Retriever-Golden Retriever Mix', 15.098445595854923),
#  ('Golden Retriever-Collie Mix', 15.0),
#  ('Cardigan Welsh Corgi-German Shepherd Dog Mix', 15.0),
#  ('Cocker Spaniel-Bichon Frise Mix', 15.0),
#  ('Chihuahua-Poodle Mix', 15.0),
#  ('Border Collie-American Foxhound Mix', 15.0),
#  ('Australian Shepherd-Cocker Spaniel Mix', 15.0),
#  ('Keeshond-American Eskimo Dog Mix', 15.0),
#  ('Pomeranian-Toy Fox Terrier Mix', 15.0),
#  ('Rottweiler-Australian Cattle Dog Mix', 15.0),
#  ('German Shepherd Dog-Basset Hound Mix', 15.0),
#  ('Australian Kelpie-Border Collie Mix', 15.0),
#  ('American Staffordshire Terrier-Lancashire Heeler Mix', 15.0),
#  ('St. Bernard-Standard Poodle Mix', 15.0),
#  ('Siberian Husky-Australian Shepherd Mix', 14.666666666666666),
#  ('Border Collie-Australian Cattle Dog Mix', 14.666666666666666),
#  ('Beauceron', 14.666666666666666),
#  ('Vizsla- Mix', 14.5),
#  ('Tibetan Spaniel', 14.5),
#  ('Akita-Siberian Husky Mix', 14.5),
#  ('Pointer-Labrador Retriever Mix', 14.333333333333334),
#  ('Shetland Sheepdog-Border Collie Mix', 14.333333333333334),
#  ('Smooth Fox Terrier', 14.333333333333334),
#  ('Labrador Retriever-Great Dane Mix', 14.333333333333334),
#  ('Bouvier des Flandres', 14.304347826086957),
#  ('German Shepherd Dog-Pembroke Welsh Corgi Mix', 14.0),
#  ('Beagle-Schipperke Mix', 14.0),
#  ('German Shepherd Dog-Belgian Tervuren Mix', 14.0),
#  ('Affenpinscher', 14.0),
#  ('Yorkshire Terrier- Mix', 14.0),
#  ('American Water Spaniel', 14.0),
#  ('Poodle-Lhasa Apso Mix', 14.0),
#  ('Miniature Pinscher-Chihuahua Mix', 14.0),
#  ('Collie-German Shepherd Dog Mix', 14.0),
#  ('German Shepherd Dog-Central Asian Shepherd Dog Mix', 14.0),
#  ('Australian Cattle Dog-Beagle Mix', 14.0),
#  ('German Shepherd Dog-Rhodesian Ridgeback Mix', 14.0),
#  ('American Staffordshire Terrier-Rhodesian Ridgeback Mix', 14.0),
#  ('Samoyed-Shetland Sheepdog Mix', 14.0),
#  ('Basset Hound-Australian Shepherd Mix', 14.0),
#  ('Australian Shepherd-Bearded Collie Mix', 14.0),
#  ('Pomeranian-American Eskimo Dog Mix', 14.0),
#  ('Golden Retriever-Bullmastiff Mix', 14.0),
#  ('American Pit Bull Terrier-Staffordshire Bull Terrier Mix', 14.0),
#  ('Miniature Schnauzer-Miniature Australian Shepherd Mix', 14.0),
#  ('Golden Retriever-Plott Mix', 14.0),
#  ('Beagle-Miniature Schnauzer Mix', 14.0),
#  ('Boston Terrier-American Staffordshire Terrier Mix', 14.0),
#  ('Toy Fox Terrier-Shih Tzu Mix', 14.0),
#  ('German Shorthaired Pointer-Rottweiler Mix', 14.0),
#  ('Mastiff-Flat-Coated Retriever Mix', 14.0),
#  ('Giant Schnauzer', 13.875),
#  ('Golden Retriever-Labrador Retriever Mix', 13.79245283018868),
#  ('Labrador Retriever-Collie Mix', 13.75),
#  ('Poodle-Old English Sheepdog Mix', 13.5),
#  ('Pug-Wire Fox Terrier Mix', 13.5),
#  ('Chinese Crested-Poodle Mix', 13.5),
#  ('Field Spaniel', 13.5),
#  ('Russell Terrier-Beagle Mix', 13.5),
#  ('Flat-Coated Retriever- Mix', 13.5),
#  ('Rat Terrier-Chihuahua Mix', 13.5),
#  ('Rat Terrier-Russell Terrier Mix', 13.5),
#  ('Golden Retriever-Chow Chow Mix', 13.5),
#  ('Yorkshire Terrier-Silky Terrier Mix', 13.5),
#  ('Belgian Malinois-Siberian Husky Mix', 13.5),
#  ('Bichon Frise-Cocker Spaniel Mix', 13.5),
#  ('Pomeranian-Rat Terrier Mix', 13.5),
#  ('Poodle-Havanese Mix', 13.5),
#  ('Kooikerhondje', 13.4),
#  ('German Shorthaired Pointer-Labrador Retriever Mix', 13.4),
#  ('Icelandic Sheepdog', 13.375),
#  ('Chihuahua-Italian Greyhound Mix', 13.333333333333334),
#  ('Komondor', 13.333333333333334),
#  ('Australian Terrier', 13.23076923076923),
#  ('Chihuahua-Russell Terrier Mix', 13.2),
#  ('Pyrenean Shepherd', 13.142857142857142),
#  ('Norwegian Elkhound', 13.0),
#  ('Afghan Hound', 13.0),
#  ('Cocker Spaniel-Cavalier King Charles Spaniel Mix', 13.0),
#  ('German Longhaired Pointer', 13.0),
#  ('Golden Retriever-Basset Hound Mix', 13.0),
#  ('Shih Tzu-Dachshund Mix', 13.0),
#  ('Border Collie-Brittany Mix', 13.0),
#  ('Golden Retriever-Pembroke Welsh Corgi Mix', 13.0),
#  ('American Pit Bull Terrier-Bullmastiff Mix', 13.0),
#  ('Staffordshire Bull Terrier-Australian Cattle Dog Mix', 13.0),
#  ('Shetland Sheepdog-Collie Mix', 13.0),
#  ('Cocker Spaniel-Miniature Pinscher Mix', 13.0),
#  ('Dogo Argentino-American Pit Bull Terrier Mix', 13.0),
#  ('Ibizan Hound-Greyhound Mix', 13.0),
#  ('Scottish Terrier', 12.894736842105264),
#  ('German Shepherd Dog-Rottweiler Mix', 12.857142857142858),
#  ('Labrador Retriever-Australian Cattle Dog Mix', 12.833333333333334),
#  ('Chow Chow-Labrador Retriever Mix', 12.75),
#  ('Border Collie-Shetland Sheepdog Mix', 12.75),
#  ('Karelian Bear Dog', 12.666666666666666),
#  ('Pekingese-Poodle Mix', 12.5),
#  ('Bernese Mountain Dog-Great Pyrenees Mix', 12.5),
#  ('Pug-Boston Terrier Mix', 12.5),
#  ('Labrador Retriever-Rhodesian Ridgeback Mix', 12.5),
#  ('Miniature Schnauzer-Poodle Mix', 12.4375),
#  ('Australian Kelpie', 12.428571428571429),
#  ('Labrador Retriever- Mix', 12.25),
#  ('Wirehaired Pointing Griffon', 12.25),
#  ('Labrador Retriever-Weimaraner Mix', 12.2),
#  ('Bichon Frise-Shih Tzu Mix', 12.1875),
#  ('Samoyed', 12.185185185185185),
#  ('Australian Shepherd-Australian Cattle Dog Mix', 12.125),
#  ('Pembroke Welsh Corgi', 12.012195121951219),
#  ('German Shepherd Dog-Border Collie Mix', 12.0),
#  ('Great Dane-Labrador Retriever Mix', 12.0),
#  ('Danish-Swedish Farmdog', 12.0),
#  ('Pekingese-Dachshund Mix', 12.0),
#  ('American Pit Bull Terrier-Australian Cattle Dog Mix', 12.0),
#  ('Dachshund-Yorkshire Terrier Mix', 12.0),
#  ('Spanish Water Dog', 12.0),
#  ('Shih Tzu-Pomeranian Mix', 12.0),
#  ('Beagle-Dachshund Mix', 12.0),
#  ('Siberian Husky-Rottweiler Mix', 12.0),
#  ('Australian Cattle Dog-Siberian Husky Mix', 12.0),
#  ('Border Collie-American Pit Bull Terrier Mix', 12.0),
#  ('Beagle-Chihuahua Mix', 12.0),
#  ('Catahoula Leopard Dog-Boxer Mix', 12.0),
#  ('Poodle-American Pit Bull Terrier Mix', 12.0),
#  ('Miniature Schnauzer-Wire Fox Terrier Mix', 12.0),
#  ('Whippet-Greyhound Mix', 12.0),
#  ('Tibetan Spaniel-Papillon Mix', 12.0),
#  ('Bichon Frise-Cavalier King Charles Spaniel Mix', 11.88888888888889),
#  ('Poodle-Cavalier King Charles Spaniel Mix', 11.875),
#  ('Siberian Husky-German Shepherd Dog Mix', 11.823529411764707),
#  ('Cockapoo', 11.808080808080808),
#  ('Shetland Sheepdog', 11.757352941176471),
#  ('Beagle-Bluetick Coonhound Mix', 11.75),
#  ('English Cocker Spaniel', 11.735294117647058),
#  ('Australian Cattle Dog- Mix', 11.666666666666666),
#  ('Labrador Retriever-Rottweiler Mix', 11.666666666666666),
#  ('Russell Terrier-Shih Tzu Mix', 11.666666666666666),
#  ('Dachshund-Poodle Mix', 11.666666666666666),
#  ('Lowchen', 11.666666666666666),
#  ('Labrador Retriever-Pointer Mix', 11.666666666666666),
#  ('Labrador Retriever-Mastiff Mix', 11.666666666666666),
#  ('Beagle-Parson Russell Terrier Mix', 11.666666666666666),
#  ('Australian Cattle Dog-German Shepherd Dog Mix', 11.636363636363637),
#  ('Belgian Malinois', 11.625),
#  ('Norfolk Terrier', 11.625),
#  ('Collie-Shetland Sheepdog Mix', 11.5),
#  ('Poodle-Maltese Mix', 11.5),
#  ('Boxer-Vizsla Mix', 11.5),
#  ('German Shepherd Dog-Doberman Pinscher Mix', 11.5),
#  ('Smooth Fox Terrier-Whippet Mix', 11.5),
#  ('Shorkie', 11.4),
#  ('Portuguese Water Dog', 11.383561643835616),
#  ('Miniature American Shepherd', 11.37037037037037),
#  ('Australian Labradoodle', 11.342105263157896),
#  ('Australian Shepherd', 11.3342939481268),
#  ('French Spaniel', 11.333333333333334),
#  ('German Shepherd Dog-Boxer Mix', 11.333333333333334),
#  ('Siberian Husky-American Staffordshire Terrier Mix', 11.333333333333334),
#  ('Border Collie-Greyhound Mix', 11.25),
#  ('Australian Shepherd-Poodle Mix', 11.23076923076923),
#  ('American Eskimo Dog', 11.083333333333334),
#  ('Soft Coated Wheaten Terrier', 11.08),
#  ('Doberman Pinscher', 11.074766355140186),
#  ('Golden Retriever-Poodle Mix', 11.03125),
#  ('Maltese-Yorkshire Terrier Mix', 11.030303030303031),
#  ('Coton de Tulear', 11.026315789473685),
#  ('German Shepherd Dog-Nova Scotia Duck Tolling Retriever Mix', 11.0),
#  ('Finnish Spitz', 11.0),
#  ('Russell Terrier-Miniature Pinscher Mix', 11.0),
#  ('Pug-Smooth Fox Terrier Mix', 11.0),
#  ('Poodle-Dachshund Mix', 11.0),
#  ('Border Collie-Pembroke Welsh Corgi Mix', 11.0),
#  ('Kerry Blue Terrier', 11.0),
#  ('Briard', 11.0),
#  ('German Shepherd Dog-Poodle Mix', 11.0),
#  ('Border Collie-Saluki Mix', 11.0),
#  ('Whippet-German Shepherd Dog Mix', 11.0),
#  ('Dachshund-Doberman Pinscher Mix', 11.0),
#  ('American Pit Bull Terrier-Mastiff Mix', 11.0),
#  ('Pumi', 11.0),
#  ('Labrador Retriever-Boxer Mix', 11.0),
#  ('Poodle-Chihuahua Mix', 11.0),
#  ('Australian Cattle Dog-Anatolian Shepherd Dog Mix', 11.0),
#  ('Border Collie-Collie Mix', 11.0),
#  ('Chinese Shar-Pei-Boerboel Mix', 11.0),
#  ('Border Collie-Flat-Coated Retriever Mix', 11.0),
#  ('Boxer-Golden Retriever Mix', 11.0),
#  ('Miniature Schnauzer-Cairn Terrier Mix', 11.0),
#  ('Bernese Mountain Dog-Rottweiler Mix', 11.0),
#  ('Airedale Terrier-German Shepherd Dog Mix', 11.0),
#  ('Beagle-Golden Retriever Mix', 11.0),
#  ('Silky Terrier-Lhasa Apso Mix', 11.0),
#  ('Cavalier King Charles Spaniel-Australian Shepherd Mix', 11.0),
#  ('Labrador Retriever-Catahoula Leopard Dog Mix', 11.0),
#  ('Basset Hound-Australian Cattle Dog Mix', 11.0),
#  ('Cocker Spaniel-Pug Mix', 11.0),
#  ('German Shepherd Dog-Shetland Sheepdog Mix', 11.0),
#  ('American Pit Bull Terrier-Cane Corso Mix', 11.0),
#  ('American Pit Bull Terrier-Treeing Tennessee Brindle Mix', 11.0),
#  ('Rottweiler-Komondor Mix', 11.0),
#  ('Miniature Australian Shepherd', 11.0),
#  ('German Shepherd Dog-Black and Tan Coonhound Mix', 11.0),
#  ('Papillon-English Springer Spaniel Mix', 11.0),
#  ('Mastiff-Great Pyrenees Mix', 11.0),
#  ('Bichon Frise-Miniature Schnauzer Mix', 11.0),
#  ('Australian Cattle Dog-Bull Terrier Mix', 11.0),
#  ('Siberian Husky-Greyhound Mix', 11.0),
#  ('Border Collie-Rhodesian Ridgeback Mix', 11.0),
#  ('Yorkshire Terrier-Havanese Mix', 11.0),
#  ('Border Collie-Pointer Mix', 11.0),
#  ('Bloodhound-Bull Terrier Mix', 11.0),
#  ('Yorkshire Terrier-Belgian Malinois Mix', 11.0),
#  ('Dalmatian-Australian Shepherd Mix', 11.0),
#  ('Boxer-Australian Shepherd Mix', 11.0),
#  ('Border Collie-Standard Poodle Mix', 11.0),
#  ('Treeing Walker Coonhound-Great Dane Mix', 11.0),
#  ('Brittany', 10.944444444444445),
#  ('Collie', 10.944444444444445),
#  ('English Setter', 10.875),
#  ('Irish Terrier', 10.857142857142858),
#  ('Gordon Setter', 10.833333333333334),
#  ('Boykin Spaniel', 10.8),
#  ('American Pit Bull Terrier-Boxer Mix', 10.8),
#  ('Irish Water Spaniel', 10.8),
#  ('American Staffordshire Terrier-Bulldog Mix', 10.8),
#  ('Nova Scotia Duck Tolling Retriever', 10.758620689655173),
#  ('Doberman Pinscher-German Shepherd Dog Mix', 10.75),
#  ('Poodle', 10.732782369146005),
#  ('Irish Red and White Setter', 10.666666666666666),
#  ('Swedish Vallhund', 10.666666666666666),
#  ('Black and Tan Coonhound', 10.666666666666666),
#  ('Yorkshire Terrier-Shih Tzu Mix', 10.666666666666666),
#  ('Australian Shepherd-German Shepherd Dog Mix', 10.6),
#  ('Border Collie-German Shepherd Dog Mix', 10.583333333333334),
#  ('Labrador Retriever', 10.57179054054054),
#  ('Weimaraner', 10.5625),
#  ('Chinook', 10.5),
#  ('Australian Shepherd- Mix', 10.5),
#  ('Glen of Imaal Terrier', 10.5),
#  ('Rhodesian Ridgeback-Labrador Retriever Mix', 10.5),
#  ('Poodle-Rat Terrier Mix', 10.5),
#  ('Alaskan Malamute-Siberian Husky Mix', 10.5),
#  ('Belgian Malinois-Labrador Retriever Mix', 10.5),
#  ('Jack Russell Terrier-Welsh Terrier Mix', 10.5),
#  ('Greyhound-Border Collie Mix', 10.5),
#  ('Finnish Lapphund', 10.428571428571429),
#  ('Yorkshire Terrier-Maltese Mix', 10.421052631578947),
#  ('Border Collie-Australian Shepherd Mix', 10.4),
#  ('Keeshond', 10.4),
#  ('German Shorthaired Pointer', 10.372549019607844),
#  ('Border Terrier', 10.368421052631579),
#  ('American Pit Bull Terrier-Rhodesian Ridgeback Mix', 10.333333333333334),
#  ('Rhodesian Ridgeback', 10.303030303030303),
#  ('Pointer', 10.285714285714286),
#  ('Standard Schnauzer', 10.25925925925926),
#  ('Australian Shepherd-Great Pyrenees Mix', 10.25),
#  ('Golden Retriever', 10.227848101265822),
#  ('Flat-Coated Retriever', 10.209302325581396),
#  ('Irish Setter', 10.1875),
#  ('Vizsla', 10.180555555555555),
#  ('Labradoodle', 10.17910447761194),
#  ('Shih Tzu', 10.173913043478262),
#  ('Labrador Retriever-Border Collie Mix', 10.172413793103448),
#  ('Border Collie', 10.172131147540984),
#  ('Redbone Coonhound', 10.166666666666666),
#  ('West Highland White Terrier', 10.121621621621621),
#  ('Welsh Springer Spaniel', 10.083333333333334),
#  ('Beagle', 10.076923076923077),
#  ('Puggle', 10.069767441860465),
#  ('German Shepherd Dog', 10.06338028169014),
#  ('Golden Doodle', 10.043010752688172),
#  ('American Staffordshire Terrier-Labrador Retriever Mix', 10.0),
#  ('German Shepherd Dog-Golden Retriever Mix', 10.0),
#  ('Border Collie-Golden Retriever Mix', 10.0),
#  ('Doberman Pinscher-Black and Tan Coonhound Mix', 10.0),
#  ('Manchester Terrier', 10.0),
#  ('Chihuahua-Pembroke Welsh Corgi Mix', 10.0),
#  ('Pomeranian-Papillon Mix', 10.0),
#  ('Bull Terrier-American Foxhound Mix', 10.0),
#  ('Siberian Husky-Alaskan Malamute Mix', 10.0),
#  ('Standard Poodle-Chinese Shar-Pei Mix', 10.0),
#  ('Lancashire Heeler-Australian Cattle Dog Mix', 10.0),
#  ('Brittany-Pointer Mix', 10.0),
#  ('Siberian Husky-Boxer Mix', 10.0),
#  ('Beagle-Jack Russell Terrier Mix', 10.0),
#  ('Poodle-Australian Cattle Dog Mix', 10.0),
#  ('Standard Poodle-Standard Schnauzer Mix', 10.0),
#  ('Miniature Schnauzer', 9.969325153374234),
#  ('Cocker Spaniel', 9.96808510638298),
#  ('St. Bernard', 9.909090909090908),
#  ('Australian Cattle Dog', 9.905882352941177),
#  ('Shiba Inu', 9.88888888888889),
#  ('Border Collie-Labrador Retriever Mix', 9.852941176470589),
#  ('Belgian Tervuren', 9.833333333333334),
#  ('Dutch Shepherd', 9.833333333333334),
#  ('Cairn Terrier', 9.825),
#  ('Bedlington Terrier', 9.8),
#  ('German Shepherd Dog-Alaskan Malamute Mix', 9.8),
#  ('German Shepherd Dog-American Pit Bull Terrier Mix', 9.8),
#  ('Poodle-Soft Coated Wheaten Terrier Mix', 9.8),
#  ('Poodle-Miniature Schnauzer Mix', 9.73913043478261),
#  ('Pug', 9.700934579439252),
#  ('Norwich Terrier', 9.7),
#  ('Australian Cattle Dog-Labrador Retriever Mix', 9.7),
#  ('Mixed', 9.688152098307443),
#  ('Chihuahua-Beagle Mix', 9.666666666666666),
#  ('Papillon', 9.634615384615385),
#  ('Cocker Spaniel-Poodle Mix', 9.620689655172415),
#  ('Rat Terrier', 9.615384615384615),
#  ('Whippet', 9.612903225806452),
#  ('Silky Terrier', 9.6),
#  ('German Shepherd Dog-Belgian Malinois Mix', 9.6),
#  ('Lhasa Apso-Poodle Mix', 9.571428571428571),
#  ('Siberian Husky', 9.548387096774194),
#  ('Akita', 9.541666666666666),
#  ('Cavalier King Charles Spaniel-Poodle Mix', 9.526315789473685),
#  ('Rottweiler', 9.525641025641026),
#  ('Mudi', 9.5),
#  ('Alaskan Malamute', 9.5),
#  ('Belgian Sheepdog', 9.5),
#  ('Beagle-American Eskimo Dog Mix', 9.5),
#  ('German Pinscher', 9.5),
#  ('Labrador Retriever-Doberman Pinscher Mix', 9.5),
#  ('Collie-Golden Retriever Mix', 9.5),
#  ('Alaskan Malamute-German Shepherd Dog Mix', 9.5),
#  ('Chihuahua-Yorkshire Terrier Mix', 9.454545454545455),
#  ('Catahoula Leopard Dog', 9.444444444444445),
#  ('Cardigan Welsh Corgi', 9.428571428571429),
#  ('Greyhound', 9.425925925925926),
#  ('Wire Fox Terrier', 9.416666666666666),
#  ('Bernese Mountain Dog', 9.404255319148936),
#  ('German Shepherd Dog-Siberian Husky Mix', 9.35),
#  ('English Springer Spaniel', 9.339285714285714),
#  ('German Shepherd Dog-Beagle Mix', 9.333333333333334),
#  ('American Staffordshire Terrier-Border Collie Mix', 9.333333333333334),
#  ('Pug-Shih Tzu Mix', 9.333333333333334),
#  ('Boxer', 9.329842931937172),
#  ('Cavalier King Charles Spaniel-Bichon Frise Mix', 9.272727272727273),
#  ('Labrador Retriever-German Shepherd Dog Mix', 9.25),
#  ('Mastiff', 9.238095238095237),
#  ('Boxer-American Staffordshire Terrier Mix', 9.2),
#  ('Chinese Shar-Pei', 9.2),
#  ('Greyhound-Labrador Retriever Mix', 9.2),
#  ('Siberian Husky-Labrador Retriever Mix', 9.2),
#  ('Dalmatian', 9.1875),
#  ('American Staffordshire Terrier', 9.175438596491228),
#  ('Pomapoo', 9.166666666666666),
#  ('Newfoundland', 9.151515151515152),
#  ('Old English Sheepdog', 9.125),
#  ('Australian Cattle Dog-Australian Shepherd Mix', 9.125),
#  ('Bichon Frise', 9.05),
#  ('French Bulldog', 9.0),
#  ('Shih Tzu-Maltese Mix', 9.0),
#  ('Irish Wolfhound', 9.0),
#  ('Treeing Walker Coonhound', 9.0),
#  ('Spinone Italiano', 9.0),
#  ('Labrador Retriever-American Pit Bull Terrier Mix', 9.0),
#  ('Borzoi', 9.0),
#  ('Basset Hound-German Shepherd Dog Mix', 9.0),
#  ('Boxer- Mix', 9.0),
#  ('Keeshond-Chow Chow Mix', 9.0),
#  ('Boxer Mix', 9.0),
#  ('Chihuahua-Cardigan Welsh Corgi Mix', 9.0),
#  ('Siberian Husky-Border Collie Mix', 9.0),
#  ('Havanese-Shih Tzu Mix', 9.0),
#  ('Bulldog-Bullmastiff Mix', 9.0),
#  ('Plott', 9.0),
#  ('Soft Coated Wheaten Terrier-Poodle Mix', 9.0),
#  ('American Eskimo Dog-Shiba Inu Mix', 9.0),
#  ('Greyhound-Irish Wolfhound Mix', 9.0),
#  ('Italian Greyhound-Miniature Pinscher Mix', 9.0),
#  ('Chesapeake Bay Retriever-Siberian Husky Mix', 9.0),
#  ('Australian Terrier-Parson Russell Terrier Mix', 9.0),
#  ('Boston Terrier-Pomeranian Mix', 9.0),
#  ('American Staffordshire Terrier-Dogue de Bordeaux Mix', 9.0),
#  ('Catahoula Leopard Dog-Bluetick Coonhound Mix', 9.0),
#  ('Plott-Labrador Retriever Mix', 9.0),
#  ('Dutch Shepherd-Labrador Retriever Mix', 9.0),
#  ('Maltese-Shih Tzu Mix', 8.923076923076923),
#  ('Welsh Terrier', 8.916666666666666),
#  ('Lagotto Romagnolo', 8.88888888888889),
#  ('Labrador Retriever-Beagle Mix', 8.875),
#  ('Other', 8.82258064516129),
#  ('Bull Terrier', 8.8),
#  ('Labrador Retriever-Siberian Husky Mix', 8.8),
#  ('Labrador Retriever-Dachshund Mix', 8.75),
#  ('Petit Basset Griffon Vendeen', 8.75),
#  ('Mastiff-Labrador Retriever Mix', 8.75),
#  ('Havanese-Poodle Mix', 8.714285714285714),
#  ('Neapolitan Mastiff', 8.666666666666666),
#  ('Poodle-Golden Retriever Mix', 8.666666666666666),
#  ('American Pit Bull Terrier', 8.654929577464788),
#  ('German Wirehaired Pointer', 8.642857142857142),
#  ('Chihuahua-Pug Mix', 8.625),
#  ('Lhasa Apso', 8.6),
#  ('Poodle-Labrador Retriever Mix', 8.6),
#  ('Labrador Retriever-German Shorthaired Pointer Mix', 8.571428571428571),
#  ('Chihuahua-Dachshund Mix', 8.521739130434783),
#  ("I Don't Know", 8.515981735159817),
#  ('American Staffordshire Terrier-American Pit Bull Terrier Mix', 8.5),
#  ('German Shorthaired Pointer-American Pit Bull Terrier Mix', 8.5),
#  ('Boxer-Labrador Retriever Mix', 8.5),
#  ('Akita-German Shepherd Dog Mix', 8.5),
#  ('Berger Picard', 8.4),
#  ('Cavalier King Charles Spaniel', 8.382978723404255),
#  ('Standard Poodle', 8.372549019607844),
#  ('Catahoula Leopard Dog-Australian Cattle Dog Mix', 8.333333333333334),
#  ('Border Collie-Siberian Husky Mix', 8.333333333333334),
#  ('Yorkshire Terrier-Miniature Schnauzer Mix', 8.333333333333334),
#  ('Doberman Pinscher-Rottweiler Mix', 8.333333333333334),
#  ('Border Collie-Australian Kelpie Mix', 8.333333333333334),
#  ('Havanese', 8.309278350515465),
#  ('Japanese Chin', 8.285714285714286),
#  ('Maltese-Poodle Mix', 8.26923076923077),
#  ('Boston Terrier', 8.247706422018348),
#  ('Miniature Pinscher', 8.229166666666666),
#  ('Greater Swiss Mountain Dog', 8.222222222222221),
#  ('Chesapeake Bay Retriever', 8.210526315789474),
#  ('Bulldog', 8.2),
#  ('Boston Terrier-French Bulldog Mix', 8.2),
#  ('Bichon Frise-Poodle Mix', 8.136363636363637),
#  ('Labrador Retriever-Australian Shepherd Mix', 8.1),
#  ('Basenji', 8.071428571428571),
#  ('Dachshund', 8.054545454545455),
#  ('Great Dane', 8.0),
#  ('American Staffordshire Terrier- Mix', 8.0),
#  ('Poodle-German Spitz Mix', 8.0),
#  ('Boerboel', 8.0),
#  ('Pembroke Welsh Corgi-Chihuahua Mix', 8.0),
#  ('Greyhound-American Pit Bull Terrier Mix', 8.0),
#  ('Rottweiler-American Pit Bull Terrier Mix', 8.0),
#  ('Dachshund-American Staffordshire Terrier Mix', 8.0),
#  ('Lhasa Apso-Tibetan Spaniel Mix', 8.0),
#  ('Russell Terrier', 7.956521739130435),
#  ('Yorkshire Terrier-Poodle Mix', 7.916666666666667),
#  ('Yorkshire Terrier', 7.893939393939394),
#  ('American Pit Bull Terrier-American Staffordshire Terrier Mix', 7.875),
#  ('Pomeranian', 7.833333333333333),
#  ('German Shepherd Dog-Australian Shepherd Mix', 7.833333333333333),
#  ('Toy Fox Terrier', 7.833333333333333),
#  ('Xoloitzcuintli', 7.8),
#  ('German Shepherd Dog-Labrador Retriever Mix', 7.777777777777778),
#  ('Poodle-Cocker Spaniel Mix', 7.75),
#  ('Pekingese', 7.75),
#  ('Australian Shepherd-Shetland Sheepdog Mix', 7.75),
#  ('Chinese Crested', 7.7272727272727275),
#  ('Beagle-Labrador Retriever Mix', 7.6923076923076925),
#  ('Australian Shepherd-Border Collie Mix', 7.6875),
#  ('Chihuahua', 7.681818181818182),
#  ('Boxer-Bulldog Mix', 7.666666666666667),
#  ('Border Collie-Newfoundland Mix', 7.666666666666667),
#  ('Borzoi-Whippet Mix', 7.666666666666667),
#  ('Golden Retriever-Border Collie Mix', 7.666666666666667),
#  ('Parson Russell Terrier', 7.661538461538462),
#  ('Poodle-Yorkshire Terrier Mix', 7.642857142857143),
#  ('Labrador Retriever-Chinese Shar-Pei Mix', 7.6),
#  ('Poodle-Bichon Frise Mix', 7.6),
#  ('Eurasier', 7.6),
#  ('Labrador Retriever-Poodle Mix', 7.6),
#  ('Bullmastiff', 7.538461538461538),
#  ('Australian Shepherd-Golden Retriever Mix', 7.5),
#  ('Miniature Bull Terrier', 7.5),
#  ('Bearded Collie', 7.5),
#  ('Havanese-Maltese Mix', 7.5),
#  ('Chihuahua-Labrador Retriever Mix', 7.5),
#  ('Maltese', 7.409638554216867),
#  ('Yorkshire Terrier-Bichon Frise Mix', 7.4),
#  ('Cane Corso', 7.3076923076923075),
#  ('Shih Tzu-Poodle Mix', 7.291666666666667),
#  ('Czechoslovakian Vlcak', 7.25),
#  ('Border Collie-Cocker Spaniel Mix', 7.25),
#  ('Brussels Griffon', 7.235294117647059),
#  ('Stabyhoun', 7.2),
#  ('Leonberger', 7.181818181818182),
#  ('Labrador Retriever-Greyhound Mix', 7.166666666666667),
#  ('Belgian Sheepdog- Mix', 7.0),
#  ('Border Collie-Belgian Tervuren Mix', 7.0),
#  ('Staffordshire Bull Terrier-Great Dane Mix', 7.0),
#  ('Staffordshire Bull Terrier-Miniature Schnauzer Mix', 7.0),
#  ('Great Dane-Irish Wolfhound Mix', 7.0),
#  ('Pembroke Welsh Corgi-Great Pyrenees Mix', 7.0),
#  ('Dandie Dinmont Terrier', 7.0),
#  ('Pointer-Beagle Mix', 7.0),
#  ('Golden Retriever-English Cocker Spaniel Mix', 7.0),
#  ('German Shepherd Dog-Chinese Shar-Pei Mix', 7.0),
#  ('Dogo Argentino', 7.0),
#  ('American Foxhound- Mix', 7.0),
#  ('Bedlington Terrier-Whippet Mix', 7.0),
#  ('Otterhound', 7.0),
#  ('Basset Hound-Russell Terrier Mix', 7.0),
#  ('Airedale Terrier-Labrador Retriever Mix', 7.0),
#  ('Shih Tzu-Chihuahua Mix', 7.0),
#  ('Miniature Schnauzer-Maltese Mix', 7.0),
#  ('Redbone Coonhound-Basset Hound Mix', 7.0),
#  ('Doberman Pinscher-Pug Mix', 7.0),
#  ('Bulldog-Chesapeake Bay Retriever Mix', 7.0),
#  ('Catahoula Leopard Dog-Siberian Husky Mix', 7.0),
#  ('Scottish Deerhound', 7.0),
#  ('Toy Fox Terrier Mix', 7.0),
#  ('German Shorthaired Pointer- Mix', 7.0),
#  ('American Pit Bull Terrier-German Shepherd Dog Mix', 7.0),
#  ('Lhasa Apso-Shih Tzu Mix', 7.0),
#  ('Mastiff-American Pit Bull Terrier Mix', 7.0),
#  ('Scottish Terrier-Shih Tzu Mix', 7.0),
#  ('Russell Terrier-Cocker Spaniel Mix', 7.0),
#  ('Maltese-Pomeranian Mix', 7.0),
#  ('Pointer-Australian Shepherd Mix', 7.0),
#  ('Belgian Malinois- Mix', 7.0),
#  ('American Eskimo Dog- Mix', 7.0),
#  ('Cardigan Welsh Corgi-Cairn Terrier Mix', 7.0),
#  ('Basenji-Shiba Inu Mix', 7.0),
#  ('Beagle-Whippet Mix', 7.0),
#  ('French Bulldog-Pug Mix', 7.0),
#  ('American Staffordshire Terrier-Chinese Shar-Pei Mix', 7.0),
#  ('German Shepherd Dog-Whippet Mix', 7.0),
#  ('Border Collie-West Highland White Terrier Mix', 7.0),
#  ('Pug-Russell Terrier Mix', 7.0),
#  ('Australian Cattle Dog-Bluetick Coonhound Mix', 7.0),
#  ('American Foxhound-Labrador Retriever Mix', 7.0),
#  ('Russell Terrier-Rat Terrier Mix', 7.0),
#  ('Australian Cattle Dog-Weimaraner Mix', 7.0),
#  ('Siberian Husky-Standard Schnauzer Mix', 7.0),
#  ('Labrador Retriever-Cocker Spaniel Mix', 7.0),
#  ('Bichon Frise-Pomeranian Mix', 7.0),
#  ('Border Collie-Kooikerhondje Mix', 7.0),
#  ('Border Collie-Chow Chow Mix', 7.0),
#  ('Border Terrier-Parson Russell Terrier Mix', 7.0),
#  ('Siberian Husky-Bernese Mountain Dog Mix', 7.0),
#  ('Black and Tan Coonhound-German Shepherd Dog Mix', 7.0),
#  ('Havanese-Bichon Frise Mix', 7.0),
#  ('Boxer-Rhodesian Ridgeback Mix', 7.0),
#  ('Great Pyrenees-Golden Retriever Mix', 7.0),
#  ('American English Coonhound-Rhodesian Ridgeback Mix', 7.0),
#  ('St. Bernard-Dachshund Mix', 7.0),
#  ('Maltese-Cavalier King Charles Spaniel Mix', 7.0),
#  ('Chihuahua-Norwich Terrier Mix', 7.0),
#  ('American Staffordshire Terrier-Greyhound Mix', 7.0),
#  ('Basenji-Whippet Mix', 7.0),
#  ('Plott-Beagle Mix', 7.0),
#  ('Flat-Coated Retriever-Portuguese Water Dog Mix', 7.0),
#  ('Miniature Pinscher-Russell Terrier Mix', 7.0),
#  ('German Shepherd Dog-Bluetick Coonhound Mix', 7.0),
#  ('Wire Fox Terrier-Parson Russell Terrier Mix', 7.0),
#  ('Parson Russell Terrier-Cairn Terrier Mix', 7.0),
#  ('Russell Terrier-Golden Retriever Mix', 7.0),
#  ('Boxer-Boston Terrier Mix', 7.0),
#  ('Akita-Bernese Mountain Dog Mix', 7.0),
#  ('Basset Hound-Cardigan Welsh Corgi Mix', 7.0),
#  ('American Pit Bull Terrier-Chinese Shar-Pei Mix', 7.0),
#  ('Karelian Bear Dog-Border Collie Mix', 7.0),
#  ('Boxer-American Foxhound Mix', 7.0),
#  ('Brittany-Siberian Husky Mix', 7.0),
#  ('Great Pyrenees-Chow Chow Mix', 7.0),
#  ('Papillon-Miniature Schnauzer Mix', 7.0),
#  ('Papillon-Pomeranian Mix', 7.0),
#  ('Border Collie-Affenpinscher Mix', 7.0),
#  ('Australian Labradoodle-Poodle Mix', 7.0),
#  ('Japanese Chin-Pekingese Mix', 7.0),
#  ('American Pit Bull Terrier-Vizsla Mix', 7.0),
#  ('Labrador Retriever-Pomeranian Mix', 7.0),
#  ('Lhasa Apso-Dandie Dinmont Terrier Mix', 7.0),
#  ('Collie-Belgian Malinois Mix', 7.0),
#  ('Chinese Shar-Pei-Australian Cattle Dog Mix', 7.0),
#  ('Shetland Sheepdog-American Eskimo Dog Mix', 7.0),
#  ('Golden Retriever-Irish Wolfhound Mix', 7.0),
#  ('Lhasa Apso-German Shepherd Dog Mix', 7.0),
#  ('Poodle-Redbone Coonhound Mix', 7.0),
#  ('Chihuahua-Australian Terrier Mix', 7.0),
#  ('Australian Cattle Dog-Chow Chow Mix', 7.0),
#  ('Brussels Griffon-Poodle Mix', 7.0),
#  ('Bulldog-Labrador Retriever Mix', 7.0),
#  ('Yorkshire Terrier-German Spitz Mix', 7.0),
#  ('Dachshund-American Pit Bull Terrier Mix', 7.0),
#  ('Bichon Frise-Havanese Mix', 7.0),
#  ('Pekingese-Lhasa Apso Mix', 7.0),
#  ('Cocker Spaniel-English Cocker Spaniel Mix', 7.0),
#  ('Brussels Griffon-Border Terrier Mix', 7.0),
#  ('German Shorthaired Pointer-Newfoundland Mix', 7.0),
#  ('Plott-American Foxhound Mix', 7.0),
#  ('Golden Retriever-Redbone Coonhound Mix', 7.0),
#  ('Cairn Terrier-Australian Terrier Mix', 7.0),
#  ('Jack Russell Terrier-Poodle Mix', 7.0),
#  ('Golden Retriever-Cavalier King Charles Spaniel Mix', 7.0),
#  ('Bullmastiff-Dogue de Bordeaux Mix', 7.0),
#  ('Smooth Fox Terrier-Bluetick Coonhound Mix', 7.0),
#  ('Australian Shepherd-Pug Mix', 7.0),
#  ('Jack Russell Terrier', 6.985074626865671),
#  ('Chihuahua-Miniature Pinscher Mix', 6.909090909090909),
#  ('Basset Hound', 6.777777777777778),
#  ('Jack-A-Poo', 6.75),
#  ('Beagle-Rat Terrier Mix', 6.75),
#  ('Australian Cattle Dog-American Pit Bull Terrier Mix', 6.666666666666667),
#  ('Beagle-Cocker Spaniel Mix', 6.666666666666667),
#  ('American Pit Bull Terrier-Labrador Retriever Mix', 6.631578947368421),
#  ('Great Pyrenees', 6.615384615384615),
#  ('Chihuahua- Mix', 6.5),
#  ('Silky Terrier-Poodle Mix', 6.5),
#  ('Canaan Dog', 6.5),
#  ('Australian Shepherd-Rottweiler Mix', 6.5),
#  ('Catahoula Leopard Dog-Labrador Retriever Mix', 6.5),
#  ('Shih Tzu-Bichon Frise Mix', 6.5),
#  ('German Shepherd Dog-Greyhound Mix', 6.5),
#  ('Bull Terrier-Labrador Retriever Mix', 6.5),
#  ('Mastiff-Great Dane Mix', 6.5),
#  ('Bichon Frise-Lhasa Apso Mix', 6.5),
#  ('Poodle-English Springer Spaniel Mix', 6.5),
#  ('Boxer-American Pit Bull Terrier Mix', 6.375),
#  ('Chow Chow', 6.375),
#  ('Labrador Retriever-American Staffordshire Terrier Mix', 6.333333333333333),
#  ('Staffordshire Bull Terrier', 6.275862068965517),
#  ('Doberman Pinscher-Labrador Retriever Mix', 6.25),
#  ('American Staffordshire Terrier-Boxer Mix', 6.25),
#  ('Tibetan Terrier', 6.2105263157894735),
#  ('Black Russian Terrier', 6.2),
#  ('Schipperke', 6.111111111111111),
#  ('Boykin Spaniel-Deutscher Wachtelhund Mix', 6.0),
#  ('Staffordshire Bull Terrier-Russell Terrier Mix', 6.0),
#  ('German Spitz', 6.0),
#  ('Boxer-Bull Terrier Mix', 6.0),
#  ('Russell Terrier- Mix', 6.0),
#  ('St. Bernard- Mix', 6.0),
#  ('Beagle-Siberian Husky Mix', 6.0),
#  ('Shih Tzu-Silky Terrier Mix', 6.0),
#  ('Rat Terrier-Beagle Mix', 6.0),
#  ('Beagle-Border Collie Mix', 6.0),
#  ('Irish Setter-Border Collie Mix', 6.0),
#  ('Golden Retriever-Cocker Spaniel Mix', 6.0),
#  ('Labrador Retriever-Pembroke Welsh Corgi Mix', 6.0),
#  ('Cardigan Welsh Corgi-Lancashire Heeler Mix', 6.0),
#  ('Chihuahua-Toy Fox Terrier Mix', 6.0),
#  ('Pekingese-Cocker Spaniel Mix', 6.0),
#  ('Labrador Retriever-Great Pyrenees Mix', 6.0),
#  ('Plott-Boxer Mix', 6.0),
#  ('Rottweiler-Collie Mix', 6.0),
#  ('Miniature Australian Shepherd-Poodle Mix', 6.0),
#  ('Australian Cattle Dog-Australian Kelpie Mix', 6.0),
#  ('Miniature Schnauzer-Soft Coated Wheaten Terrier Mix', 6.0),
#  ('Jack Russell Terrier-Smooth Fox Terrier Mix', 6.0),
#  ('Jindo-Shiba Inu Mix', 6.0),
#  ('Golden Retriever-German Shepherd Dog Mix', 5.875),
#  ('Dachshund-Chihuahua Mix', 5.875),
#  ('Italian Greyhound', 5.84),
#  ('Dachshund-Miniature Pinscher Mix', 5.75),
#  ('Chihuahua-Rat Terrier Mix', 5.75),
#  ('Small Munsterlander Pointer', 5.666666666666667),
#  ('Bulldog-Boxer Mix', 5.666666666666667),
#  ('Airedale Terrier', 5.6),
#  ('Staffordshire Bull Terrier-Bulldog Mix', 5.5),
#  ('Labrador Retriever-English Springer Spaniel Mix', 5.5),
#  ('Labrador Retriever-St. Bernard Mix', 5.5),
#  ('Dogue de Bordeaux', 5.5),
#  ('Australian Shepherd-Labrador Retriever Mix', 5.5),
#  ('St. Bernard-Border Collie Mix', 5.5),
#  ('Siberian Husky-Beagle Mix', 5.5),
#  ('Australian Shepherd-Siberian Husky Mix', 5.5),
#  ('Australian Shepherd-Collie Mix', 5.5),
#  ('Jack Russell Terrier-American Pit Bull Terrier Mix', 5.5),
#  ('Poodle-Shih Tzu Mix', 5.363636363636363),
#  ('Beagle-Australian Cattle Dog Mix', 5.333333333333333),
#  ('BullBoxer', 5.333333333333333),
#  ('Collie-Labrador Retriever Mix', 5.333333333333333),
#  ('Jindo', 5.333333333333333),
#  ('Boxer-Border Collie Mix', 5.0),
#  ('German Shepherd Dog-Chow Chow Mix', 5.0),
#  ('Bugg', 5.0),
#  ('Lakeland Terrier', 5.0),
#  ('Chesapeake Bay Retriever-Beagle Mix', 5.0),
#  ('Cairn Terrier-Shih Tzu Mix', 5.0),
#  ('Pharaoh Hound', 5.0),
#  ('Pug-Lhasa Apso Mix', 5.0),
#  ('American Foxhound', 5.0),
#  ('Rat Terrier- Mix', 5.0),
#  ('Boxer-Jindo Mix', 5.0),
#  ('Bolognese', 5.0),
#  ('Staffordshire Bull Terrier-Bullmastiff Mix', 5.0),
#  ('Boxer-Great Dane Mix', 5.0),
#  ('Barbet', 5.0),
#  ('Border Collie-Standard Schnauzer Mix', 5.0),
#  ('Yorkshire Terrier-Soft Coated Wheaten Terrier Mix', 5.0),
#  ('Great Dane-Doberman Pinscher Mix', 5.0),
#  ('Giant Schnauzer-Standard Poodle Mix', 5.0),
#  ('Poodle-English Cocker Spaniel Mix', 5.0),
#  ('Poodle-Newfoundland Mix', 5.0),
#  ('Labrador Retriever-Standard Poodle Mix', 5.0),
#  ('American Eskimo Dog-Pembroke Welsh Corgi Mix', 5.0),
#  ('Border Collie-Icelandic Sheepdog Mix', 5.0),
#  ('Bernese Mountain Dog-Chow Chow Mix', 5.0),
#  ('Labrador Retriever-Chow Chow Mix', 4.8),
#  ('Chihuahua-Pomeranian Mix', 4.777777777777778),
#  ('Dachshund-Beagle Mix', 4.75),
#  ('Saluki', 4.75),
#  ('Rottweiler-German Shepherd Dog Mix', 4.714285714285714),
#  ('Beagle-Russell Terrier Mix', 4.5),
#  ('Dachshund-Parson Russell Terrier Mix', 4.5),
#  ('German Shepherd Dog-Redbone Coonhound Mix', 4.5),
#  ('Bulldog-American Pit Bull Terrier Mix', 4.5),
#  ('Flat-Coated Retriever-Border Collie Mix', 4.5),
#  ('Belgian Malinois-Dutch Shepherd Mix', 4.5),
#  ('Poodle-German Shepherd Dog Mix', 4.5),
#  ('Anatolian Shepherd Dog-Great Pyrenees Mix', 4.5),
#  ('Standard Poodle-Golden Retriever Mix', 4.5),
#  ('Chihuahua-Jack Russell Terrier Mix', 4.5),
#  ('Jack Russell Terrier-Rat Terrier Mix', 4.5),
#  ('German Shepherd Dog-Norwegian Elkhound Mix', 4.5),
#  ('German Shorthaired Pointer-Pointer Mix', 4.5),
#  ('Border Collie-Bluetick Coonhound Mix', 4.5),
#  ('Boxer-German Shepherd Dog Mix', 4.333333333333333),
#  ('Basset Hound-Labrador Retriever Mix', 4.333333333333333),
#  ('Miniature Schnauzer-Yorkshire Terrier Mix', 4.333333333333333),
#  ('Parson Russell Terrier-Beagle Mix', 4.0),
#  ('Russell Terrier-Pug Mix', 4.0),
#  ('Bulldog-Beagle Mix', 4.0),
#  ('Russell Terrier-Chihuahua Mix', 4.0),
#  ('American Staffordshire Terrier-Catahoula Leopard Dog Mix', 4.0),
#  ('Whippet-Chinese Shar-Pei Mix', 4.0),
#  ('Labrador Retriever-Basset Hound Mix', 4.0),
#  ('Poodle-Standard Schnauzer Mix', 4.0),
#  ('Boxer-Bloodhound Mix', 4.0),
#  ('Australian Shepherd-Chow Chow Mix', 4.0),
#  ('Pembroke Welsh Corgi-American Eskimo Dog Mix', 4.0),
#  ('English Cocker Spaniel-Poodle Mix', 4.0),
#  ('Border Collie- Mix', 4.0),
#  ('Shiba Inu-Pembroke Welsh Corgi Mix', 4.0),
#  ('Papillon-Japanese Chin Mix', 4.0),
#  ('Russell Terrier-Poodle Mix', 4.0),
#  ('Italian Greyhound-Cardigan Welsh Corgi Mix', 4.0),
#  ('Maltese-Cocker Spaniel Mix', 4.0),
#  ('Australian Cattle Dog Mix', 4.0),
#  ('Bloodhound-Irish Setter Mix', 4.0),
#  ('Maltese-Standard Schnauzer Mix', 4.0),
#  ('Papillon-Poodle Mix', 4.0),
#  ('Boxer-Russell Terrier Mix', 4.0),
#  ('Chihuahua-Shiba Inu Mix', 4.0),
#  ('German Shepherd Dog- Mix', 4.0),
#  ('Beagle-Pointer Mix', 4.0),
#  ('Border Collie-American Eskimo Dog Mix', 4.0),
#  ('Whippet-Russell Terrier Mix', 4.0),
#  ('Pomeranian-Chihuahua Mix', 4.0),
#  ('Boxer-Greyhound Mix', 4.0),
#  ('German Shepherd Dog-Mastiff Mix', 4.0),
#  ('Rhodesian Ridgeback-Redbone Coonhound Mix', 4.0),
#  ('Catahoula Leopard Dog-American Pit Bull Terrier Mix', 4.0),
#  ...]

# %% [markdown]
# **Question 5: Write a query that outputs the average amount of time it took customers to complete each type of test where any individual reaction times over 6000 hours are excluded and only average reaction times that are greater than 0 seconds are included (your output should end up with 67 rows).**

# %%
# %%sql
# SELECT test_name, AVG(TIMESTAMPDIFF(SECOND, start_time, end_time)) as time_taken
# FROM exam_answers
# GROUP BY test_name
# HAVING time_taken <= 6000*60*60 and time_taken > 0
# ORDER BY time_taken DESC
# Out:
# 67 rows affected.
# [('Social-Quiz', Decimal('469974.4235')),
#  ('Diet', Decimal('195618.1398')),
#  ('Sociability', Decimal('91686.1501')),
#  ('Activity', Decimal('79732.3222')),
#  ('Yawn Warm-up', Decimal('70944.8185')),
#  ('Watching', Decimal('63921.4748')),
#  ('Surprise And Delight', Decimal('62280.4908')),
#  ('Set 3', Decimal('46084.8740')),
#  ('Confinement', Decimal('45523.1903')),
#  ('Shy/Boldness', Decimal('44284.0845')),
#  ('Attachment', Decimal('41531.5367')),
#  ('Excitability', Decimal('40739.0252')),
#  ('Smell Game', Decimal('27092.3268')),
#  ('Physical', Decimal('26598.6297')),
#  ('Gender', Decimal('24887.8159')),
#  ('Owner', Decimal('24222.7035')),
#  ('Navigation Warm-up', Decimal('22267.6312')),
#  ('Purina-Only', Decimal('20205.8761')),
#  ('Emotions', Decimal('17397.3007')),
#  ('Numerosity Warm-Up', Decimal('16555.1668')),
#  ('Yawn Game', Decimal('16515.5140')),
#  ('Watching - Part 2', Decimal('15671.7395')),
#  ('Purina', Decimal('15211.0516')),
#  ('Perception', Decimal('13997.3807')),
#  ('Recall', Decimal('13939.1675')),
#  ('Puzzles', Decimal('13782.1014')),
#  ('Impossible Task Warm-up', Decimal('13706.5646')),
#  ('Partnership', Decimal('12709.8895')),
#  ('Obedience', Decimal('12484.6163')),
#  ('Toys', Decimal('11207.1117')),
#  ('Set 1', Decimal('11182.7955')),
#  ('Training', Decimal('10691.6541')),
#  ('Social', Decimal('9936.3177')),
#  ('Treat Warm-up', Decimal('9902.7286')),
#  ('Cover Your Eyes', Decimal('8773.2955')),
#  ('Warm-Up', Decimal('7520.0704')),
#  ('Delayed Cup Game', Decimal('7246.6225')),
#  ('Turn Your Back', Decimal('6928.7912')),
#  ('Environment', Decimal('6669.6083')),
#  ('One Cup Warm-up', Decimal('6233.5012')),
#  ('Eye Contact Warm-up', Decimal('5477.6878')),
#  ('Eye Contact Game', Decimal('5320.0699')),
#  ('Inferential Reasoning Warm-up', Decimal('4993.8225')),
#  ('Memory versus Smell', Decimal('4289.5062')),
#  ('Physical Reasoning Warm-up', Decimal('3719.1250')),
#  ('Arm Pointing', Decimal('3379.7847')),
#  ('Foot Pointing', Decimal('2075.6727')),
#  ('Slide', Decimal('1939.4002')),
#  ('Physical Reasoning Game', Decimal('1751.3968')),
#  ('Memory versus Pointing', Decimal('1609.4567')),
#  ('Inferential Reasoning Game', Decimal('1408.4918')),
#  ('Stair Game', Decimal('1113.1217')),
#  ('Navigation Learning', Decimal('832.0526')),
#  ('Impossible Task Game', Decimal('737.3073')),
#  ('Set 2', Decimal('494.1049')),
#  ('Navigation Game', Decimal('482.5239')),
#  ('Two Cup Warm-up', Decimal('456.4392')),
#  ('Shaker Warm-Up', Decimal('250.2791')),
#  ('Different Perspective', Decimal('209.2164')),
#  ('Switch', Decimal('202.8889')),
#  ('Shared Perspective', Decimal('19.9822')),
#  ('1 vs 1 Game', Decimal('12.2278')),
#  ('3 vs 1 Game', Decimal('11.8237')),
#  ('5 vs 1 Game', Decimal('11.7260')),
#  ('Expression Game', Decimal('10.3948')),
#  ('Self Control Game', Decimal('9.5476')),
#  ('Shaker Game', Decimal('7.5290'))]

# %% [markdown]
# **Question 6: Write a query that outputs the total number of unique User_Guids in each combination of State and ZIP code (postal code) in the United States, sorted first by state name in ascending alphabetical order, and second by total number of unique User_Guids in descending order (your first state should be AE and there should be 5043 rows in total in your output).**

# %%
# %sql describe users
# Out:
# 16 rows affected.
# [('sign_in_count', 'int(11)', 'YES', '', '0', ''),
#  ('created_at', 'datetime', 'NO', '', None, ''),
#  ('updated_at', 'datetime', 'NO', '', None, ''),
#  ('max_dogs', 'int(11)', 'YES', '', '0', ''),
#  ('membership_id', 'int(11)', 'YES', '', None, ''),
#  ('subscribed', 'tinyint(1)', 'YES', '', '0', ''),
#  ('exclude', 'tinyint(1)', 'YES', '', None, ''),
#  ('free_start_user', 'tinyint(1)', 'YES', '', None, ''),
#  ('last_active_at', 'datetime', 'YES', '', None, ''),
#  ('membership_type', 'int(11)', 'YES', '', None, ''),
#  ('user_guid', 'text', 'YES', 'MUL', None, ''),
#  ('city', 'varchar(255)', 'YES', '', None, ''),
#  ('state', 'varchar(255)', 'YES', '', None, ''),
#  ('zip', 'varchar(255)', 'YES', '', None, ''),
#  ('country', 'varchar(255)', 'YES', '', None, ''),
#  ('utc_correction', 'varchar(255)', 'YES', '', None, '')]

# %%
# %%sql
# SELECT state, zip, COUNT(DISTINCT user_guid) as unique_user_count
# FROM users
# WHERE country = 'US'
# GROUP BY state, zip
# ORDER BY state ASC, unique_user_count DESC
# Out:
# 5043 rows affected.
# [('AE', '9128', 2),
#  ('AE', '9053', 1),
#  ('AE', '9107', 1),
#  ('AE', '9469', 1),
#  ('AE', '9845', 1),
#  ('AK', '99507', 3),
#  ('AK', '99709', 3),
#  ('AK', '99501', 2),
#  ('AK', '99577', 2),
#  ('AK', '99502', 1),
#  ('AK', '99509', 1),
#  ('AK', '99516', 1),
#  ('AK', '99518', 1),
#  ('AK', '99567', 1),
#  ('AK', '99587', 1),
#  ('AK', '99611', 1),
#  ('AK', '99645', 1),
#  ('AK', '99676', 1),
#  ('AK', '99705', 1),
#  ('AK', '99712', 1),
#  ('AK', '99752', 1),
#  ('AK', '99775', 1),
#  ('AK', '99824', 1),
#  ('AK', '99928', 1),
#  ('AL', '35209', 4),
#  ('AL', '35801', 2),
#  ('AL', '36116', 2),
#  ('AL', '36532', 2),
#  ('AL', '36609', 2),
#  ('AL', '35216', 1),
#  ('AL', '35242', 1),
#  ('AL', '35405', 1),
#  ('AL', '35476', 1),
#  ('AL', '35646', 1),
#  ('AL', '35662', 1),
#  ('AL', '35674', 1),
#  ('AL', '35758', 1),
#  ('AL', '35760', 1),
#  ('AL', '35763', 1),
#  ('AL', '35803', 1),
#  ('AL', '35906', 1),
#  ('AL', '35976', 1),
#  ('AL', '36037', 1),
#  ('AL', '36104', 1),
#  ('AL', '36106', 1),
#  ('AL', '36203', 1),
#  ('AL', '36303', 1),
#  ('AL', '36375', 1),
#  ('AL', '36527', 1),
#  ('AL', '36561', 1),
#  ('AL', '36602', 1),
#  ('AL', '36604', 1),
#  ('AL', '35004', 1),
#  ('AL', '35007', 1),
#  ('AL', '36695', 1),
#  ('AL', '35094', 1),
#  ('AL', '35121', 1),
#  ('AL', '36801', 1),
#  ('AL', '35179', 1),
#  ('AL', '36832', 1),
#  ('AL', '35205', 1),
#  ('AP', '96310', 1),
#  ('AP', '96367', 1),
#  ('AP', '96377', 1),
#  ('AP', '96205', 1),
#  ('AR', '72207', 3),
#  ('AR', '72401', 3),
#  ('AR', '72223', 2),
#  ('AR', '72632', 2),
#  ('AR', '72712', 2),
#  ('AR', '72956', 1),
#  ('AR', '71909', 1),
#  ('AR', '71913', 1),
#  ('AR', '72015', 1),
#  ('AR', '72034', 1),
#  ('AR', '72042', 1),
#  ('AR', '72058', 1),
#  ('AR', '72113', 1),
#  ('AR', '72135', 1),
#  ('AR', '72201', 1),
#  ('AR', '72202', 1),
#  ('AR', '72206', 1),
#  ('AR', '72212', 1),
#  ('AR', '72554', 1),
#  ('AR', '72631', 1),
#  ('AR', '72701', 1),
#  ('AR', '72703', 1),
#  ('AR', '72704', 1),
#  ('AR', '72714', 1),
#  ('AR', '72756', 1),
#  ('AR', '72762', 1),
#  ('AR', '72802', 1),
#  ('AR', '72901', 1),
#  ('AR', '72908', 1),
#  ('AZ', '86303', 14),
#  ('AZ', '85718', 6),
#  ('AZ', '85749', 5),
#  ('AZ', '85253', 5),
#  ('AZ', '85254', 5),
#  ('AZ', '85260', 5),
#  ('AZ', '85711', 5),
#  ('AZ', '85750', 4),
#  ('AZ', 'N/A', 4),
#  ('AZ', '85266', 4),
#  ('AZ', '85716', 4),
#  ('AZ', '85719', 4),
#  ('AZ', '86305', 3),
#  ('AZ', '85392', 3),
#  ('AZ', '85233', 3),
#  ('AZ', '85021', 3),
#  ('AZ', '85022', 3),
#  ('AZ', '85250', 3),
#  ('AZ', '85032', 3),
#  ('AZ', '85255', 3),
#  ('AZ', '85042', 3),
#  ('AZ', '85257', 3),
#  ('AZ', '85044', 3),
#  ('AZ', '85048', 3),
#  ('AZ', '85282', 3),
#  ('AZ', '85283', 3),
#  ('AZ', '85296', 3),
#  ('AZ', '85737', 3),
#  ('AZ', '85203', 2),
#  ('AZ', '85748', 2),
#  ('AZ', '85206', 2),
#  ('AZ', '85374', 2),
#  ('AZ', '85024', 2),
#  ('AZ', '85615', 2),
#  ('AZ', '85251', 2),
#  ('AZ', '85028', 2),
#  ('AZ', '86351', 2),
#  ('AZ', '85259', 2),
#  ('AZ', '85045', 2),
#  ('AZ', '85704', 2),
#  ('AZ', '85086', 2),
#  ('AZ', '85712', 2),
#  ('AZ', '85281', 2),
#  ('AZ', '85715', 2),
#  ('AZ', '85304', 2),
#  ('AZ', '85739', 2),
#  ('AZ', '85143', 2),
#  ('AZ', '85202', 2),
#  ('AZ', '85745', 2),
#  ('AZ', '85335', 1),
#  ('AZ', '85338', 1),
#  ('AZ', '85205', 1),
#  ('AZ', '85006', 1),
#  ('AZ', '85340', 1),
#  ('AZ', '85008', 1),
#  ('AZ', '85353', 1),
#  ('AZ', '85207', 1),
#  ('AZ', '85012', 1),
#  ('AZ', '85755', 1),
#  ('AZ', '85365', 1),
#  ('AZ', '85209', 1),
#  ('AZ', '85013', 1),
#  ('AZ', '86002', 1),
#  ('AZ', '85210', 1),
#  ('AZ', '85015', 1),
#  ('AZ', '86301', 1),
#  ('AZ', '85382', 1),
#  ('AZ', '85212', 1),
#  ('AZ', '85016', 1),
#  ('AZ', '85385', 1),
#  ('AZ', '85226', 1),
#  ('AZ', '85020', 1),
#  ('AZ', '86312', 1),
#  ('AZ', '86314', 1),
#  ('AZ', '85248', 1),
#  ('AZ', '86323', 1),
#  ('AZ', '85614', 1),
#  ('AZ', '85249', 1),
#  ('AZ', '86326', 1),
#  ('AZ', '85027', 1),
#  ('AZ', '86327', 1),
#  ('AZ', '85622', 1),
#  ('AZ', '86336', 1),
#  ('AZ', '85635', 1),
#  ('AZ', '85029', 1),
#  ('AZ', '85636', 1),
#  ('AZ', '86403', 1),
#  ('AZ', '85641', 1),
#  ('AZ', '86426', 1),
#  ('AZ', '85646', 1),
#  ('AZ', '86504', 1),
#  ('AZ', '85650', 1),
#  ('AZ', '85658', 1),
#  ('AZ', '85050', 1),
#  ('AZ', '85262', 1),
#  ('AZ', '85069', 1),
#  ('AZ', '85710', 1),
#  ('AZ', '85083', 1),
#  ('AZ', '85268', 1),
#  ('AZ', '85118', 1),
#  ('AZ', '85119', 1),
#  ('AZ', '85120', 1),
#  ('AZ', '85284', 1),
#  ('AZ', '85122', 1),
#  ('AZ', '85286', 1),
#  ('AZ', '85128', 1),
#  ('AZ', '85730', 1),
#  ('AZ', '85138', 1),
#  ('AZ', '85303', 1),
#  ('AZ', '85140', 1),
#  ('AZ', '85308', 1),
#  ('AZ', '85743', 1),
#  ('AZ', '85327', 1),
#  ('CA', '92107', 16),
#  ('CA', '90046', 13),
#  ('CA', '92130', 12),
#  ('CA', '94107', 12),
#  ('CA', '94110', 10),
#  ('CA', '92024', 10),
#  ('CA', '94611', 9),
#  ('CA', '94114', 9),
#  ('CA', '94941', 9),
#  ('CA', '94025', 9),
#  ('CA', '92064', 8),
#  ('CA', '90049', 8),
#  ('CA', '90068', 8),
#  ('CA', '90069', 8),
#  ('CA', '94131', 8),
#  ('CA', '94602', 7),
#  ('CA', '90278', 7),
#  ('CA', '90291', 7),
#  ('CA', '90292', 7),
#  ('CA', '90803', 7),
#  ('CA', '93003', 7),
#  ('CA', '94117', 7),
#  ('CA', '94121', 7),
#  ('CA', '90266', 7),
#  ('CA', '90274', 6),
#  ('CA', '94952', 6),
#  ('CA', '90277', 6),
#  ('CA', '90036', 6),
#  ('CA', '94549', 6),
#  ('CA', '90039', 6),
#  ('CA', '94061', 6),
#  ('CA', '95762', 6),
#  ('CA', '92071', 6),
#  ('CA', '95008', 6),
#  ('CA', '95014', 6),
#  ('CA', '91301', 6),
#  ('CA', '92103', 6),
#  ('CA', '94901', 6),
#  ('CA', '94903', 6),
#  ('CA', '92672', 6),
#  ('CA', '94123', 6),
#  ('CA', '94040', 5),
#  ('CA', '93105', 5),
#  ('CA', '95476', 5),
#  ('CA', '94550', 5),
#  ('CA', '91406', 5),
#  ('CA', '95003', 5),
#  ('CA', '92211', 5),
#  ('CA', '95818', 5),
#  ('CA', '90405', 5),
#  ('CA', '92101', 5),
#  ('CA', '92009', 5),
#  ('CA', '94706', 5),
#  ('CA', '94510', 5),
#  ('CA', '94109', 5),
#  ('CA', '93940', 5),
#  ('CA', '92106', 5),
#  ('CA', '90210', 5),
#  ('CA', '94904', 5),
#  ('CA', '93012', 5),
#  ('CA', '94118', 5),
#  ('CA', '90232', 5),
#  ('CA', '93023', 5),
#  ('CA', '90025', 5),
#  ('CA', '94597', 5),
#  ('CA', '92122', 5),
#  ('CA', '91367', 4),
#  ('CA', '91030', 4),
#  ('CA', '93103', 4),
#  ('CA', '92126', 4),
#  ('CA', '90034', 4),
#  ('CA', '93561', 4),
#  ('CA', '95472', 4),
#  ('CA', '92128', 4),
#  ('CA', '95125', 4),
#  ('CA', '94965', 4),
#  ('CA', '92067', 4),
#  ('CA', '94306', 4),
#  ('CA', '94062', 4),
#  ('CA', '92612', 4),
#  ('CA', '94403', 4),
#  ('CA', '91941', 4),
#  ('CA', '90404', 4),
#  ('CA', '92078', 4),
#  ('CA', '94558', 4),
#  ('CA', '91942', 4),
#  ('CA', '94501', 4),
#  ('CA', '94703', 4),
#  ('CA', '94506', 4),
#  ('CA', '90720', 4),
#  ('CA', '95608', 4),
#  ('CA', '91307', 4),
#  ('CA', '95616', 4),
#  ('CA', '95401', 4),
#  ('CA', '90004', 4),
#  ('CA', '92649', 4),
#  ('CA', '92886', 4),
#  ('CA', '95403', 4),
#  ('CA', '91320', 4),
#  ('CA', '90211', 4),
#  ('CA', '94523', 4),
#  ('CA', '95404', 4),
#  ('CA', '92656', 4),
#  ('CA', '92109', 4),
#  ('CA', '90212', 4),
#  ('CA', '94583', 4),
#  ('CA', '92026', 4),
#  ('CA', '95407', 4),
#  ('CA', '92660', 4),
#  ('CA', '92116', 4),
#  ('CA', '92117', 4),
#  ('CA', '90265', 4),
#  ('CA', '94127', 4),
#  ('CA', '92677', 4),
#  ('CA', '90026', 4),
#  ('CA', '90027', 4),
#  ('CA', '93546', 3),
#  ('CA', '92056', 3),
#  ('CA', '93065', 3),
#  ('CA', '92691', 3),
#  ('CA', '94027', 3),
#  ('CA', '92057', 3),
#  ('CA', '92592', 3),
#  ('CA', '91403', 3),
#  ('CA', '91101', 3),
#  ('CA', '94607', 3),
#  ('CA', '92603', 3),
#  ('CA', '92129', 3),
#  ('CA', '94551', 3),
#  ('CA', '95492', 3),
#  ('CA', '94609', 3),
#  ('CA', '92131', 3),
#  ('CA', '93230', 3),
#  ('CA', '95136', 3),
#  ('CA', '92618', 3),
#  ('CA', '90403', 3),
#  ('CA', '94618', 3),
#  ('CA', '93711', 3),
#  ('CA', '94619', 3),
#  ('CA', '92081', 3),
#  ('CA', '95819', 3),
#  ('CA', '92084', 3),
#  ('CA', '91208', 3),
#  ('CA', '94563', 3),
#  ('CA', '90064', 3),
#  ('CA', '92629', 3),
#  ('CA', '90065', 3),
#  ('CA', '92008', 3),
#  ('CA', '94705', 3),
#  ('CA', '92867', 3),
#  ('CA', '92646', 3),
#  ('CA', '93907', 3),
#  ('CA', '95032', 3),
#  ('CA', '90731', 3),
#  ('CA', '94568', 3),
#  ('CA', '92019', 3),
#  ('CA', '91311', 3),
#  ('CA', '93924', 3),
#  ('CA', '95926', 3),
#  ('CA', '95618', 3),
#  ('CA', '94115', 3),
#  ('CA', '95621', 3),
#  ('CA', '95051', 3),
#  ('CA', '91321', 3),
#  ('CA', '93955', 3),
#  ('CA', '94002', 3),
#  ('CA', '90807', 3),
#  ('CA', '95062', 3),
#  ('CA', '94010', 3),
#  ('CA', '92111', 3),
#  ('CA', '95630', 3),
#  ('CA', '94928', 3),
#  ('CA', '92115', 3),
#  ('CA', '95648', 3),
#  ('CA', '92037', 3),
#  ('CA', '93035', 3),
#  ('CA', '94536', 3),
#  ('CA', '90024', 3),
#  ('CA', '91001', 3),
#  ('CA', '95682', 3),
#  ('CA', '93041', 3),
#  ('CA', '95448', 3),
#  ('CA', '91786', 3),
#  ('CA', '92562', 3),
#  ('CA', '94949', 3),
#  ('CA', '94598', 3),
#  ('CA', '91364', 3),
#  ('CA', '92123', 2),
#  ('CA', '95691', 2),
#  ('CA', '95460', 2),
#  ('CA', '90029', 2),
#  ('CA', '94133', 2),
#  ('CA', '92124', 2),
#  ('CA', '94954', 2),
#  ('CA', '92694', 2),
#  ('CA', '94158', 2),
#  ('CA', '91387', 2),
#  ('CA', '94041', 2),
#  ('CA', '95695', 2),
#  ('CA', '94301', 2),
#  ('CA', '95124', 2),
#  ('CA', '94960', 2),
#  ('CA', '96161', 2),
#  ('CA', '93110', 2),
#  ('CA', 'N/A', 2),
#  ('CA', '91104', 2),
#  ('CA', '92065', 2),
#  ('CA', '95482', 2),
#  ('CA', '91105', 2),
#  ('CA', '94608', 2),
#  ('CA', '92606', 2),
#  ('CA', '91106', 2),
#  ('CA', '94553', 2),
#  ('CA', '92780', 2),
#  ('CA', '95134', 2),
#  ('CA', '91423', 2),
#  ('CA', '94070', 2),
#  ('CA', '94610', 2),
#  ('CA', '90402', 2),
#  ('CA', '90045', 2),
#  ('CA', '92782', 2),
#  ('CA', '95005', 2),
#  ('CA', '92075', 2),
#  ('CA', '91502', 2),
#  ('CA', '95816', 2),
#  ('CA', '91505', 2),
#  ('CA', '95010', 2),
#  ('CA', '93291', 2),
#  ('CA', '94559', 2),
#  ('CA', '91945', 2),
#  ('CA', '94502', 2),
#  ('CA', '92626', 2),
#  ('CA', '94089', 2),
#  ('CA', '91207', 2),
#  ('CA', '90503', 2),
#  ('CA', '92003', 2),
#  ('CA', '91604', 2),
#  ('CA', '92627', 2),
#  ('CA', '93308', 2),
#  ('CA', '92835', 2),
#  ('CA', '94505', 2),
#  ('CA', '95354', 2),
#  ('CA', '91606', 2),
#  ('CA', '90638', 2),
#  ('CA', '93309', 2),
#  ('CA', '94564', 2),
#  ('CA', '91607', 2),
#  ('CA', '90066', 2),
#  ('CA', '94507', 2),
#  ('CA', '95030', 2),
#  ('CA', '91302', 2),
#  ('CA', '95835', 2),
#  ('CA', '94566', 2),
#  ('CA', '92010', 2),
#  ('CA', '92647', 2),
#  ('CA', '93908', 2),
#  ('CA', '94707', 2),
#  ('CA', '95843', 2),
#  ('CA', '93401', 2),
#  ('CA', '94515', 2),
#  ('CA', '92880', 2),
#  ('CA', '95033', 2),
#  ('CA', '93923', 2),
#  ('CA', '92104', 2),
#  ('CA', '93402', 2),
#  ('CA', '92014', 2),
#  ('CA', '92881', 2),
#  ('CA', '94519', 2),
#  ('CA', '92270', 2),
#  ('CA', '90755', 2),
#  ('CA', '92020', 2),
#  ('CA', '95620', 2),
#  ('CA', '94521', 2),
#  ('CA', '90012', 2),
#  ('CA', '91730', 2),
#  ('CA', '92653', 2),
#  ('CA', '93422', 2),
#  ('CA', '93010', 2),
#  ('CA', '94116', 2),
#  ('CA', '92373', 2),
#  ('CA', '95959', 2),
#  ('CA', '94582', 2),
#  ('CA', '94526', 2),
#  ('CA', '92657', 2),
#  ('CA', '94920', 2),
#  ('CA', '92110', 2),
#  ('CA', '93013', 2),
#  ('CA', '90808', 2),
#  ('CA', '93444', 2),
#  ('CA', '94530', 2),
#  ('CA', '95409', 2),
#  ('CA', '95065', 2),
#  ('CA', '95070', 2),
#  ('CA', '91335', 2),
#  ('CA', '92506', 2),
#  ('CA', '94930', 2),
#  ('CA', '90813', 2),
#  ('CA', '94534', 2),
#  ('CA', '92673', 2),
#  ('CA', '91354', 2),
#  ('CA', '94015', 2),
#  ('CA', '94939', 2),
#  ('CA', '96022', 2),
#  ('CA', '95437', 2),
#  ('CA', '95110', 2),
#  ('CA', '91355', 2),
#  ('CA', '90815', 2),
#  ('CA', '95678', 2),
#  ('CA', '93036', 2),
#  ('CA', '94129', 2),
#  ('CA', '95112', 2),
#  ('CA', '94022', 2),
#  ('CA', '92120', 2),
#  ('CA', '94539', 2),
#  ('CA', '94024', 2),
#  ('CA', '93536', 2),
#  ('CA', '90272', 2),
#  ('CA', '92054', 2),
#  ('CA', '93063', 2),
#  ('CA', '94132', 2),
#  ('CA', '91016', 1),
#  ('CA', '94599', 1),
#  ('CA', '94544', 1),
#  ('CA', '91791', 1),
#  ('CA', '95119', 1),
#  ('CA', '92590', 1),
#  ('CA', '96141', 1),
#  ('CA', '93549', 1),
#  ('CA', '95692', 1),
#  ('CA', '94545', 1),
#  ('CA', '95465', 1),
#  ('CA', '90031', 1),
#  ('CA', '91801', 1),
#  ('CA', '92692', 1),
#  ('CA', '94134', 1),
#  ('CA', '95120', 1),
#  ('CA', '91377', 1),
#  ('CA', '96145', 1),
#  ('CA', '91041', 1),
#  ('CA', '93550', 1),
#  ('CA', '95694', 1),
#  ('CA', '92058', 1),
#  ('CA', '94546', 1),
#  ('CA', '95470', 1),
#  ('CA', '91901', 1),
#  ('CA', '95123', 1),
#  ('CA', '92593', 1),
#  ('CA', '94955', 1),
#  ('CA', '96151', 1),
#  ('CA', '91042', 1),
#  ('CA', '92127', 1),
#  ('CA', '94605', 1),
#  ('CA', '90290', 1),
#  ('CA', '92059', 1),
#  ('CA', '93108', 1),
#  ('CA', '94547', 1),
#  ('CA', '91902', 1),
#  ('CA', '92701', 1),
#  ('CA', '92595', 1),
#  ('CA', '94043', 1),
#  ('CA', '93562', 1),
#  ('CA', '94606', 1),
#  ('CA', '95722', 1),
#  ('CA', '91908', 1),
#  ('CA', '92705', 1),
#  ('CA', '94303', 1),
#  ('CA', '91405', 1),
#  ('CA', '92602', 1),
#  ('CA', '94044', 1),
#  ('CA', '94963', 1),
#  ('CA', '93611', 1),
#  ('CA', '95746', 1),
#  ('CA', '93117', 1),
#  ('CA', '90041', 1),
#  ('CA', '91910', 1),
#  ('CA', '92707', 1),
#  ('CA', '94304', 1),
#  ('CA', '95128', 1),
#  ('CA', '93619', 1),
#  ('CA', '95747', 1),
#  ('CA', '90293', 1),
#  ('CA', '93150', 1),
#  ('CA', '90042', 1),
#  ('CA', '91913', 1),
#  ('CA', '92708', 1),
#  ('CA', '95132', 1),
#  ('CA', '91411', 1),
#  ('CA', '94966', 1),
#  ('CA', '94063', 1),
#  ('CA', '94970', 1),
#  ('CA', '93637', 1),
#  ('CA', '90401', 1),
#  ('CA', '93225', 1),
#  ('CA', '95501', 1),
#  ('CA', '90043', 1),
#  ('CA', '91921', 1),
#  ('CA', '94402', 1),
#  ('CA', '92610', 1),
#  ('CA', '91436', 1),
#  ('CA', '91201', 1),
#  ('CA', '93643', 1),
#  ('CA', '95765', 1),
#  ('CA', '92072', 1),
#  ('CA', '94555', 1),
#  ('CA', '95503', 1),
#  ('CA', '91931', 1),
#  ('CA', '91501', 1),
#  ('CA', '94080', 1),
#  ('CA', '91203', 1),
#  ('CA', '92143', 1),
#  ('CA', '93654', 1),
#  ('CA', '95811', 1),
#  ('CA', '93243', 1),
#  ('CA', '94556', 1),
#  ('CA', '95519', 1),
#  ('CA', '92806', 1),
#  ('CA', '94404', 1),
#  ('CA', '95138', 1),
#  ('CA', '92620', 1),
#  ('CA', '94086', 1),
#  ('CA', '91204', 1),
#  ('CA', '92163', 1),
#  ('CA', '93710', 1),
#  ('CA', '93257', 1),
#  ('CA', '95536', 1),
#  ('CA', '90048', 1),
#  ('CA', '92807', 1),
#  ('CA', '95212', 1),
#  ('CA', '92625', 1),
#  ('CA', '94087', 1),
#  ('CA', '91205', 1),
#  ('CA', '95540', 1),
#  ('CA', '92821', 1),
#  ('CA', '95227', 1),
#  ('CA', '91602', 1),
#  ('CA', '92223', 1),
#  ('CA', '93720', 1),
#  ('CA', '94702', 1),
#  ('CA', '93292', 1),
#  ('CA', '94560', 1),
#  ('CA', '95570', 1),
#  ('CA', '90051', 1),
#  ('CA', '92831', 1),
#  ('CA', '94503', 1),
#  ('CA', '95236', 1),
#  ('CA', '95018', 1),
#  ('CA', '92232', 1),
#  ('CA', '93722', 1),
#  ('CA', '95831', 1),
#  ('CA', '90504', 1),
#  ('CA', '92091', 1),
#  ('CA', '95602', 1),
#  ('CA', '92007', 1),
#  ('CA', '94102', 1),
#  ('CA', '95020', 1),
#  ('CA', '91214', 1),
#  ('CA', '92247', 1),
#  ('CA', '93726', 1),
#  ('CA', '94704', 1),
#  ('CA', '95833', 1),
#  ('CA', '92092', 1),
#  ('CA', '95603', 1),
#  ('CA', '92865', 1),
#  ('CA', '95355', 1),
#  ('CA', '92637', 1),
#  ('CA', '94103', 1),
#  ('CA', '95023', 1),
#  ('CA', '92253', 1),
#  ('CA', '93730', 1),
#  ('CA', '95834', 1),
#  ('CA', '90704', 1),
#  ('CA', '93311', 1),
#  ('CA', '94565', 1),
#  ('CA', '95605', 1),
#  ('CA', '95356', 1),
#  ('CA', '91701', 1),
#  ('CA', '92260', 1),
#  ('CA', '92102', 1),
#  ('CA', '93312', 1),
#  ('CA', '90067', 1),
#  ('CA', '92869', 1),
#  ('CA', '95361', 1),
#  ('CA', '91303', 1),
#  ('CA', '92262', 1),
#  ('CA', '95610', 1),
#  ('CA', '92011', 1),
#  ('CA', '92870', 1),
#  ('CA', '95366', 1),
#  ('CA', '94518', 1),
#  ('CA', '95383', 1),
#  ('CA', '91702', 1),
#  ('CA', '92648', 1),
#  ('CA', '92263', 1),
#  ('CA', '94708', 1),
#  ('CA', '95864', 1),
#  ('CA', '90740', 1),
#  ('CA', '94571', 1),
#  ('CA', '90071', 1),
#  ('CA', '91711', 1),
#  ('CA', '94112', 1),
#  ('CA', '95037', 1),
#  ('CA', '94709', 1),
#  ('CA', '92105', 1),
#  ('CA', '93405', 1),
#  ('CA', '94574', 1),
#  ('CA', '90077', 1),
#  ('CA', '94520', 1),
#  ('CA', '90005', 1),
#  ('CA', '91723', 1),
#  ('CA', '92651', 1),
#  ('CA', '95046', 1),
#  ('CA', '91316', 1),
#  ('CA', '92307', 1),
#  ('CA', '95945', 1),
#  ('CA', '93420', 1),
#  ('CA', '94577', 1),
#  ('CA', '92021', 1),
#  ('CA', '95050', 1),
#  ('CA', '92320', 1),
#  ('CA', '93953', 1),
#  ('CA', '95949', 1),
#  ('CA', '90804', 1),
#  ('CA', '94580', 1),
#  ('CA', '90014', 1),
#  ('CA', '91737', 1),
#  ('CA', '90806', 1),
#  ('CA', '93428', 1),
#  ('CA', '95624', 1),
#  ('CA', '92025', 1),
#  ('CA', '95405', 1),
#  ('CA', '90015', 1),
#  ('CA', '91748', 1),
#  ('CA', '95060', 1),
#  ('CA', '91324', 1),
#  ('CA', '92374', 1),
#  ('CA', '95965', 1),
#  ('CA', '93443', 1),
#  ('CA', '95628', 1),
#  ('CA', '90230', 1),
#  ('CA', '94528', 1),
#  ('CA', '90016', 1),
#  ('CA', '91750', 1),
#  ('CA', '91325', 1),
#  ('CA', '92503', 1),
#  ('CA', '94925', 1),
#  ('CA', '96001', 1),
#  ('CA', '94585', 1),
#  ('CA', '92027', 1),
#  ('CA', '90017', 1),
#  ('CA', '91755', 1),
#  ('CA', '92663', 1),
#  ('CA', '91326', 1),
#  ('CA', '92504', 1),
#  ('CA', '94011', 1),
#  ('CA', '96002', 1),
#  ('CA', '90810', 1),
#  ('CA', '93446', 1),
#  ('CA', '94588', 1),
#  ('CA', '95633', 1),
#  ('CA', '90242', 1),
#  ('CA', '92028', 1),
#  ('CA', '93021', 1),
#  ('CA', '94531', 1),
#  ('CA', '95425', 1),
#  ('CA', '90019', 1),
#  ('CA', '91764', 1),
#  ('CA', '94122', 1),
#  ('CA', '94014', 1),
#  ('CA', '96003', 1),
#  ('CA', '93447', 1),
#  ('CA', '94590', 1),
#  ('CA', '90247', 1),
#  ('CA', '95436', 1),
#  ('CA', '90020', 1),
#  ('CA', '91770', 1),
#  ('CA', '95076', 1),
#  ('CA', '92516', 1),
#  ('CA', '90814', 1),
#  ('CA', '93452', 1),
#  ('CA', '94591', 1),
#  ('CA', '95650', 1),
#  ('CA', '92038', 1),
#  ('CA', '91775', 1),
#  ('CA', '92675', 1),
#  ('CA', '92545', 1),
#  ('CA', '94018', 1),
#  ('CA', '96067', 1),
#  ('CA', '92118', 1),
#  ('CA', '93458', 1),
#  ('CA', '94595', 1),
#  ('CA', '95677', 1),
#  ('CA', '92119', 1),
#  ('CA', '93463', 1),
#  ('CA', '94596', 1),
#  ('CA', '92040', 1),
#  ('CA', '94538', 1),
#  ('CA', '95442', 1),
#  ('CA', '91776', 1),
#  ('CA', '91356', 1),
#  ('CA', '92549', 1),
#  ('CA', '94947', 1),
#  ('CA', '96073', 1),
#  ('CA', '91006', 1),
#  ('CA', '93534', 1),
#  ('CA', '92046', 1),
#  ('CA', '92683', 1),
#  ('CA', '95113', 1),
#  ('CA', '91361', 1),
#  ('CA', '96104', 1),
#  ('CA', '91011', 1),
#  ('CA', '95688', 1),
#  ('CA', '94542', 1),
#  ('CA', '95457', 1),
#  ('CA', '91789', 1),
#  ('CA', '92688', 1),
#  ('CA', '95116', 1),
#  ('CA', '92586', 1),
#  ('CA', '94951', 1),
#  ('CA', '96107', 1),
#  ('CO', '80304', 10),
#  ('CO', '80210', 9),
#  ('CO', '80526', 7),
#  ('CO', '80303', 7),
#  ('CO', '80403', 6),
#  ('CO', '80220', 6),
#  ('CO', '80227', 5),
#  ('CO', '80126', 5),
#  ('CO', '80401', 5),
#  ('CO', '80205', 5),
#  ('CO', '80206', 5),
#  ('CO', '80237', 4),
#  ('CO', '81601', 4),
#  ('CO', '81620', 4),
#  ('CO', '80127', 4),
#  ('CO', '80128', 4),
#  ('CO', '80132', 4),
#  ('CO', '80134', 4),
#  ('CO', '80020', 4),
#  ('CO', '80439', 4),
#  ('CO', '80021', 4),
#  ('CO', '80026', 4),
#  ('CO', '80211', 4),
#  ('CO', '80922', 4),
#  ('CO', '80521', 4),
#  ('CO', '80111', 4),
#  ('CO', '80302', 3),
#  ('CO', '80014', 3),
#  ('CO', '80015', 3),
#  ('CO', '80904', 3),
#  ('CO', '80906', 3),
#  ('CO', '80212', 3),
#  ('CO', '80503', 3),
#  ('CO', '80525', 3),
#  ('CO', '80113', 2),
#  ('CO', '80120', 2),
#  ('CO', '81301', 2),
#  ('CO', '80234', 2),
#  ('CO', '81501', 2),
#  ('CO', '80238', 2),
#  ('CO', '80004', 2),
#  ('CO', '81611', 2),
#  ('CO', '80247', 2),
#  ('CO', '80005', 2),
#  ('CO', '80301', 2),
#  ('CO', '81623', 2),
#  ('CO', '80129', 2),
#  ('CO', '80138', 2),
#  ('CO', '80827', 2),
#  ('CO', '80203', 2),
#  ('CO', '80908', 2),
#  ('CO', '80027', 2),
#  ('CO', '80917', 2),
#  ('CO', '80918', 2),
#  ('CO', '80214', 2),
#  ('CO', '80919', 2),
#  ('CO', '80923', 2),
#  ('CO', '80218', 2),
#  ('CO', '80222', 2),
#  ('CO', '80524', 2),
#  ('CO', '80112', 2),
#  ('CO', '81236', 1),
#  ('CO', '80527', 1),
#  ('CO', '80228', 1),
#  ('CO', '80116', 1),
#  ('CO', '81252', 1),
#  ('CO', '80528', 1),
#  ('CO', '80230', 1),
#  ('CO', '80534', 1),
#  ('CO', '80233', 1),
#  ('CO', '80121', 1),
#  ('CO', '81403', 1),
#  ('CO', '80537', 1),
#  ('CO', '80122', 1),
#  ('CO', '80540', 1),
#  ('CO', '80123', 1),
#  ('CO', '80000', 1),
#  ('CO', '81507', 1),
#  ('CO', '80542', 1),
#  ('CO', '80124', 1),
#  ('CO', '80002', 1),
#  ('CO', '80547', 1),
#  ('CO', '80602', 1),
#  ('CO', '81621', 1),
#  ('CO', '80631', 1),
#  ('CO', '80010', 1),
#  ('CO', '80634', 1),
#  ('CO', '80011', 1),
#  ('CO', '81625', 1),
#  ('CO', '80643', 1),
#  ('CO', '80012', 1),
#  ('CO', '81639', 1),
#  ('CO', '80644', 1),
#  ('CO', '80308', 1),
#  ('CO', '80013', 1),
#  ('CO', '81652', 1),
#  ('CO', '80808', 1),
#  ('CO', '80813', 1),
#  ('CO', '80202', 1),
#  ('CO', '80422', 1),
#  ('CO', '80016', 1),
#  ('CO', '80829', 1),
#  ('CO', '80430', 1),
#  ('CO', '80204', 1),
#  ('CO', '80864', 1),
#  ('CO', '80465', 1),
#  ('CO', '80207', 1),
#  ('CO', '80022', 1),
#  ('CO', '80466', 1),
#  ('CO', '80209', 1),
#  ('CO', '80023', 1),
#  ('CO', '80487', 1),
#  ('CO', '80911', 1),
#  ('CO', '80488', 1),
#  ('CO', '80498', 1),
#  ('CO', '80031', 1),
#  ('CO', '80501', 1),
#  ('CO', '80033', 1),
#  ('CO', '80215', 1),
#  ('CO', '80104', 1),
#  ('CO', '80504', 1),
#  ('CO', '80216', 1),
#  ('CO', '80106', 1),
#  ('CO', '80516', 1),
#  ('CO', '80107', 1),
#  ('CO', '80962', 1),
#  ('CO', '80517', 1),
#  ('CO', '80108', 1),
#  ('CO', '81007', 1),
#  ('CO', '80109', 1),
#  ('CO', '81131', 1),
#  ('CO', '80223', 1),
#  ('CO', '81201', 1),
#  ('CO', '80226', 1),
#  ('CO', '81235', 1),
#  ('CT', '6880', 8),
#  ('CT', '6840', 6),
#  ('CT', '6824', 6),
#  ('CT', '6614', 5),
#  ('CT', '6820', 5),
#  ('CT', '6107', 4),
#  ('CT', '6109', 4),
#  ('CT', '6902', 4),
#  ('CT', '6851', 3),
#  ('CT', '6484', 3),
#  ('CT', '6117', 3),
#  ('CT', '6489', 3),
#  ('CT', '6877', 3),
#  ('CT', '6517', 3),
#  ('CT', '6371', 3),
#  ('CT', '6903', 3),
#  ('CT', '6905', 3),
#  ('CT', '6410', 3),
#  ('CT', '6478', 2),
#  ('CT', '6480', 2),
#  ('CT', '6853', 2),
#  ('CT', '6854', 2),
#  ('CT', '6511', 2),
#  ('CT', '6512', 2),
#  ('CT', '6883', 2),
#  ('CT', '6340', 2),
#  ('CT', '6001', 2),
#  ('CT', '6010', 2),
#  ('CT', '6612', 2),
#  ('CT', '6405', 2),
#  ('CT', '6033', 2),
#  ('CT', '6415', 2),
#  ('CT', '6035', 2),
#  ('CT', '6416', 2),
#  ('CT', '6762', 2),
#  ('CT', '6040', 2),
#  ('CT', '6776', 2),
#  ('CT', '6422', 2),
#  ('CT', '6777', 2),
#  ...]

# %% [markdown]
# **Question 7: Write a query that outputs the total number of unique User_Guids in each combination of State and ZIP code in the United States *that have at least 5 users*, sorted first by state name in ascending alphabetical order, and second by total number of unique User_Guids in descending order (your first state/ZIP code combination should be AZ/86303).**

# %%
# %%sql
# SELECT state, zip, COUNT(DISTINCT user_guid) as unique_user_count
# FROM users
# WHERE country = 'US'
# GROUP BY state, zip
# HAVING unique_user_count >= 5
# ORDER BY state ASC, unique_user_count DESC
# Out:
# 285 rows affected.
# [('AZ', '86303', 14),
#  ('AZ', '85718', 6),
#  ('AZ', '85749', 5),
#  ('AZ', '85253', 5),
#  ('AZ', '85254', 5),
#  ('AZ', '85260', 5),
#  ('AZ', '85711', 5),
#  ('CA', '92107', 16),
#  ('CA', '90046', 13),
#  ('CA', '92130', 12),
#  ('CA', '94107', 12),
#  ('CA', '94110', 10),
#  ('CA', '92024', 10),
#  ('CA', '94611', 9),
#  ('CA', '94114', 9),
#  ('CA', '94941', 9),
#  ('CA', '94025', 9),
#  ('CA', '92064', 8),
#  ('CA', '90049', 8),
#  ('CA', '90068', 8),
#  ('CA', '90069', 8),
#  ('CA', '94131', 8),
#  ('CA', '94602', 7),
#  ('CA', '90278', 7),
#  ('CA', '90291', 7),
#  ('CA', '90292', 7),
#  ('CA', '90803', 7),
#  ('CA', '93003', 7),
#  ('CA', '94117', 7),
#  ('CA', '94121', 7),
#  ('CA', '90266', 7),
#  ('CA', '90274', 6),
#  ('CA', '94952', 6),
#  ('CA', '90277', 6),
#  ('CA', '90036', 6),
#  ('CA', '94549', 6),
#  ('CA', '90039', 6),
#  ('CA', '94061', 6),
#  ('CA', '95762', 6),
#  ('CA', '92071', 6),
#  ('CA', '95008', 6),
#  ('CA', '95014', 6),
#  ('CA', '91301', 6),
#  ('CA', '92103', 6),
#  ('CA', '94901', 6),
#  ('CA', '94903', 6),
#  ('CA', '92672', 6),
#  ('CA', '94123', 6),
#  ('CA', '94040', 5),
#  ('CA', '93105', 5),
#  ('CA', '95476', 5),
#  ('CA', '94550', 5),
#  ('CA', '91406', 5),
#  ('CA', '95003', 5),
#  ('CA', '92211', 5),
#  ('CA', '95818', 5),
#  ('CA', '90405', 5),
#  ('CA', '92101', 5),
#  ('CA', '92009', 5),
#  ('CA', '94706', 5),
#  ('CA', '94510', 5),
#  ('CA', '94109', 5),
#  ('CA', '93940', 5),
#  ('CA', '92106', 5),
#  ('CA', '90210', 5),
#  ('CA', '94904', 5),
#  ('CA', '93012', 5),
#  ('CA', '94118', 5),
#  ('CA', '90232', 5),
#  ('CA', '93023', 5),
#  ('CA', '90025', 5),
#  ('CA', '94597', 5),
#  ('CA', '92122', 5),
#  ('CO', '80304', 10),
#  ('CO', '80210', 9),
#  ('CO', '80526', 7),
#  ('CO', '80303', 7),
#  ('CO', '80403', 6),
#  ('CO', '80220', 6),
#  ('CO', '80227', 5),
#  ('CO', '80126', 5),
#  ('CO', '80401', 5),
#  ('CO', '80205', 5),
#  ('CO', '80206', 5),
#  ('CT', '6880', 8),
#  ('CT', '6840', 6),
#  ('CT', '6824', 6),
#  ('CT', '6614', 5),
#  ('CT', '6820', 5),
#  ('DC', '20009', 14),
#  ('DC', '20002', 8),
#  ('DC', '20007', 8),
#  ('DC', '20001', 7),
#  ('DC', '20016', 7),
#  ('DC', '20005', 6),
#  ('DC', '20011', 6),
#  ('DC', '20003', 5),
#  ('DE', '19958', 7),
#  ('FL', '32312', 6),
#  ('FL', '33647', 6),
#  ('FL', '33418', 6),
#  ('FL', '32751', 5),
#  ('FL', '32765', 5),
#  ('FL', '33156', 5),
#  ('GA', '30305', 7),
#  ('GA', '30004', 7),
#  ('GA', '30345', 6),
#  ('GA', '30328', 5),
#  ('GA', '30067', 5),
#  ('GA', '30308', 5),
#  ('GA', '30316', 5),
#  ('HI', '96734', 8),
#  ('ID', '83702', 9),
#  ('IL', '60614', 18),
#  ('IL', '60654', 11),
#  ('IL', '60640', 9),
#  ('IL', '60657', 9),
#  ('IL', '60613', 8),
#  ('IL', '60610', 7),
#  ('IL', '60660', 7),
#  ('IL', '60618', 6),
#  ('IL', '60647', 6),
#  ('IL', '60626', 5),
#  ('IL', '60642', 5),
#  ('IL', '60093', 5),
#  ('IN', '47401', 6),
#  ('KS', '66062', 6),
#  ('LA', '70115', 8),
#  ('LA', '70118', 6),
#  ('MA', '2127', 8),
#  ('MA', '2129', 6),
#  ('MA', '2143', 5),
#  ('MA', '2472', 5),
#  ('MA', '2116', 5),
#  ('MA', '2130', 5),
#  ('MA', '2135', 5),
#  ('MD', '20854', 8),
#  ('MD', '20910', 7),
#  ('MD', '20817', 7),
#  ('MD', '21286', 6),
#  ('MD', '20878', 6),
#  ('MD', '20895', 5),
#  ('MD', '20852', 5),
#  ('MD', '21228', 5),
#  ('MD', '21230', 5),
#  ('MI', '48103', 8),
#  ('MN', '55426', 6),
#  ('MO', '63139', 6),
#  ('MO', '63122', 5),
#  ('MT', '59715', 5),
#  ('N/A', 'N/A', 83),
#  ('NC', '27701', 32),
#  ('NC', '27705', 26),
#  ('NC', '27707', 17),
#  ('NC', '27516', 17),
#  ('NC', '27517', 11),
#  ('NC', '27613', 11),
#  ('NC', '27615', 11),
#  ('NC', '27713', 10),
#  ('NC', '27278', 9),
#  ('NC', '27539', 9),
#  ('NC', '27514', 9),
#  ('NC', '27617', 9),
#  ('NC', '27608', 7),
#  ('NC', '27513', 7),
#  ('NC', '27609', 7),
#  ('NC', '27614', 7),
#  ('NC', '27519', 7),
#  ('NC', '28270', 6),
#  ('NC', '27587', 6),
#  ('NC', '27410', 6),
#  ('NC', '27603', 6),
#  ('NC', '27607', 6),
#  ('NC', '28374', 6),
#  ('NC', '27104', 6),
#  ('NC', '27612', 6),
#  ('NC', '28787', 6),
#  ('NC', '28226', 5),
#  ('NC', '27502', 5),
#  ('NC', '27606', 5),
#  ('NC', '28205', 5),
#  ('NJ', '7030', 8),
#  ('NJ', '7302', 7),
#  ('NJ', '8540', 5),
#  ('NM', '87111', 6),
#  ('NV', '89511', 5),
#  ('NY', '10003', 14),
#  ('NY', '10024', 13),
#  ('NY', '10023', 13),
#  ('NY', '10025', 12),
#  ('NY', '11201', 12),
#  ('NY', '10028', 11),
#  ('NY', '10016', 10),
#  ('NY', '10011', 9),
#  ('NY', '10019', 9),
#  ('NY', '11238', 8),
#  ('NY', '14850', 8),
#  ('NY', '10014', 8),
#  ('NY', '10021', 8),
#  ('NY', '11249', 7),
#  ('NY', '10128', 6),
#  ('NY', '10583', 6),
#  ('NY', '10012', 6),
#  ('NY', '10013', 6),
#  ('NY', '11217', 6),
#  ('NY', '11105', 5),
#  ('NY', '10075', 5),
#  ('NY', '11209', 5),
#  ('NY', '11211', 5),
#  ('NY', '11215', 5),
#  ('NY', '10708', 5),
#  ('NY', '11222', 5),
#  ('NY', '10022', 5),
#  ('OH', '43214', 8),
#  ('OH', '45243', 5),
#  ('OH', '45040', 5),
#  ('OH', '44149', 5),
#  ('OH', '43235', 5),
#  ('OH', '43068', 5),
#  ('OK', '73013', 5),
#  ('OR', '97229', 8),
#  ('OR', '97212', 7),
#  ('OR', '97405', 5),
#  ('OR', '97206', 5),
#  ('OR', '97215', 5),
#  ('OR', '97702', 5),
#  ('PA', '19147', 6),
#  ('PA', '19087', 6),
#  ('PA', '19460', 6),
#  ('PA', '15237', 5),
#  ('PA', '15101', 5),
#  ('SC', '29303', 14),
#  ('SC', '29464', 13),
#  ('SC', '29707', 5),
#  ('SC', '29205', 5),
#  ('SC', '29407', 5),
#  ('TN', '37205', 7),
#  ('TN', '37027', 6),
#  ('TN', '37067', 6),
#  ('TX', '78750', 8),
#  ('TX', '77008', 8),
#  ('TX', '78745', 8),
#  ('TX', '78703', 7),
#  ('TX', '77007', 7),
#  ('TX', '78757', 6),
#  ('TX', '77584', 6),
#  ('TX', '78704', 6),
#  ('TX', '77381', 5),
#  ('TX', '77382', 5),
#  ('TX', '75023', 5),
#  ('TX', '75025', 5),
#  ('TX', '75219', 5),
#  ('TX', '76712', 5),
#  ('TX', '78613', 5),
#  ('TX', '77006', 5),
#  ('TX', '75248', 5),
#  ('TX', '78748', 5),
#  ('UT', '84098', 6),
#  ('VA', '22201', 9),
#  ('VA', '20191', 9),
#  ('VA', '22314', 8),
#  ('VA', '22903', 7),
#  ('VA', '22043', 7),
#  ('VA', '20147', 7),
#  ('VA', '20120', 6),
#  ('VA', '22304', 6),
#  ('VA', '22101', 6),
#  ('VA', '22301', 5),
#  ('VA', '22902', 5),
#  ('VA', '23462', 5),
#  ('WA', '98103', 9),
#  ('WA', '98118', 7),
#  ('WA', '98122', 7),
#  ('WA', '98225', 7),
#  ('WA', '98102', 7),
#  ('WA', '98033', 6),
#  ('WA', '98115', 6),
#  ('WA', '98045', 6),
#  ('WA', '98052', 6),
#  ('WA', '98199', 6),
#  ('WA', '98074', 6),
#  ('WA', '98106', 5),
#  ('WA', '98110', 5),
#  ('WA', '98072', 5),
#  ('WI', '53213', 5)]

# %% [markdown]
# <mark>**Be sure to watch the next video before beginning Exercise 6, the next set of MySQL exercises</mark>,** **and feel free to practice any other queries you wish below!**
